# %%
import rdflib
from rdflib import Graph, Namespace, RDF, RDFS, OWL, URIRef, Literal, XSD

# Create graph
g = Graph()

# Define Namespaces
schema  = Namespace("http://schema.org/")
rdf     = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
rdfs    = Namespace("http://www.w3.org/2000/01/rdf-schema#")
owl     = Namespace("http://www.w3.org/2002/07/owl#")
xsd     = Namespace("http://www.w3.org/2001/XMLSchema#")
fo      = Namespace("https://purl.org/ontology/fo/")
dbr     = Namespace("http://dbpedia.org/resource/")
ex      = Namespace("http://example.org/")
foodon = Namespace("http://purl.obolibrary.org/obo/FOODON_")
wikidata = Namespace("http://www.wikidata.org/entity/")
OBO = Namespace("http://purl.obolibrary.org/obo/")

g.bind("schema", schema)
g.bind("rdf", rdf)
g.bind("rdfs", rdfs)
g.bind("owl", owl)
g.bind("xsd", xsd)
g.bind("fo", fo)
g.bind("dbr",dbr)
g.bind("ex", ex)
g.bind("obo", OBO)
g.bind("wikidata", wikidata)

# List of subclass relationships
subclass_relationships = [
    # Subclass Macronutrients
    ("Weight","Macronutrients"),("Calories","Macronutrients"),("Fat","Macronutrients"),("Protein","Macronutrients"),("Carbohydrate","Macronutrients"),("Sugars","Macronutrients"),("Fiber","Macronutrients"),("Cholesterol","Macronutrients"),("SaturatedFats","Macronutrients"),("NetCarbs","Macronutrients"),("TransFattyAcids","Macronutrients"),

    # Subclass Minerals
    ("Calcium", "Minerals"), ("Iron", "Minerals"), ("Potassium", "Minerals"),
    ("Magnesium", "Minerals"), ("Phosphorus", "Minerals"), ("Sodium", "Minerals"),
    ("Zinc", "Minerals"), ("Copper", "Minerals"), ("Manganese", "Minerals"),
    ("Selenium", "Minerals"), ("Fluoride", "Minerals"), ("Molybdenum", "Minerals"),
    ("Iodine", "Minerals"), ("Chloride", "Minerals"), ("Chromium", "Minerals"),

    # Subclass Vitamins
    ("VitaminA", "Vitamins"), ("VitaminC", "Vitamins"), ("ThiaminB1", "Vitamins"),
    ("RiboflavinB2", "Vitamins"), ("NiacinB3", "Vitamins"), ("VitaminB5", "Vitamins"),
    ("VitaminB6", "Vitamins"), ("Biotin", "Vitamins"), ("Folate", "Vitamins"),
    ("Folicacid", "Vitamins"), ("Foodfolate", "Vitamins"), ("FolateDFE", "Vitamins"),
    ("Choline", "Vitamins"), ("VitaminB12", "Vitamins"), ("Retinol", "Vitamins"),
    ("Carotenebeta", "Vitamins"), ("Carotenealpha", "Vitamins"),
    ("Cryptoxanthinbeta", "Vitamins"), ("VitaminAIU", "Vitamins"),
    ("Lycopene", "Vitamins"), ("LutZeaxanthin", "Vitamins"), ("VitaminE", "Vitamins"),
    ("VitaminD", "Vitamins"), ("VitaminD2", "Vitamins"), ("VitaminD3", "Vitamins"),
    ("VitaminDIU", "Vitamins"), ("VitaminK", "Vitamins"), ("VitaminK1", "Vitamins"),
    ("Menaquinone4", "Vitamins"),

    # Subclass Others
    ("Water", "OtherComponent"), ("Ash", "OtherComponent"), ("Alcohol", "OtherComponent"),
    ("Caffeine", "OtherComponent"), ("Theobromine", "OtherComponent"), ("PRALscore", "OtherComponent"),

    # Subclass Carbohydrates
    ("SolubleFiber", "Carbohydrates"), ("InsolubleFiber", "Carbohydrates"), ("AddedSugar", "Carbohydrates"),
    ("Sucrose", "Carbohydrates"), ("Glucose", "Carbohydrates"), ("Fructose", "Carbohydrates"),
    ("Lactose", "Carbohydrates"), ("Maltose", "Carbohydrates"), ("Galactose", "Carbohydrates"),
    ("Strarch", "Carbohydrates"), ("otherSugar", "Carbohydrates"), ("SugarAlcohols", "Carbohydrates"),

    # Subclass Fats
    ("TotalMonounsaturated","Fats"),("TotalPolyunsaturated","Fats"),("Omega3s","Fats"),("Omega6s","Fats"),("Omega3toOmega6Ratio","Fats"),("Omega6toOmega3Ratio","Fats"),

    # Subclass Omega3Fat
    ("alphaLinolenicAcid", "Omega3Fat"), ("EicosapentaenoicAcid", "Omega3Fat"), ("DocosapentaenoicAcid", "Omega3Fat"), ("DocosahexaenoicAcid", "Omega3Fat"), ("n3EicosatrienoicAcid", "Omega3Fat"),

    # Subclass Omega6Fat
    ("alphaLinolenicAcid", "Omega6Fat"),("gammaLinolenicAcid", "Omega6Fat"),("ciscisn6EicosadienoicAcid", "Omega6Fat"),("DihomogammalinolenicAcid", "Omega6Fat"),("ArachidonicAcid", "Omega6Fat"),("Butyric", "Omega6Fat"),("Caproic", "Omega6Fat"),("CaprylicAcid", "Omega6Fat"), ("CapricAcid", "Omega6Fat"), ("LauricAcid", "Omega6Fat"), ("TridecanoicAcid", "Omega6Fat"), ("MyristicAcid", "Omega6Fat"),("PentadecanoicAcid", "Omega6Fat"),("PalmiticAcid", "Omega6Fat"),("MargaricAcid", "Omega6Fat"),("StearicAcid", "Omega6Fat"),("ArachidicAcid", "Omega6Fat"),("BehenicAcid", "Omega6Fat"),("LignocericAcid", "Omega6Fat"),

    # Subclass Monounsaturated
    ("MyristoleicAcid", "MonounsaturatedFat"), ("PentadecenoicAcid", "MonounsaturatedFat"), ("PalmitoleicAcid", "MonounsaturatedFat"),
    ("cisPalmitoleicAcid", "MonounsaturatedFat"), ("HeptadecenoicAcid", "MonounsaturatedFat"), ("OleicAcid", "MonounsaturatedFat"),
    ("cisOleicAcid", "MonounsaturatedFat"), ("cisVaccenicAcid", "MonounsaturatedFat"), ("GadoleicAcid", "MonounsaturatedFat"), ("DocosenoicAcid", "MonounsaturatedFat"), ("cisDocosenoicAcid", "MonounsaturatedFat"), ("cisTetracosenoicAcid", "MonounsaturatedFat"),

    # Subclass Polyunsaturated
    ("OctadecadienoicAcid","PolyunsaturatedFat"),("ConjugatedLinoleicAcid","PolyunsaturatedFat"),("iOctadecadienoicAcid","PolyunsaturatedFat"),("undifferentiatedOctadecatrienoic","PolyunsaturatedFat"),("OctadecatrienoicAcid","PolyunsaturatedFat"),("ParinaricAcid","PolyunsaturatedFat"),("EicosatrienoicAcid","PolyunsaturatedFat"),("EicosatetraenoicAcid","PolyunsaturatedFat"),("HeneicosapentaenoicAcid","PolyunsaturatedFat"),("22:4","PolyunsaturatedFat"),

    # Subclass TransFat
    ("TransPolyenoicFats","TransFat"),("TransMonoenoicFats","TransFat"),("transPalmitoleicAcid","TransFat"),("transOleicAcid","TransFat"),("transDocosenoicAcid","TransFat"),("transOctadecadienoicAcid","TransFat"),("transtransOctadecadienoicAcid","TransFat"),

    # Subclass Phytosterols
    ("TotalPhytosterols","Phytosterols"),("Stigmasterol","Phytosterols"),("Campesterol","Phytosterols"),("Betasitosterol","Phytosterols"),

    # Subclass Fats
    ("Omega3Fat", "Fats"), ("Omega6Fat", "Fats"), ("MonounsaturatedFat", "Fats"),("PolyunsaturatedFat", "Fats"), ("TransFat", "Fats"), ("Phytosterols", "Fats"),

    # Subclass EssentialAminoAcid
    ("Histidine","EssentialAminoAcid"),("Isoleucine","EssentialAminoAcid"),("Leucine","EssentialAminoAcid"),("Lysine","EssentialAminoAcid"),("Methionine","EssentialAminoAcid"),("Phenylalanine","EssentialAminoAcid"),("Threonine","EssentialAminoAcid"),("Tryptophan","EssentialAminoAcid"),("Valine","EssentialAminoAcid"),

    # Subclass ConditionallyEssentialAminoAcid
    ("Arginine","ConditionallyEssentialAminoAcid"),("Cystine","ConditionallyEssentialAminoAcid"),("Glycine","ConditionallyEssentialAminoAcid"),("Proline","ConditionallyEssentialAminoAcid"),("Tyrosine","ConditionallyEssentialAminoAcid"),

    # Subclass NonEssentialAminoAcid
    ("Alanine","NonEssentialAminoAcid"),("Asparticacid","NonEssentialAminoAcid"),("Betaine","NonEssentialAminoAcid"),("Glutamicacid","NonEssentialAminoAcid"),("Hydroxyproline","NonEssentialAminoAcid"),("Serine","NonEssentialAminoAcid"),

    # Subclass Amino Acids
    ("EssentialAminoAcid", "AminoAcids"),
    ("ConditionallyEssentialAminoAcid", "AminoAcids"),
    ("NonEssentialAminoAcid", "AminoAcids"),

    # General classes
    ("Macronutrients", "Food"),
    ("Minerals", "Food"),
    ("Vitamins", "Food"),
    ("OtherComponent", "Food"),
    ("Carbohydrates", "Food"),
    ("Fats", "Food"),
    ("AminoAcids", "Food"),
]

# Create and define each class
all_classes = set()
for subclass, superclass in subclass_relationships:
    subclass_uri = getattr(ex, subclass)
    superclass_uri = getattr(ex, superclass)

    # Declare both subclass and superclass as OWL classes
    if subclass not in all_classes:
        g.add((subclass_uri, RDF.type, OWL.Class))
        all_classes.add(subclass)
        g.add((ex.Weight, RDFS.subClassOf, subclass_uri))
        g.add((ex.DailyValue, RDFS.subClassOf, subclass_uri))
        g.add((ex.unite, RDFS.subClassOf, subclass_uri))

    if superclass not in all_classes:
        g.add((superclass_uri, RDF.type, OWL.Class))
        all_classes.add(superclass)

    # Establish hierarchy
    g.add((subclass_uri, RDFS.subClassOf, superclass_uri))

# Define data property for food name
g.add((ex.hasName, RDF.type, OWL.DatatypeProperty))
g.add((ex.hasName, RDFS.range, xsd.string))

# Define data property for food weight (e.g., in grams)
g.add((ex.hasWeight, RDF.type, OWL.DatatypeProperty))
g.add((ex.hasWeight, RDFS.range, xsd.float))

# Define data property for food weight (e.g., in grams)
g.add((ex.hasUnite, RDF.type, OWL.DatatypeProperty))
g.add((ex.hasUnite, RDFS.range, xsd.string))

g.add((ex.hasDailyValue, RDF.type, OWL.DatatypeProperty))
g.add((ex.hasDailyValue, RDFS.range, xsd.float))
# Out:
# <Graph identifier=Nf24f24f26e024d2eb114a501680a1088 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Defining vitamins, amino acids, minerals, etc from existing ontologies

# %% [markdown]
# Macronutrients

# %%
calories = URIRef(OBO["NCIT_C15646"])
fats = URIRef(OBO["NCIT_C15224"])
protein = URIRef(OBO["NCIT_C15920"])
carbohydrates = URIRef(OBO["NCIT_C15223"])
sugars = URIRef(OBO["NCIT_C71939"])
fiber = URIRef(OBO["NCIT_C15225"])
cholesterol = URIRef(OBO["NCIT_C15205"])
saturated_fats = URIRef(OBO["NCIT_C68421"])
net_carbs = URIRef(OBO["NCIT_C68492"])
trans_fatty_acids = URIRef(OBO["NCIT_C68440"])

# %%
g.add((ex.Calories, OWL.equivalentClass, calories))
g.add((ex.Fat, OWL.equivalentClass, fats))
g.add((ex.Protein, OWL.equivalentClass, protein))
g.add((ex.Carbohydrate, OWL.equivalentClass, carbohydrates))
g.add((ex.Sugars, OWL.equivalentClass, sugars))
g.add((ex.Fiber, OWL.equivalentClass, fiber))
g.add((ex.Cholesterol, OWL.equivalentClass, cholesterol))
g.add((ex.SaturatedFats, OWL.equivalentClass, saturated_fats))
g.add((ex.NetCarbs, OWL.equivalentClass, net_carbs))
g.add((ex.TransFattyAcids, OWL.equivalentClass, trans_fatty_acids))
# Out:
# <Graph identifier=Nf24f24f26e024d2eb114a501680a1088 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Minerals

# %%
# calcium = URIRef(OBO["NCIT_C68241"])
# iron = URIRef(OBO["NCIT_C68256"])
# potassium = URIRef(OBO["NCIT_C68279"])
# magnesium = URIRef(OBO["NCIT_C68264"])
# phosphorus = URIRef(OBO["NCIT_C68277"])
# sodium = URIRef(OBO["NCIT_C68287"])
# zinc = URIRef(OBO["NCIT_C68295"])
# copper = URIRef(OBO["NCIT_C68249"])
# manganese = URIRef(OBO["NCIT_C68266"])
# selenium = URIRef(OBO["NCIT_C68281"])
# fluoride = URIRef(OBO["NCIT_C68252"])
# molybdenum = URIRef(OBO["NCIT_C68272"])
# iodine = URIRef(OBO["NCIT_C68254"])
# chloride = URIRef(OBO["NCIT_C68243"])
# chromium = URIRef(OBO["NCIT_C68245"])

# %%
# g.add((ex.Calcium, OWL.equivalentClass, calcium))
# g.add((ex.Iron, OWL.equivalentClass, iron))
# g.add((ex.Potassium, OWL.equivalentClass, potassium))
# g.add((ex.Magnesium, OWL.equivalentClass, magnesium))
# g.add((ex.Phosphorus, OWL.equivalentClass, phosphorus))
# g.add((ex.Sodium, OWL.equivalentClass, sodium))
# g.add((ex.Zinc, OWL.equivalentClass, zinc))
# g.add((ex.Copper, OWL.equivalentClass, copper))
# g.add((ex.Manganese, OWL.equivalentClass, manganese))
# g.add((ex.Selenium, OWL.equivalentClass, selenium))
# g.add((ex.Fluoride, OWL.equivalentClass, fluoride))
# g.add((ex.Molybdenum, OWL.equivalentClass, molybdenum))
# g.add((ex.Iodine, OWL.equivalentClass, iodine))
# g.add((ex.Chloride, OWL.equivalentClass, chloride))
# g.add((ex.Chromium, OWL.equivalentClass, chromium))

# %% [markdown]
# Vitamins

# %%
# vitaminA = URIRef(OBO["NCIT_C938"])
# vitaminC = URIRef(OBO["NCIT_C68507"])
# thiaminB1 = URIRef(OBO["NCIT_C874"])
# riboflavinB2 = URIRef(OBO["NCIT_C808"])
# niacinB3 = URIRef(OBO["NCIT_C689"])
# vitaminB5 = URIRef(OBO["NCIT_C47783"])
# vitaminB6 = URIRef(OBO["NCIT_C1334"])
# biotin = URIRef(OBO["NCIT_C309"])
# folate = URIRef(OBO["NCIT_C1444"])
# folicacid = URIRef(OBO["NCIT_C510"])
# foodfolate = URIRef(OBO["NCIT_C68512"])
# folateDFE = URIRef(OBO["NCIT_C68513"])
# choline = URIRef(OBO["NCIT_C61674"])
# vitaminB12 = URIRef(OBO["NCIT_C173805"])
# retinol = URIRef(OBO["NCIT_C68302"])
# carotenebeta = URIRef(OBO["NCIT_C1016"])
# carotenealpha = URIRef(OBO["NCIT_C68304"])
# cryptoxanthinbeta = URIRef(OBO["NCIT_C68306"])
# #vitaminAIU = URIRef(OBO[""])
# lycopene = URIRef(OBO["NCIT_C2226"])
# lutzeaxanthin = URIRef(OBO["NCIT_C68310"])
# vitaminE = URIRef(OBO["NCIT_C942"])
# vitaminD = URIRef(OBO["NCIT_C941"])
# vitaminD2 = URIRef(OBO["NCIT_C29029"])
# vitaminD3 = URIRef(OBO["NCIT_C48194"])
# #vitaminDIU = URIRef(OBO[""])
# vitaminK = URIRef(OBO["NCIT_C943"])
# vitaminK1 = URIRef(OBO["NCIT_C29365"])
# menaquinone4 = URIRef(OBO["NCIT_C68319"])

# %%
# g.add((ex.VitaminA, OWL.equivalentClass, vitaminA))
# g.add((ex.VitaminC, OWL.equivalentClass, vitaminC))
# g.add((ex.ThiaminB1, OWL.equivalentClass, thiaminB1))
# g.add((ex.RiboflavinB2, OWL.equivalentClass, riboflavinB2))
# g.add((ex.NiacinB3, OWL.equivalentClass, niacinB3))
# g.add((ex.VitaminB5, OWL.equivalentClass, vitaminB5))
# g.add((ex.VitaminB6, OWL.equivalentClass, vitaminB6))
# g.add((ex.Biotin, OWL.equivalentClass, biotin))
# g.add((ex.Folate, OWL.equivalentClass, folate))
# g.add((ex.Folicacid, OWL.equivalentClass, folicacid))
# g.add((ex.Foodfolate, OWL.equivalentClass, foodfolate))
# g.add((ex.FolateDFE, OWL.equivalentClass, folateDFE))
# g.add((ex.Choline, OWL.equivalentClass, choline))
# g.add((ex.VitaminB12, OWL.equivalentClass, vitaminB12))
# g.add((ex.Retinol, OWL.equivalentClass, retinol))
# g.add((ex.Carotenebeta, OWL.equivalentClass, carotenebeta))
# g.add((ex.Carotenealpha, OWL.equivalentClass, carotenealpha))
# g.add((ex.Cryptoxanthinbeta, OWL.equivalentClass, cryptoxanthinbeta))
# #g.add((ex.VitaminAIU, OWL.equivalentClass, vitaminAIU))
# g.add((ex.Lycopene, OWL.equivalentClass, lycopene))
# g.add((ex.LutZeaxanthin, OWL.equivalentClass, lutzeaxanthin))
# g.add((ex.VitaminE, OWL.equivalentClass, vitaminE))
# g.add((ex.VitaminD, OWL.equivalentClass, vitaminD))
# g.add((ex.VitaminD2, OWL.equivalentClass, vitaminD2))
# g.add((ex.VitaminD3, OWL.equivalentClass, vitaminD3))
# #g.add((ex.VitaminDIU, OWL.equivalentClass, vitaminDIU))
# g.add((ex.VitaminK, OWL.equivalentClass, vitaminK))
# g.add((ex.VitaminK1, OWL.equivalentClass, vitaminK1))
# g.add((ex.Menaquinone4, OWL.equivalentClass, menaquinone4))

# %% [markdown]
# Essential amino acids

# %%
histidine = URIRef(OBO["OMIT_0007798"])
isoleucine = URIRef(OBO["OMIT_0008647"])
leucine = URIRef(OBO["OMIT_0009021"])
lysine = URIRef(OBO["OMIT_0009315"])
methionine = URIRef(OBO["OMIT_0009774"])
phenylalanine = URIRef(OBO["OMIT_0011637"])
threonine = URIRef(OBO["OMIT_0014757"])
tryptophan = URIRef(OBO["OMIT_0015201"])
valine = URIRef(OBO["OMIT_0015467"])

# %%
g.add((ex.Histidine, OWL.equivalentClass, histidine))
g.add((ex.Isoleucine, OWL.equivalentClass, isoleucine))
g.add((ex.Leucine, OWL.equivalentClass, leucine))
g.add((ex.Lysine, OWL.equivalentClass, lysine))
g.add((ex.Methionine, OWL.equivalentClass, methionine))
g.add((ex.Phenylalanine, OWL.equivalentClass, phenylalanine))
g.add((ex.Threonine, OWL.equivalentClass, threonine))
g.add((ex.Tryptophan, OWL.equivalentClass, tryptophan))
g.add((ex.Valine, OWL.equivalentClass, valine))
# Out:
# <Graph identifier=Nf24f24f26e024d2eb114a501680a1088 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Generate graph

# %%
# Serialize and save the ontology
g.serialize("C:/Users/laure/OneDrive/Documents/GitHub/KG_project/nutrition_structure_short.ttl", format="turtle")
# Out:
# <Graph identifier=Nf24f24f26e024d2eb114a501680a1088 (<class 'rdflib.graph.Graph'>)>

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a NetworkX directed graph
G = nx.DiGraph()

# Add nodes and edges from RDF graph
for subj, pred, obj in g:
    G.add_node(str(subj), label=str(subj).split("/")[-1])  # Use last part of URI as label
    G.add_node(str(obj), label=str(obj).split("/")[-1])
    G.add_edge(str(subj), str(obj), label=str(pred).split("#")[-1])  # Use last part of predicate as edge label

# Draw the graph
nx.write_gexf(G, "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/structure_short.gexf")

# %% [markdown]
# # Add items to the graph

# %%
def separate_values_and_units(text):
    if(text == '' or text == '--%'):
        return [(0.0,'%')]
    elif(text == '--' or text == '--mcg' or text == '--mg' or text == '--g' or text == '--IU'):
        return [(0.0,'g')]
    pattern = r"(\d*\.?\d*)([a-zA-Z%]*)"
    matches = re.findall(pattern, text)
    return [(value.strip(), unit.strip()) for value, unit in matches if value or unit]

# %%
Match_data_with_csv = [
    # Subclass Macronutrients
    ("Weight","Macronutrients"),("Calories","Macronutrients"),("Fat","Macronutrients"),("Protein","Macronutrients"),("Carbohydrate","Macronutrients"),("Sugars","Macronutrients"),("Fiber","Macronutrients"),("Cholesterol","Macronutrients"),("SaturatedFats","Macronutrients"),("NetCarbs","Macronutrients"),("TransFattyAcids","Macronutrients"),

    # Subclass Minerals
    ("Calcium", "Minerals"), ("Iron", "Minerals"), ("Potassium", "Minerals"),
    ("Magnesium", "Minerals"), ("Phosphorus", "Minerals"), ("Sodium", "Minerals"),
    ("Zinc", "Minerals"), ("Copper", "Minerals"), ("Manganese", "Minerals"),
    ("Selenium", "Minerals"), ("Fluoride", "Minerals"), ("Molybdenum", "Minerals"),
    ("Iodine", "Minerals"), ("Chloride", "Minerals"), ("Chromium", "Minerals"),

    # Subclass Vitamins
    ("VitaminA", "Vitamins"), ("VitaminC", "Vitamins"), ("ThiaminB1", "Vitamins"),
    ("RiboflavinB2", "Vitamins"), ("NiacinB3", "Vitamins"), ("VitaminB5", "Vitamins"),
    ("VitaminB6", "Vitamins"), ("Biotin", "Vitamins"), ("Folate", "Vitamins"),
    ("Folicacid", "Vitamins"), ("Foodfolate", "Vitamins"), ("FolateDFE", "Vitamins"),
    ("Choline", "Vitamins"), ("VitaminB12", "Vitamins"), ("Retinol", "Vitamins"),
    ("Carotenebeta", "Vitamins"), ("Carotenealpha", "Vitamins"),
    ("Cryptoxanthinbeta", "Vitamins"), ("VitaminAIU", "Vitamins"),
    ("Lycopene", "Vitamins"), ("LutZeaxanthin", "Vitamins"), ("VitaminE", "Vitamins"),
    ("VitaminD", "Vitamins"), ("VitaminD2", "Vitamins"), ("VitaminD3", "Vitamins"),
    ("VitaminDIU", "Vitamins"), ("VitaminK", "Vitamins"), ("VitaminK1", "Vitamins"),
    ("Menaquinone4", "Vitamins"),

    # Subclass Others
    ("Water", "OtherComponent"), ("Ash", "OtherComponent"), ("Alcohol", "OtherComponent"),
    ("Caffeine", "OtherComponent"), ("Theobromine", "OtherComponent"), ("PRALscore", "OtherComponent"),

    # Subclass Carbohydrates
    ("SolubleFiber", "Carbohydrates"), ("InsolubleFiber", "Carbohydrates"), ("AddedSugar", "Carbohydrates"),
    ("Sucrose", "Carbohydrates"), ("Glucose", "Carbohydrates"), ("Fructose", "Carbohydrates"),
    ("Lactose", "Carbohydrates"), ("Maltose", "Carbohydrates"), ("Galactose", "Carbohydrates"),
    ("Strarch", "Carbohydrates"), ("otherSugar", "Carbohydrates"), ("SugarAlcohols", "Carbohydrates"),

    # Subclass Fats
    ("TotalMonounsaturated","Fats"),("TotalPolyunsaturated","Fats"),("Omega3s","Fats"),("Omega6s","Fats"),("Omega3toOmega6Ratio","Fats"),("Omega6toOmega3Ratio","Fats"),

    # Subclass Omega3Fat
    ("alphaLinolenicAcid", "Omega3Fat"), ("EicosapentaenoicAcid", "Omega3Fat"), ("DocosapentaenoicAcid", "Omega3Fat"), ("DocosahexaenoicAcid", "Omega3Fat"), ("n3EicosatrienoicAcid", "Omega3Fat"),

    # Subclass Omega6Fat
    ("alphaLinolenicAcid", "Omega6Fat"),("gammaLinolenicAcid", "Omega6Fat"),("ciscisn6EicosadienoicAcid", "Omega6Fat"),("DihomogammalinolenicAcid", "Omega6Fat"),("ArachidonicAcid", "Omega6Fat"),("Butyric", "Omega6Fat"),("Caproic", "Omega6Fat"),("CaprylicAcid", "Omega6Fat"), ("CapricAcid", "Omega6Fat"), ("LauricAcid", "Omega6Fat"), ("TridecanoicAcid", "Omega6Fat"), ("MyristicAcid", "Omega6Fat"),("PentadecanoicAcid", "Omega6Fat"),("PalmiticAcid", "Omega6Fat"),("MargaricAcid", "Omega6Fat"),("StearicAcid", "Omega6Fat"),("ArachidicAcid", "Omega6Fat"),("BehenicAcid", "Omega6Fat"),("LignocericAcid", "Omega6Fat"),

    # Subclass Monounsaturated
    ("MyristoleicAcid", "MonounsaturatedFat"), ("PentadecenoicAcid", "MonounsaturatedFat"), ("PalmitoleicAcid", "MonounsaturatedFat"),
    ("cisPalmitoleicAcid", "MonounsaturatedFat"), ("HeptadecenoicAcid", "MonounsaturatedFat"), ("OleicAcid", "MonounsaturatedFat"),
    ("cisOleicAcid", "MonounsaturatedFat"), ("cisVaccenicAcid", "MonounsaturatedFat"), ("GadoleicAcid", "MonounsaturatedFat"), ("DocosenoicAcid", "MonounsaturatedFat"), ("cisDocosenoicAcid", "MonounsaturatedFat"), ("cisTetracosenoicAcid", "MonounsaturatedFat"),

    # Subclass Polyunsaturated
    ("OctadecadienoicAcid","PolyunsaturatedFat"),("ConjugatedLinoleicAcid","PolyunsaturatedFat"),("iOctadecadienoicAcid","PolyunsaturatedFat"),("undifferentiatedOctadecatrienoic","PolyunsaturatedFat"),("OctadecatrienoicAcid","PolyunsaturatedFat"),("ParinaricAcid","PolyunsaturatedFat"),("EicosatrienoicAcid","PolyunsaturatedFat"),("EicosatetraenoicAcid","PolyunsaturatedFat"),("HeneicosapentaenoicAcid","PolyunsaturatedFat"),("22:4","PolyunsaturatedFat"),

    # Subclass TransFat
    ("TransPolyenoicFats","TransFat"),("TransMonoenoicFats","TransFat"),("transPalmitoleicAcid","TransFat"),("transOleicAcid","TransFat"),("transDocosenoicAcid","TransFat"),("transOctadecadienoicAcid","TransFat"),("transtransOctadecadienoicAcid","TransFat"),

    # Subclass Phytosterols
    ("TotalPhytosterols","Phytosterols"),("Stigmasterol","Phytosterols"),("Campesterol","Phytosterols"),("Betasitosterol","Phytosterols"),

    # Subclass EssentialAminoAcid
    ("Histidine","EssentialAminoAcid"),("Isoleucine","EssentialAminoAcid"),("Leucine","EssentialAminoAcid"),("Lysine","EssentialAminoAcid"),("Methionine","EssentialAminoAcid"),("Phenylalanine","EssentialAminoAcid"),("Threonine","EssentialAminoAcid"),("Tryptophan","EssentialAminoAcid"),("Valine","EssentialAminoAcid"),

    # Subclass ConditionallyEssentialAminoAcid
    ("Arginine","ConditionallyEssentialAminoAcid"),("Cystine","ConditionallyEssentialAminoAcid"),("Glycine","ConditionallyEssentialAminoAcid"),("Proline","ConditionallyEssentialAminoAcid"),("Tyrosine","ConditionallyEssentialAminoAcid"),

    # Subclass NonEssentialAminoAcid
    ("Alanine","NonEssentialAminoAcid"),("Asparticacid","NonEssentialAminoAcid"),("Betaine","NonEssentialAminoAcid"),("Glutamicacid","NonEssentialAminoAcid"),("Hydroxyproline","NonEssentialAminoAcid"),("Serine","NonEssentialAminoAcid"),
]

# %%
from hashlib import sha256
from rdflib import URIRef

def generate_unique_iri(base_uri, food_uri, nutrient_name, measure):
    unique_id = sha256(f"{food_uri}_{nutrient_name}_{measure}".encode()).hexdigest()[:10]
    return URIRef(f"{base_uri}{nutrient_name.replace(' ', '_')}_{unique_id}")

# %%
def separate_values_and_units_boolean(text):
    if(text == '' or text == '--%'):
        return True
    elif(text == '--' or text == '--mcg' or text == '--mg' or text == '--g' or text == '--IU'):
        return True

    return False

# %%
import csv
import re
import os
from rdflib import Graph, URIRef, Literal, XSD, RDF

folder_path = 'C:/Users/laure/OneDrive/Documents/GitHub/KG_project/Nutrition/'
count = 0
correct_count = 0

# Define required nutrients
REQUIRED_NUTRIENTS = {
    "Weight", "Calories (kcal)", "Protein", "Histidine", "Isoleucine", "Leucine",
    "Lysine", "Methionine", "Phenylalanine", "Threonine", "Tryptophan", "Valine"
}

# Iterate over all files in the specified folder
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        url = os.path.join(folder_path, filename)
        c = 0

        # Extract food name from filename
        match = re.search(r'([^/]+)(?=_\d+\.csv$)', filename)
        if match:
            result = match.group(1)

        # Read the CSV file
        with open(url, mode='r') as file:
            csvFile = csv.reader(file)
            next(csvFile)  # Skip header

            # Track nutrients and triples
            nutrient_tracker = set()
            nutrient_triples = []  # Temporary storage for triples

            food_uri = URIRef(ex[result])

            # Iterate over CSV rows
            for lines in csvFile:
                category_name = lines[0]
                if category_name not in {"Macronutrients", "Essential Amino Acids"}:
                    continue

                value_name = lines[1]
                if not(separate_values_and_units_boolean(lines[2])):
                    measureUnity = separate_values_and_units(lines[2])
                    measure = float(measureUnity[0][0])
                    measure_unit = measureUnity[0][1]
                    daily_percentage = float(separate_values_and_units(lines[3])[0][0])

                    if value_name in REQUIRED_NUTRIENTS:
                        nutrient_tracker.add(value_name)

                        feature_uri = ex[Match_data_with_csv[c][0]]
                        nutrient_uri = generate_unique_iri(ex, food_uri, value_name, measure)

                        # Store triples in a list first
                        nutrient_triples.extend([
                            (nutrient_uri, RDF.type, feature_uri),
                            (nutrient_uri, ex.hasWeight, Literal(measure, datatype=XSD.float)),
                            (nutrient_uri, ex.hasUnit, Literal(measure_unit, datatype=XSD.string)),
                            (nutrient_uri, ex.hasDailyValue, Literal(daily_percentage, datatype=XSD.float)),
                            (food_uri, ex.hasNutrient, nutrient_uri)
                        ])

            # Only add if all required nutrients are present
            if REQUIRED_NUTRIENTS.issubset(nutrient_tracker):
                correct_count+=1
                g.add((food_uri, RDF.type, ex.Food))
                g.add((food_uri, ex.hasName, Literal(result, datatype=XSD.string)))

                # Add all stored triples
                for triple in nutrient_triples:
                    g.add(triple)
            else:
                # Remove stored triples if food does not meet the criteria
                for triple in nutrient_triples:
                    g.remove(triple)

    count += 1
    if count % 1000 == 0:
        break

print(correct_count)
# 80806 values in the end
# Out:
# 30

# %% [markdown]
# # Checking the graph nodes and edges

# %%
food_name = "http://example.org/-_Annies_Dressing_Tuscany_Italian"  # Adjust to actual node name
food_name = "http://example.org/-_Annies_Dressing_Tuscany_Italian"

if food_name in G:
    neighbors = list(G.neighbors(food_name))
    print(f"Food Item: {food_name} has relationships with: {neighbors}")
else:
    print("Food not found in graph.")
# Out:
# Food Item: http://example.org/-_Annies_Dressing_Tuscany_Italian has relationships with: ['http://example.org/Leucine_6ce69b8b17', 'http://example.org/Histidine_92f37625a5', '-_Annies_Dressing_Tuscany_Italian', 'http://example.org/Lysine_3caa5fab81', 'http://example.org/Protein_c91116ed2a', 'http://example.org/Phenylalanine_ecd093668f', 'http://example.org/Isoleucine_e8993410f0', 'http://example.org/Threonine_984a59cb3d', 'http://example.org/Valine_946d5dd270', 'http://example.org/Tryptophan_e50cbab6b1', 'http://example.org/Food', 'http://example.org/Calories_(kcal)_838b9ec3f4', 'http://example.org/Methionine_d6f42e16e0']

# %%
food_name = "http://example.org/Rb__Confections_Lc__-_Mint_Nonpareils"

if food_name in g:
    neighbors = list(g.neighbors(food_name))
    print(f"Food Item: {food_name} has relationships with: {neighbors}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 food_name = "http://example.org/Rb__Confections_Lc__-_Mint_Nonpareils"
# ----> 3 if food_name in g:
#       4     neighbors = list(g.neighbors(food_name))
#       5     print(f"Food Item: {food_name} has relationships with: {neighbors}")
#
# File ~\anaconda3\Lib\site-packages\rdflib\graph.py:727, in Graph.__contains__(self, triple)
#     725 def __contains__(self, triple: _TripleSelectorType) -> bool:
#     726     """Support for 'triple in graph' syntax"""
# --> 727     for triple in self.triples(triple):
#     728         return True
#     729     return False
#
# File ~\anaconda3\Lib\site-packages\rdflib\graph.py:633, in Graph.triples(self, triple)
#     624 def triples(
#     625     self,
#     626     triple: _TripleSelectorType,
#     627 ) -> Generator[_TripleOrTriplePathType, None, None]:
#     628     """Generator over the triple store
#     629
#     630     Returns triples that match the given triple pattern. If triple pattern
#     631     does not provide a context, all contexts will be searched.
#     632     """
# --> 633     s, p, o = triple
#     634     if isinstance(p, Path):
#     635         for _s, _o in p.eval(self, s, o):
#
# ValueError: too many values to unpack (expected 3)

# %%
import re

food_name = "http://example.org/-_Annies_Dressing_Tuscany_Italian"  # Adjust to actual node name
search_nutrient = "Leucine"  # User input

if food_name in G:
    neighbors = list(G.neighbors(food_name))

    # Extract only the nutrient name (remove prefix and suffix)
    pattern = r"http://example\.org/([^_]+)_.*"  # Extracts the part between '/' and '_'

    matched_nutrient = [
        n for n in neighbors
        if re.match(pattern, n) and re.match(pattern, n).group(1).lower() == search_nutrient.lower()
    ]

    if matched_nutrient:
        print(f"Food Item: {food_name} has the following '{search_nutrient}' relationships:")
        print(matched_nutrient)

        # Print the neighbors of the matched nutrient
        for nutrient in matched_nutrient:
            if nutrient in G:
                nutrient_neighbors = list(G.neighbors(nutrient))
                print(f"\nNutrient: {nutrient} has relationships with:")
                print(nutrient_neighbors)
            else:
                print(f"\nNo relationships found for {nutrient}.")
    else:
        print(f"No match found for '{search_nutrient}' in {food_name}'s relationships.")
else:
    print("Food not found in graph.")
# Out:
# Food Item: http://example.org/-_Annies_Dressing_Tuscany_Italian has the following 'Leucine' relationships:
# ['http://example.org/Leucine_6ce69b8b17']
#
# Nutrient: http://example.org/Leucine_6ce69b8b17 has relationships with:
# ['mg', '0.0', 'http://example.org/Weight']

# %%
food_name = "http://example.org/Rb__Confections_Lc__-_Mint_Nonpareils"  # Adjust to actual node name

if food_name in G:
    edges = []

    for _, target, edge_data in G.edges(food_name, data=True):  # ✅ Loop only once
        edge_label = edge_data.get("label", "No label")
        edges.append((food_name, edge_label, target))

    # Print the edges
    print(f"Edges connected to {food_name}:")
    for source, label, target in edges:
        print(f"{source} --[{label}]--> {target}")
else:
    print("Food not found in graph.")
# Out:
# Food not found in graph.

# %%
for i in g:
    print(i)
# Out:
# (rdflib.term.URIRef('http://example.org/VitaminB6'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/TotalPolyunsaturated'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/MargaricAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Lycopene'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/transPalmitoleicAcid'))
# (rdflib.term.URIRef('http://example.org/Threonine'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EssentialAminoAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phosphorus'))
# (rdflib.term.URIRef('http://example.org/transOleicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/22:4'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Potassium'))
# (rdflib.term.URIRef('http://example.org/Carbohydrates'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Folate'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/alphaLinolenicAcid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Sugars'))
# (rdflib.term.URIRef('http://example.org/Sucrose'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carbohydrates'))
# (rdflib.term.URIRef('http://example.org/VitaminB5'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/DihomogammalinolenicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/Cryptoxanthinbeta'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/cisTetracosenoicAcid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/transPalmitoleicAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminD2'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/22:4'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Betaine'))
# (rdflib.term.URIRef('http://example.org/Stigmasterol'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Sucrose'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/MyristicAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EicosapentaenoicAcid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Betaine'))
# (rdflib.term.URIRef('http://example.org/Menaquinone4'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Selenium'))
# (rdflib.term.URIRef('http://example.org/Cholesterol'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C15205'))
# (rdflib.term.URIRef('http://example.org/Campesterol'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/MyristicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/EicosapentaenoicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega3Fat'))
# (rdflib.term.URIRef('http://example.org/Valine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Protein_c91116ed2a'), rdflib.term.URIRef('http://example.org/hasUnit'), rdflib.term.Literal('g', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/VitaminD'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Choline'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carotenebeta'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminAIU'))
# (rdflib.term.URIRef('http://example.org/Foodfolate'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Threonine_984a59cb3d'), rdflib.term.URIRef('http://example.org/hasUnit'), rdflib.term.Literal('mg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Selenium'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/BehenicAcid'))
# (rdflib.term.URIRef('http://example.org/NonEssentialAminoAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TotalPhytosterols'))
# (rdflib.term.URIRef('http://example.org/Proline'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/PalmiticAcid'))
# (rdflib.term.URIRef('http://example.org/Isoleucine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Chromium'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Minerals'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Weight'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Choline'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TotalMonounsaturated'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Copper'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Lycopene'))
# (rdflib.term.URIRef('http://example.org/VitaminDIU'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Sodium'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminAIU'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Fluoride'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminD3'))
# (rdflib.term.URIRef('http://example.org/Glutamicacid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminC'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glucose'))
# (rdflib.term.URIRef('http://example.org/Asparticacid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/NonEssentialAminoAcid'))
# (rdflib.term.URIRef('http://example.org/SaturatedFats'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C68421'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/iOctadecadienoicAcid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Lycopene'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/gammaLinolenicAcid'))
# (rdflib.term.URIRef('http://example.org/cisVaccenicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/MonounsaturatedFat'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/transDocosenoicAcid'))
# (rdflib.term.URIRef('http://example.org/hasWeight'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminD2'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Folate'))
# (rdflib.term.URIRef('http://example.org/VitaminE'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminD3'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Tyrosine'))
# (rdflib.term.URIRef('http://example.org/Omega3toOmega6Ratio'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Fats'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carotenealpha'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Calories'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/transDocosenoicAcid'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Sucrose'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminD2'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Folate'))
# (rdflib.term.URIRef('http://example.org/AddedSugar'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carbohydrates'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Tyrosine'))
# (rdflib.term.URIRef('http://example.org/MyristoleicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Sodium'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Minerals'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Calories'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Stigmasterol'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Sucrose'))
# (rdflib.term.URIRef('http://example.org/PolyunsaturatedFat'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Threonine_984a59cb3d'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/Weight'))
# (rdflib.term.URIRef('http://example.org/Betaine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EicosapentaenoicAcid'))
# (rdflib.term.URIRef('http://example.org/TotalPhytosterols'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phytosterols'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Iodine'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Lysine'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Cystine'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminE'))
# (rdflib.term.URIRef('http://example.org/FolateDFE'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/CapricAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/Tryptophan'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EssentialAminoAcid'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TotalPhytosterols'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/SaturatedFats'))
# (rdflib.term.URIRef('http://example.org/Vitamins'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Food'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EicosatrienoicAcid'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TotalMonounsaturated'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carotenebeta'))
# (rdflib.term.URIRef('http://example.org/SolubleFiber'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6s'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Tryptophan'))
# (rdflib.term.URIRef('http://example.org/Protein_c91116ed2a'), rdflib.term.URIRef('http://example.org/hasWeight'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/HeptadecenoicAcid'))
# (rdflib.term.URIRef('http://example.org/CapricAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TotalPhytosterols'))
# (rdflib.term.URIRef('http://example.org/Lysine'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/OMIT_0009315'))
# (rdflib.term.URIRef('http://example.org/Isoleucine_e8993410f0'), rdflib.term.URIRef('http://example.org/hasUnit'), rdflib.term.Literal('mg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/SaturatedFats'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EicosatrienoicAcid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TotalMonounsaturated'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TransPolyenoicFats'))
# (rdflib.term.URIRef('http://example.org/Sugars'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Macronutrients'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6s'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Proline'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/HeptadecenoicAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Caproic'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Foodfolate'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carotenealpha'))
# (rdflib.term.URIRef('http://example.org/Macronutrients'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Food'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/transtransOctadecadienoicAcid'))
# (rdflib.term.URIRef('http://example.org/Carbohydrate'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Macronutrients'))
# (rdflib.term.URIRef('http://example.org/hasUnite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# (rdflib.term.URIRef('http://example.org/Calories'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Macronutrients'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/HeneicosapentaenoicAcid'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Serine'))
# (rdflib.term.URIRef('http://example.org/OtherComponent'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Food'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carotenealpha'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Calcium'))
# (rdflib.term.URIRef('http://example.org/n3EicosatrienoicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega3Fat'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/OleicAcid'))
# (rdflib.term.URIRef('http://example.org/VitaminD3'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/Leucine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Fiber'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Macronutrients'))
# (rdflib.term.URIRef('http://example.org/Butyric'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/Histidine_92f37625a5'), rdflib.term.URIRef('http://example.org/hasWeight'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/Minerals'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Food'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/HeneicosapentaenoicAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/DihomogammalinolenicAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Chloride'))
# (rdflib.term.URIRef('http://example.org/Lactose'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carbohydrates'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Serine'))
# (rdflib.term.URIRef('http://example.org/Protein'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Macronutrients'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminE'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Menaquinone4'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Zinc'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Folicacid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Lysine'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Tryptophan'))
# (rdflib.term.URIRef('http://example.org/Tryptophan_e50cbab6b1'), rdflib.term.URIRef('http://example.org/hasWeight'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminE'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Chromium'))
# (rdflib.term.URIRef('http://example.org/TridecanoicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega3toOmega6Ratio'))
# (rdflib.term.URIRef('http://example.org/TotalMonounsaturated'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Strarch'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carbohydrates'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Methionine'))
# (rdflib.term.URIRef('http://example.org/Zinc'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Minerals'))
# (rdflib.term.URIRef('http://example.org/TotalMonounsaturated'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Fats'))
# (rdflib.term.URIRef('http://example.org/gammaLinolenicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glycine'))
# (rdflib.term.URIRef('http://example.org/Strarch'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Tryptophan'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Chromium'))
# (rdflib.term.URIRef('http://example.org/ParinaricAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/PolyunsaturatedFat'))
# (rdflib.term.URIRef('http://example.org/Lysine_3caa5fab81'), rdflib.term.URIRef('http://example.org/hasWeight'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/hasUnite'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#DatatypeProperty'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Strarch'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/PentadecanoicAcid'))
# (rdflib.term.URIRef('http://example.org/PalmitoleicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/-_Annies_Dressing_Tuscany_Italian'), rdflib.term.URIRef('http://example.org/hasNutrient'), rdflib.term.URIRef('http://example.org/Leucine_6ce69b8b17'))
# (rdflib.term.URIRef('http://example.org/HeptadecenoicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/MonounsaturatedFat'))
# (rdflib.term.URIRef('http://example.org/ArachidonicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Foodfolate'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/OleicAcid'))
# (rdflib.term.URIRef('http://example.org/NetCarbs'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Iodine'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Minerals'))
# (rdflib.term.URIRef('http://example.org/Copper'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Minerals'))
# (rdflib.term.URIRef('http://example.org/Maltose'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminD'))
# (rdflib.term.URIRef('http://example.org/Ash'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/OtherComponent'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Strarch'))
# (rdflib.term.URIRef('http://example.org/LignocericAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Glucose'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/iOctadecadienoicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/OctadecatrienoicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/-_Annies_Dressing_Tuscany_Italian'), rdflib.term.URIRef('http://example.org/hasNutrient'), rdflib.term.URIRef('http://example.org/Histidine_92f37625a5'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Biotin'))
# (rdflib.term.URIRef('http://example.org/-_Annies_Dressing_Tuscany_Italian'), rdflib.term.URIRef('http://example.org/hasName'), rdflib.term.Literal('-_Annies_Dressing_Tuscany_Italian', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/Caproic'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/Lycopene'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/OleicAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phenylalanine'))
# (rdflib.term.URIRef('http://example.org/Chromium'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminD'))
# (rdflib.term.URIRef('http://example.org/DocosapentaenoicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/NiacinB3'))
# (rdflib.term.URIRef('http://example.org/Tryptophan_e50cbab6b1'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/Weight'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carbohydrate'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/otherSugar'))
# (rdflib.term.URIRef('http://example.org/CaprylicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/22:4'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/PolyunsaturatedFat'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glutamicacid'))
# (rdflib.term.URIRef('http://example.org/Sodium'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/VitaminD2'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/Cryptoxanthinbeta'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/OctadecatrienoicAcid'))
# (rdflib.term.URIRef('http://example.org/Omega3Fat'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/otherSugar'))
# (rdflib.term.URIRef('http://example.org/transOleicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TransFat'))
# (rdflib.term.URIRef('http://example.org/Lysine_3caa5fab81'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/Weight'))
# (rdflib.term.URIRef('http://example.org/Omega3Fat'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Fats'))
# (rdflib.term.URIRef('http://example.org/MargaricAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/DocosenoicAcid'))
# (rdflib.term.URIRef('http://example.org/transtransOctadecadienoicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/RiboflavinB2'))
# (rdflib.term.URIRef('http://example.org/RiboflavinB2'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/Leucine_6ce69b8b17'), rdflib.term.URIRef('http://example.org/hasUnit'), rdflib.term.Literal('mg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glycine'))
# (rdflib.term.URIRef('http://example.org/Fluoride'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Minerals'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/transPalmitoleicAcid'))
# (rdflib.term.URIRef('http://example.org/Histidine_92f37625a5'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/Weight'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/RiboflavinB2'))
# (rdflib.term.URIRef('http://example.org/Caffeine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/22:4'))
# (rdflib.term.URIRef('http://example.org/VitaminA'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/VitaminC'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/PentadecanoicAcid'))
# (rdflib.term.URIRef('http://example.org/ConditionallyEssentialAminoAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/AminoAcids'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/cisTetracosenoicAcid'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/ArachidonicAcid'))
# (rdflib.term.URIRef('http://example.org/BehenicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DocosahexaenoicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phenylalanine'))
# (rdflib.term.URIRef('http://example.org/TransFat'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Threonine'))
# (rdflib.term.URIRef('http://example.org/MyristicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/ArachidonicAcid'))
# (rdflib.term.URIRef('http://example.org/Serine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Fats'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Food'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phenylalanine'))
# (rdflib.term.URIRef('http://example.org/StearicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Omega6Fat'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Campesterol'))
# (rdflib.term.URIRef('http://example.org/VitaminK1'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Phenylalanine_ecd093668f'), rdflib.term.URIRef('http://example.org/hasUnit'), rdflib.term.Literal('mg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Threonine'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Retinol'))
# (rdflib.term.URIRef('http://example.org/TransPolyenoicFats'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TransFat'))
# (rdflib.term.URIRef('http://example.org/CaprylicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Methionine_d6f42e16e0'), rdflib.term.URIRef('http://example.org/hasUnit'), rdflib.term.Literal('mg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/Iodine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Theobromine'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Cholesterol'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/PalmitoleicAcid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Campesterol'))
# (rdflib.term.URIRef('http://example.org/Caffeine'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/OtherComponent'))
# ...
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminK'))
# (rdflib.term.URIRef('http://example.org/EssentialAminoAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/AminoAcids'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/DihomogammalinolenicAcid'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Chloride'))
# (rdflib.term.URIRef('http://example.org/Leucine_6ce69b8b17'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/Weight'))
# (rdflib.term.URIRef('http://example.org/SaturatedFats'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Macronutrients'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Folicacid'))
# (rdflib.term.URIRef('http://example.org/Protein'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C15920'))
# (rdflib.term.URIRef('http://example.org/Carbohydrate'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C15223'))
# (rdflib.term.URIRef('http://example.org/Stigmasterol'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phytosterols'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Menaquinone4'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TotalPolyunsaturated'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EicosatetraenoicAcid'))
# (rdflib.term.URIRef('http://example.org/Phenylalanine_ecd093668f'), rdflib.term.URIRef('http://example.org/hasWeight'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/VitaminB12'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/Omega6Fat'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Fats'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Methionine'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glycine'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminB6'))
# (rdflib.term.URIRef('http://example.org/Methionine_d6f42e16e0'), rdflib.term.URIRef('http://example.org/hasWeight'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/AminoAcids'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Folicacid'))
# (rdflib.term.URIRef('http://example.org/TridecanoicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/TransPolyenoicFats'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Methionine'))
# (rdflib.term.URIRef('http://example.org/Campesterol'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phytosterols'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Potassium'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/PentadecanoicAcid'))
# (rdflib.term.URIRef('http://example.org/Calcium'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Sugars'))
# (rdflib.term.URIRef('http://example.org/Tyrosine'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Tryptophan'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/OMIT_0015201'))
# (rdflib.term.URIRef('http://example.org/Phenylalanine'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EssentialAminoAcid'))
# (rdflib.term.URIRef('http://example.org/SugarAlcohols'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminB12'))
# (rdflib.term.URIRef('http://example.org/ArachidonicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Lysine_3caa5fab81'), rdflib.term.URIRef('http://example.org/hasDailyValue'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/VitaminDIU'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/LutZeaxanthin'))
# (rdflib.term.URIRef('http://example.org/hasDailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'), rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Alanine'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Galactose'))
# (rdflib.term.URIRef('http://example.org/Betasitosterol'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Phytosterols'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminK1'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Betaine'))
# (rdflib.term.URIRef('http://example.org/LutZeaxanthin'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminB12'))
# (rdflib.term.URIRef('http://example.org/Valine_946d5dd270'), rdflib.term.URIRef('http://example.org/hasUnit'), rdflib.term.Literal('mg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')))
# (rdflib.term.URIRef('http://example.org/Fat'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Macronutrients'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/NiacinB3'))
# (rdflib.term.URIRef('http://example.org/Fats'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Caproic'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Alanine'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Galactose'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carbohydrate'))
# (rdflib.term.URIRef('http://example.org/Histidine_92f37625a5'), rdflib.term.URIRef('http://example.org/hasDailyValue'), rdflib.term.Literal('0.0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#float')))
# (rdflib.term.URIRef('http://example.org/Phenylalanine_ecd093668f'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/Weight'))
# (rdflib.term.URIRef('http://example.org/NiacinB3'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/ThiaminB1'))
# (rdflib.term.URIRef('http://example.org/Folicacid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Vitamins'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/CaprylicAcid'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EicosatetraenoicAcid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/SugarAlcohols'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/NiacinB3'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glutamicacid'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Selenium'))
# (rdflib.term.URIRef('http://example.org/NetCarbs'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#equivalentClass'), rdflib.term.URIRef('http://purl.obolibrary.org/obo/NCIT_C68492'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/OctadecatrienoicAcid'))
# (rdflib.term.URIRef('http://example.org/cisOleicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/MonounsaturatedFat'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Carbohydrate'))
# (rdflib.term.URIRef('http://example.org/TotalPolyunsaturated'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Fats'))
# (rdflib.term.URIRef('http://example.org/n3EicosatrienoicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/cisDocosenoicAcid'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/MonounsaturatedFat'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Choline'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Copper'))
# (rdflib.term.URIRef('http://example.org/StearicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/VitaminAIU'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/EicosatetraenoicAcid'))
# (rdflib.term.URIRef('http://example.org/Food'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Weight'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/DocosenoicAcid'))
# (rdflib.term.URIRef('http://example.org/Tryptophan'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/Omega6Fat'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/DailyValue'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glutamicacid'))
# (rdflib.term.URIRef('http://example.org/cisPalmitoleicAcid'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Glucose'))
# (rdflib.term.URIRef('http://example.org/Omega6s'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/Fats'))
# (rdflib.term.URIRef('http://example.org/unite'), rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'), rdflib.term.URIRef('http://example.org/TransFattyAcids'))

# %% [markdown]
# # Counting the number of duplicated products

# %%
import os
import re
from collections import defaultdict


def process_file_names_with_counter(folder_path, output_file):
    # Dictionary to count occurrences of cleaned names
    name_counter = defaultdict(int)

    # Open the output file
    with open(output_file, "w") as file:
        # Iterate through all files in the folder
        for filename in os.listdir(folder_path):
            # Remove the extension to work only on the name
            name, ext = os.path.splitext(filename)

            # Use regex to match the name without the trailing number
            match = re.match(r"(.*?)[0-9]+$", name)

            if match:
                # Extract the part before the number
                cleaned_name = match.group(1)
            else:
                # If no number at the end, keep the original name
                cleaned_name = name

            # Increment the count for this cleaned name
            name_counter[cleaned_name] += 1

        # Sort the names by their counts in descending order
        sorted_names = sorted(name_counter.items(), key=lambda item: item[1], reverse=True)

        # Write the sorted count of similar cleaned names to the file
        file.write("\nCounts of similar cleaned names (sorted):\n")
        for name, count in sorted_names:
            file.write(f"{name}: {count}\n")

    print(f"Output written to {output_file}")


# Example usage
folder_path = "C:/Users/laure/OneDrive/Documents/GitHub/Dataset_KG/Nutrition"
output_file = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/Cleaning_steps/output.txt"
process_file_names_with_counter(folder_path, output_file)

#39031 have at least 2 duplicates
# Milk_Whole_ has 247 duplicates
# Out:
# Output written to C:/Users/laure/OneDrive/Documents/GitHub/KG_project/Cleaning_steps/output.txt

# %% [markdown]
# # Count how many items have an undefined calorie amount

# %%
def separate_values_and_units_boolean(text):
    if(text == '' or text == '--%'):
        return True
    elif(text == '--' or text == '--mcg' or text == '--mg' or text == '--g' or text == '--IU'):
        return True

    return False

# %%
import os
import csv


# Function to count files where "calories" is not defined
def count_files_with_undefined_calories(folder_path):
    undefined_calories_count = 0
    files_checked = 0

    # Iterate through all files in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):  # Only process CSV files
            file_path = os.path.join(folder_path, file_name)
            files_checked += 1
            calories_defined = False  # Tracks if "calories" are defined in the file

            # Open and read the CSV file
            with open(file_path, mode='r') as file:
                csv_reader = csv.reader(file)

                # Skip the header row
                next(csv_reader)

                # Check each row in the file
                for row in csv_reader:
                    if len(row) < 3:
                        continue  # Skip rows with missing columns

                    value_name = row[1].strip()  # Second column for "value_name"
                    #measure = row[2].strip()  # Third column for "measure" value
                    measureUnity = separate_values_and_units_boolean(row[2])

                    if value_name.lower() == "calories (kcal)":
                        if measureUnity:  # If measure is not empty or invalid
                            calories_defined = False
                        else:
                            calories_defined = True
                        break  # Stop checking further since we found "calories"

            # Increment the count if calories are not defined
            if not calories_defined:
                undefined_calories_count += 1

    print(f"Checked {files_checked} files.")
    return undefined_calories_count


# Specify the folder containing the CSV files
folder_path = "C:/Users/laure/OneDrive/Documents/GitHub/Dataset_KG/Nutrition"

# Call the function and print the result
undefined_count = count_files_with_undefined_calories(folder_path)
print(f"Number of files where 'Calories' is not defined: {undefined_count}")

# Checked 327139 files.
# Number of files where 'Calories' is not defined: 28152
# Out:
# Checked 327139 files.
# Number of files where 'Calories' is not defined: 28152

# %% [markdown]
# # Count the number of products with a complete Essential amino acids profil

# %%
import os
import csv

# List of required essential amino acids
essential_amino_acids = [
    "Histidine", "Isoleucine", "Leucine", "Lysine",
    "Methionine", "Phenylalanine", "Threonine",
    "Tryptophan", "Valine"
]


# Function to count products with all essential amino acids values filled
def count_products_with_all_essential_amino_acids(folder_path):
    products_with_all_essential_amino_acids = 0
    files_checked = 0

    # Iterate through all files in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):  # Only process CSV files
            file_path = os.path.join(folder_path, file_name)
            files_checked += 1
            essential_acids_status = {acid: False for acid in essential_amino_acids}

            # Open and read the CSV file
            with open(file_path, mode='r') as file:
                csv_reader = csv.reader(file)

                # Skip the header row
                next(csv_reader)

                # Check each row in the file
                for row in csv_reader:
                    if len(row) < 3:
                        continue  # Skip rows with missing columns

                    category_name = row[0].strip()  # First column for "category_name"
                    value_name = row[1].strip()  # Second column for "value_name"
                    measure = row[2].strip()  # Third column for "measure"
                    measureUnity = separate_values_and_units_boolean(row[2])

                    # Track if the current row corresponds to an essential amino acid entry
                    if category_name.lower() == "essential amino acids" and value_name in essential_amino_acids:
                        if measureUnity:  # If measure is non-empty, mark the amino acid as filled
                            essential_acids_status[value_name] = False
                            break
                        else:
                            essential_acids_status[value_name] = True

            # If all essential amino acids are filled, count this product
            if all(essential_acids_status.values()):

                products_with_all_essential_amino_acids += 1
                #print(file_name)

            if(files_checked%10000 == 0):
                print(files_checked)

    print(f"Checked {files_checked} files.")
    return products_with_all_essential_amino_acids


# Specify the folder containing the CSV files
folder_path = "C:/Users/laure/OneDrive/Documents/GitHub/Dataset_KG/Nutrition"

# Call the function and print the result
filled_count = count_products_with_all_essential_amino_acids(folder_path)
print(f"Number of products with all essential amino acids values filled: {filled_count}")

# Checked 327139 files.
# Number of products with all essential amino acids values filled: 83375
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# Checked 327139 files.
# Number of products with all essential amino acids values filled: 83375

# %% [markdown]
# # SPARSQL Queries

# %% [markdown]
# ## An average human of 70kg should have a daily intake of essential amino acids of : Histidine: 980 mg Isoleucine: 1330 mg Leucine: 2940 mg Lysine: 2660 mg Methionine: 1330 mg Phenylalanine: 2310 mg Threonine: 1400 mg Tryptophan: 350 mg Valine: 1680 mg

# %% [markdown]
# https://my.clevelandclinic.org/health/articles/22243-amino-acids

# %%
import csv

# Define required minimum values for a "complete" amino acid profile (in mg)
REQUIRED_AMINO_ACIDS = {
    "Histidine": 980,
    "Isoleucine": 1330,
    "Leucine": 2940,
    "Lysine": 2660,
    "Methionine": 1330,
    "Phenylalanine": 2310,
    "Threonine": 1400,
    "Tryptophan": 350,
    "Valine": 1680
}

# Read the food amino acids CSV file
file_path = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/food_amino_acids_cleaned.csv"
complete_proteins = []
count_complete_proteins = 0
incomplete_proteins = []
count_incomplete_proteins = 0

with open(file_path, mode="r", encoding="utf-8") as file:
    reader = csv.reader(file)
    header = next(reader)  # Read the header row

    # Get column indices of essential amino acids
    amino_acid_indices = {aa: header.index(aa) for aa in REQUIRED_AMINO_ACIDS.keys()}

    # Check each food item
    for row in reader:
        food_name = row[0]
        amino_acid_values = {aa: float(row[amino_acid_indices[aa]]) for aa in REQUIRED_AMINO_ACIDS.keys()}

        # Check if this food meets or exceeds all required amino acids
        if all(amino_acid_values[aa] >= REQUIRED_AMINO_ACIDS[aa] for aa in REQUIRED_AMINO_ACIDS.keys()):
            complete_proteins.append(food_name)
            count_complete_proteins += 1
        else:
            incomplete_proteins.append(food_name)
            count_incomplete_proteins += 1

# Print results
print("Foods with a complete amino acid profile:")
if complete_proteins:
    for food in complete_proteins:
        print(f"- {food}")
    print(f"Total foods with a complete amino acid profile: {count_complete_proteins}")
else:
    print("No individual foods meet the complete amino acid profile.")

print("\nFoods with an incomplete amino acid profile:")
if incomplete_proteins:
    for food in incomplete_proteins:
        print(f"- {food}")
    print(f"Total foods with an incomplete amino acid profile: {count_incomplete_proteins}")
else:
    print("All foods are complete proteins.")
# Out:
# Foods with a complete amino acid profile:
# - Apples_Canned_Sweetened_Sliced_Drained_Unheated
# - Cream_Of_Rice_Cooked_With_Water_Without_Salt
# - Dried_Eggs
# - Dried_Salted_Atlantic_Cod
# - Egg_white_dried
# - Egg_white_dried_flakes_stabilized_glucose_reduced
# - Egg_white_dried_powder_stabilized_glucose_reduced
# - Egg_White_Powder
# - Egg_whole_dried_stabilized_glucose_reduced
# - Fish_whitefish_dried__Alaska_Native_
# - Nutribiotic_Systems_-_Rice_Protein
# - Seal_bearded__Oogruk__meat_dried__Alaska_Native_
# - Soup_Swanson_Chicken_Broth_99__Fat_Free
# - Tangerine_Juice_Canned_Sweetened
# - Vital_wheat_gluten
# - Whale_beluga_meat_dried__Alaska_Native_
# Total foods with a complete amino acid profile: 16
#
# Foods with an incomplete amino acid profile:
# - Acorn_stew__Apache_
# - Agave_raw__Southwest_
# - Alaskan_King_Crab
# - All_Purpose_Flour__Enrinched_and_Unbleached_
# - Almonds
# - Almond_Butter
# - Amaranth_grain_uncooked
# - Amaranth_leaves_cooked_boiled_drained_without_salt
# - Amaranth_leaves_cooked_boiled_drained_with_salt
# - Amaranth_leaves_raw
# - American_Cheese
# - American_Cheese_Spread
# - Applebee_s_9_oz_house_sirloin_steak
# - Applebee_s_chicken_tenders_from_kids__menu
# - Applebee_s_chicken_tenders_platter
# - Applebee_s_chili
# - Applebee_s_coleslaw
# - Applebee_s_crunchy_onion_rings
# - Applebee_s_Double_Crunch_Shrimp
# - Applebee_s_fish_hand_battered
# - Applebee_s_KRAFT_Macaroni___Cheese_from_kid_s_menu
# - Applebee_s_mozzarella_sticks
# - Applesauce_canned_sweetened_without_salt
# - Applesauce_canned_sweetened_with_salt
# - Applesauce_canned_unsweetened_without_added_ascorbic_acid
# - Applesauce_canned_unsweetened_with_added_ascorbic_acid
# - Apples
# - Apples_canned_sweetened_sliced_drained_heated
# - Apples_dehydrated__low_moisture__sulfured_stewed
# - Apples_dehydrated__low_moisture__sulfured_uncooked
# - Apples_dried_sulfured_stewed_without_added_sugar
# - Apples_dried_sulfured_stewed_with_added_sugar
# - Apples_frozen_unsweetened_heated
# - Apples_Frozen_Unsweetened_Unheated
# - Apples_raw_without_skin_cooked_microwave
# - Apples__Without_Skin_
# - Apple_Strudel
# - Apricots
# - Apricots_canned_extra_heavy_syrup_pack_without_skin_solids_and_liquids
# - Apricots_canned_extra_light_syrup_pack_with_skin_solids_and_liquids
# - Apricots_canned_heavy_syrup_pack_without_skin_solids_and_liquids
# - Apricots_canned_heavy_syrup_pack_with_skin_solids_and_liquids
# - Apricots_canned_juice_pack_with_skin_solids_and_liquids
# - Apricots_canned_light_syrup_pack_with_skin_solids_and_liquids
# - Apricots_canned_water_pack_without_skin_solids_and_liquids
# - Apricots_canned_water_pack_with_skin_solids_and_liquids
# - Apricots_dehydrated__low-moisture__sulfured_stewed
# - Apricots_dried_sulfured_stewed_without_added_sugar
# - Apricots_dried_sulfured_stewed_with_added_sugar
# - Apricots_frozen_sweetened
# - Arrowroot_flour
# - Asian_Pears
# - Asparagus_canned_no_salt_added_solids_and_liquids
# - Asparagus_canned_regular_pack_solids_and_liquids
# - Asparagus_cooked_boiled_drained_with_salt
# - Asparagus_frozen_cooked_boiled_drained_without_salt
# - Asparagus_frozen_cooked_boiled_drained_with_salt
# - Asparagus_frozen_unprepared
# - Atlantic_Herring
# - Avocados
# - Babyfood_Baby_MUM_MUM_Rice_Biscuits
# - Babyfood_banana_with_mixed_berries_strained
# - Babyfood_cereal_barley_prepared_with_whole_milk
# - Babyfood_cereal_high_protein_prepared_with_whole_milk
# - Babyfood_cereal_mixed_dry_fortified
# - Babyfood_cereal_mixed_prepared_with_whole_milk
# - Babyfood_cereal_mixed_with_applesauce_and_bananas_junior_fortified
# - Babyfood_cereal_mixed_with_applesauce_and_bananas_strained
# - Babyfood_cereal_mixed_with_bananas_dry
# - Babyfood_cereal_mixed_with_bananas_prepared_with_whole_milk
# - Babyfood_cereal_oatmeal_prepared_with_whole_milk
# - Babyfood_cereal_oatmeal_with_applesauce_and_bananas_junior_fortified
# - Babyfood_cereal_oatmeal_with_applesauce_and_bananas_strained
# - Babyfood_cereal_oatmeal_with_bananas_dry
# - Babyfood_cereal_oatmeal_with_bananas_prepared_with_whole_milk
# - Babyfood_cereal_rice_dry_fortified
# - Babyfood_cereal_rice_prepared_with_whole_milk
# - Babyfood_cereal_rice_with_applesauce_and_bananas_strained
# - Babyfood_cereal_rice_with_bananas_dry
# - Babyfood_cereal_rice_with_bananas_prepared_with_whole_milk
# - Babyfood_cereal_with_egg_yolks_junior
# - Babyfood_cereal_with_egg_yolks_strained
# - Babyfood_corn_and_sweet_potatoes_strained
# - Babyfood_dessert_dutch_apple_junior
# - Babyfood_dinner_beef_and_rice_toddler
# - Babyfood_dinner_beef_lasagna_toddler
# - Babyfood_dinner_beef_noodle_junior
# - Babyfood_dinner_chicken_stew_toddler
# - Babyfood_dinner_macaroni_and_cheese_junior
# - Babyfood_dinner_macaroni_and_tomato_and_beef_junior
# - Babyfood_dinner_spaghetti_and_tomato_and_meat_toddler
# - Babyfood_dinner_vegetables_and_beef_junior
# - Babyfood_dinner_vegetables_and_beef_strained
# - Babyfood_dinner_vegetables_and_lamb_junior
# - Babyfood_fruit_banana_and_strawberry_junior
# - Babyfood_GERBER_2nd_Foods_apple_carrot_and_squash_organic
# - Babyfood_mashed_cheddar_potatoes_and_broccoli_toddlers
# - Babyfood_meat_chicken_junior
# - Babyfood_meat_chicken_sticks_junior
# - Babyfood_meat_chicken_strained
# - Babyfood_meat_ham_junior
# - Babyfood_meat_ham_strained
# - Babyfood_meat_lamb_junior
# - Babyfood_meat_meat_sticks_junior
# - Babyfood_meat_pork_strained
# - Babyfood_meat_turkey_sticks_junior
# - Babyfood_meat_turkey_strained
# - Babyfood_rice_cereal_dry_EARTHS_BEST_ORGANIC_WHOLE_GRAIN_fortified_only_with_iron
# - Babyfood_snack_GERBER_GRADUATES_YOGURT_MELTS
# - Babyfood_tropical_fruit_medley
# - Babyfood_vegetables_beets_strained
# - Babyfood_vegetables_carrots_junior
# - Babyfood_vegetables_carrots_strained
# - Babyfood_vegetables_corn_creamed_junior
# - Babyfood_vegetables_corn_creamed_strained
# - Babyfood_vegetables_garden_vegetable_strained
# - Babyfood_vegetables_green_beans_junior
# - Babyfood_vegetables_green_beans_strained
# - Babyfood_vegetables_mix_vegetables_junior
# - Babyfood_vegetables_mix_vegetables_strained
# - Babyfood_vegetables_spinach_creamed_strained
# - Babyfood_vegetables_sweet_potatoes_junior
# - Babyfood_vegetables_sweet_potatoes_strained
# - Baby_Carrots
# - Bacon_and_beef_sticks
# - Bacon_meatless
# - Bacon_pre-sliced_reduced_low_sodium_unprepared
# - Bacon_turkey_low_sodium
# - Bagels_plain_enriched_without_calcium_propionate__includes_onion_poppy_sesame_
# - Bagels_plain_unenriched_without_calcium_propionate_includes_onion_poppy_sesame_
# - Bagels_plain_unenriched_with_calcium_propionate__includes_onion_poppy_sesame_
# - Baked_Acorn_Squash
# - Baked_Beans
# - Baked_Potatoes_with_Skin__Peel_
# - Baked_Potatoes__With_Skin_
# - Baked_Potato__No_Skin_
# - Baked_Red_Potatoes
# - Baked_Russet_Potatoes
# - Baked_Sweet_Potatoes
# - Baking_chocolate_unsweetened_liquid
# - Bamboo_shoots_cooked_boiled_drained_with_salt
# - Bananas
# - Barbecue_loaf_pork_beef
# - Barley_flour_or_meal
# - Barley_hulled
# - Barley_malt_flour
# - Barley_pearled_raw
# - Bartlett_Pears
# - Beans_adzuki_mature_seeds_canned_sweetened
# - Beans_adzuki_mature_seeds_raw
# - Beans_adzuki_mature_seed_cooked_boiled_with_salt
# - Beans_baked_canned_with_franks
# - Beans_baked_canned_with_pork
# - Beans_baked_canned_with_pork_and_sweet_sauce
# - Beans_baked_canned_with_pork_and_tomato_sauce
# - Beans_black_mature_seeds_canned_low_sodium
# - Beans_black_mature_seeds_cooked_boiled_with_salt
# - Beans_black_mature_seeds_raw
# - Beans_black_turtle_mature_seeds_canned
# - Beans_black_turtle_mature_seeds_cooked_boiled_with_salt
# - Beans_black_turtle_mature_seeds_raw
# - Beans_cranberry__roman__mature_seeds_cooked_boiled_with_salt
# - Beans_cranberry__roman__mature_seeds_raw
# - Beans_french_mature_seeds_cooked_boiled_without_salt
# - Beans_french_mature_seeds_cooked_boiled_with_salt
# - Beans_french_mature_seeds_raw
# - Beans_great_northern_mature_seeds_canned
# - Beans_great_northern_mature_seeds_canned_low_sodium
# - Beans_great_northern_mature_seeds_cooked_boiled_with_salt
# - Beans_Great_Northern_Mature_Seeds_Raw
# - Beans_kidney_all_types_mature_seeds_cooked_boiled_with_salt
# - Beans_kidney_all_types_mature_seeds_raw
# - Beans_kidney_california_red_mature_seeds_cooked_boiled_with_salt
# - Beans_kidney_california_red_mature_seeds_raw
# - Beans_kidney_mature_seeds_sprouted_cooked_boiled_drained_without_salt
# - Beans_kidney_mature_seeds_sprouted_cooked_boiled_drained_with_salt
# - Beans_kidney_red_mature_seeds_canned_drained_solids
# - Beans_kidney_red_mature_seeds_canned_drained_solids_rinsed_in_tap_water
# - Beans_kidney_red_mature_seeds_canned_solids_and_liquid_low_sodium
# - Beans_kidney_red_mature_seeds_cooked_boiled_with_salt
# - Beans_kidney_red_mature_seeds_raw
# - Beans_kidney_royal_red_mature_seeds_cooked_boiled_with_salt
# - Beans_kidney_royal_red_mature_seeds_raw
# - Beans_navy_mature_seeds_cooked_boiled_with_salt
# - Beans_navy_mature_seeds_raw
# - Beans_navy_mature_seeds_sprouted_cooked_boiled_drained_without_salt
# - Beans_navy_mature_seeds_sprouted_cooked_boiled_drained_with_salt
# - Beans_navy_mature_seeds_sprouted_raw
# - Beans_pink_mature_seeds_cooked_boiled_without_salt
# - Beans_pink_mature_seeds_cooked_boiled_with_salt
# - Beans_pink_mature_seeds_raw
# - Beans_pinto_canned_drained_solids
# - Beans_pinto_mature_seeds_canned_drained_solids_rinsed_in_tap_water
# - Beans_pinto_mature_seeds_canned_solids_and_liquids
# - Beans_pinto_mature_seeds_canned_solids_and_liquids_low_sodium
# - Beans_pinto_mature_seeds_cooked_boiled_with_salt
# - Beans_Pinto_Mature_Seeds_Raw
# - Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt
# - Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_with_salt
# - Beans_pinto_mature_seeds_sprouted_raw
# - Beans_small_white_mature_seeds_cooked_boiled_with_salt
# - Beans_small_white_mature_seeds_raw
# - Beans_snap_canned_all_styles_seasoned_solids_and_liquids
# - Beans_snap_green_canned_no_salt_added_drained_solids
# - Beans_snap_green_canned_no_salt_added_solids_and_liquids
# - Beans_snap_green_canned_regular_pack_drained_solids
# - Beans_snap_green_cooked_boiled_drained_with_salt
# - Beans_snap_green_frozen_all_styles_microwaved
# - Beans_snap_green_frozen_all_styles_unprepared
# - Beans_snap_green_frozen_cooked_boiled_drained_with_salt
# - Beans_snap_yellow_canned_no_salt_added_drained_solids
# - Beans_snap_yellow_canned_no_salt_added_solids_and_liquids
# - Beans_snap_yellow_canned_regular_pack_drained_solids
# - Beans_snap_yellow_canned_regular_pack_solids_and_liquids
# - Beans_snap_yellow_cooked_boiled_drained_with_salt
# - Beans_snap_yellow_frozen_all_styles_unprepared
# - Beans_snap_yellow_frozen_cooked_boiled_drained_without_salt
# - Beans_snap_yellow_frozen_cooked_boiled_drained_with_salt
# - Beans_white_mature_seeds_canned
# - Beans_white_mature_seeds_cooked_boiled_with_salt
# - Beans_white_mature_seeds_raw
# - Beans_yellow_mature_seeds_cooked_boiled_without_salt
# - Beans_yellow_mature_seeds_cooked_boiled_with_salt
# - Beans_yellow_mature_seeds_raw
# - Beef_And_Chicken_Polish_Sausage
# - Beef_And_Pork_Baloney__Bologna_
# - Beef_Australian_imported_grass-fed_ground__minced__85__lean___15__fat_raw
# - Beef_Australian_imported_grass-fed_loin_tenderloin_steak_roast_boneless_separable_lean_and_fat_raw
# - Beef_Australian_imported_grass-fed_loin_tenderloin_steak_roast_boneless_separable_lean_only_raw
# - Beef_Australian_imported_grass-fed_loin_top_loin_steak_roast_boneless_separable_lean_and_fat_raw
# - Beef_Australian_imported_grass-fed_loin_top_loin_steak_roast_boneless_separable_lean_only_raw
# - Beef_Australian_imported_grass-fed_loin_top_sirloin_cap-off_steak_roast_boneless_separable_lean_and_fat_raw
# - Beef_Australian_imported_grass-fed_loin_top_sirloin_cap-off_steak_roast_boneless_separable_lean_only_raw
# - Beef_Australian_imported_grass-fed_rib_ribeye_steak_roast_lip-on_boneless_separable_lean_and_fat_raw
# - Beef_Australian_imported_grass-fed_rib_ribeye_steak_roast_lip-on_boneless_separable_lean_only_raw
# - Beef_Australian_imported_grass-fed_round_bottom_round_steak_roast_boneless_separable_lean_and_fat_raw
# - Beef_Australian_imported_grass-fed_round_bottom_round_steak_roast_boneless_separable_lean_only_raw
# - Beef_Australian_imported_grass-fed_round_top_round_cap-off_steak_roast_boneless_separable_lean_and_fat_raw
# - Beef_Australian_imported_grass-fed_round_top_round_cap-off_steak_roast_boneless_separable_lean_only_raw
# - Beef_Australian_imported_Wagyu_loin_tenderloin_steak_roast_boneless_separable_lean_and_fat_Aust__marble_score_4_5_raw
# - Beef_Australian_imported_Wagyu_loin_tenderloin_steak_roast_boneless_separable_lean_and_fat_Aust__marble_score_9_raw
# - Beef_Australian_imported_Wagyu_loin_tenderloin_steak_roast_boneless_separable_lean_only_Aust__marble_score_4_5_raw
# - Beef_Australian_imported_Wagyu_loin_tenderloin_steak_roast_boneless_separable_lean_only_Aust__marble_score_9_raw
# - Beef_Australian_imported_Wagyu_loin_top_loin_steak_roast_boneless_separable_lean_and_fat_Aust__marble_score_4_5_raw
# - Beef_Australian_imported_Wagyu_loin_top_loin_steak_roast_boneless_separable_lean_only_Aust__marble_score_4_5_raw
# - Beef_Australian_imported_Wagyu_loin_top_loin_steak_roast_boneless_separable_lean_only_Aust__marble_score_9_raw
# - Beef_Australian_imported_Wagyu_loin_top_loin_steak_roast_separable_lean_and_fat_Aust__marble_score_9_raw
# - Beef_Australian_imported_Wagyu_rib_small_end_rib_steak_roast_boneless_separable_lean_and_fat_Aust__marble_score_4_5_raw
# - Beef_Australian_imported_Wagyu_rib_small_end_rib_steak_roast_boneless_separable_lean_and_fat_Aust__marble_score_9_raw
# - Beef_Australian_imported_Wagyu_rib_small_end_rib_steak_roast_boneless_separable_lean_only_Aust__marble_score_4_5_raw
# - Beef_Australian_imported_Wagyu_rib_small_end_rib_steak_roast_boneless_separable_lean_only_Aust__marble_score_9_raw
# - Beef_Baloney__Bologna_
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_roasted
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_only_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_only_trimmed_to_0__fat_select_cooked_roasted
# - Beef_bottom_sirloin_tri-tip_roast_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_brisket_flat_half_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_brisket_flat_half_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_brisket_flat_half_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_brisket_flat_half_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_brisket_flat_half_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_brisket_flat_half_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_braised
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_braised
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_braised
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_1_8__fat_choice_cooked_braised
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_1_8__fat_choice_raw
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_1_8__fat_select_cooked_braised
# - Beef_brisket_flat_half_separable_lean_and_fat_trimmed_to_1_8__fat_select_raw
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_0__fat_choice_cooked_braised
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_0__fat_select_cooked_braised
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_1_8__fat_all_grades_cooked_braised
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_1_8__fat_all_grades_raw
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_1_8__fat_choice_cooked_braised
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_1_8__fat_choice_raw
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_1_8__fat_select_cooked_braised
# - Beef_brisket_flat_half_separable_lean_only_trimmed_to_1_8__fat_select_raw
# - Beef_brisket_point_half_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_brisket_point_half_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_braised
# - Beef_brisket_point_half_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_brisket_point_half_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_brisket_whole_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_brisket_whole_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_braised
# - Beef_brisket_whole_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_brisket_whole_separable_lean_only_all_grades_raw
# - Beef_brisket_whole_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_carcass_separable_lean_and_fat_choice_raw
# - Beef_carcass_separable_lean_and_fat_select_raw
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_1_8__fat_choice_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_1_8__fat_choice_raw
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_1_8__fat_select_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_and_fat_trimmed_to_1_8__fat_select_raw
# - Beef_chuck_arm_pot_roast_separable_lean_only_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_only_trimmed_to_1_8__fat_all_grades_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_only_trimmed_to_1_8__fat_all_grades_raw
# - Beef_chuck_arm_pot_roast_separable_lean_only_trimmed_to_1_8__fat_choice_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_only_trimmed_to_1_8__fat_choice_raw
# - Beef_chuck_arm_pot_roast_separable_lean_only_trimmed_to_1_8__fat_select_cooked_braised
# - Beef_chuck_arm_pot_roast_separable_lean_only_trimmed_to_1_8__fat_select_raw
# - Beef_chuck_blade_roast_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_blade_roast_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_braised
# - Beef_chuck_blade_roast_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_chuck_blade_roast_separable_lean_and_fat_trimmed_to_1_8__fat_choice_cooked_braised
# - Beef_chuck_blade_roast_separable_lean_and_fat_trimmed_to_1_8__fat_choice_raw
# - Beef_chuck_blade_roast_separable_lean_and_fat_trimmed_to_1_8__fat_select_raw
# - Beef_chuck_blade_roast_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_clod_roast_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_chuck_clod_roast_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_chuck_clod_roast_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_roasted
# - Beef_chuck_clod_roast_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_chuck_clod_roast_separable_lean_only_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_chuck_clod_roast_separable_lean_only_trimmed_to_0__fat_select_cooked_roasted
# - Beef_chuck_clod_roast_separable_lean_only_trimmed_to_1_4__fat_all_grades_cooked_roasted
# - Beef_chuck_clod_roast_separable_lean_only_trimmed_to_1_4__fat_all_grades_raw
# - Beef_chuck_clod_steak_separable_lean_only_trimmed_to_1_4__fat_all_grades_cooked_braised
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_eye_Country-Style_ribs_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_roasted
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_only_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_only_trimmed_to_0__fat_select_cooked_roasted
# - Beef_chuck_eye_roast_boneless_America_s_Beef_Roast_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_chuck_eye_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_chuck_eye_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_eye_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_chuck_eye_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_eye_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_grilled
# - Beef_chuck_eye_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_eye_steak_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_chuck_eye_steak_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_eye_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_chuck_eye_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_chuck_eye_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_grilled
# - Beef_chuck_eye_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_chuck_for_stew_separable_lean_and_fat_all_grades_raw
# - Beef_chuck_for_stew_separable_lean_and_fat_choice_cooked_braised
# - Beef_chuck_for_stew_separable_lean_and_fat_choice_raw
# - Beef_chuck_for_stew_separable_lean_and_fat_select_cooked_braised
# - Beef_chuck_for_stew_separable_lean_and_fat_select_raw
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_mock_tender_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_chuck_mock_tender_steak_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_broiled
# - Beef_chuck_mock_tender_steak_separable_lean_and_fat_trimmed_to_0__fat_USDA_choice_cooked_broiled
# - Beef_chuck_mock_tender_steak_separable_lean_and_fat_trimmed_to_0__fat_USDA_select_cooked_broiled
# - Beef_chuck_mock_tender_steak_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_broiled
# - Beef_chuck_mock_tender_steak_separable_lean_only_trimmed_to_0__fat_choice_cooked_broiled
# - Beef_chuck_mock_tender_steak_separable_lean_only_trimmed_to_0__fat_select_cooked_broiled
# - Beef_Chuck_Pot_Roast__Trimmed_to_0_inch_fat_
# - Beef_chuck_short_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_short_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_short_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_short_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_short_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_short_ribs_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_short_ribs_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_short_ribs_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_short_ribs_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_short_ribs_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_chuck_short_ribs_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_short_ribs_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_chuck_shoulder_clod_shoulder_tender_medallion_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_chuck_shoulder_clod_shoulder_tender_medallion_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_shoulder_clod_shoulder_tender_medallion_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_chuck_shoulder_clod_shoulder_tender_medallion_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_shoulder_clod_shoulder_tender_medallion_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_grilled
# - Beef_chuck_shoulder_clod_shoulder_tender_medallion_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_shoulder_clod_shoulder_top_and_center_steaks_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_chuck_shoulder_clod_shoulder_top_and_center_steaks_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_shoulder_clod_shoulder_top_and_center_steaks_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_chuck_shoulder_clod_shoulder_top_and_center_steaks_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_shoulder_clod_shoulder_top_and_center_steaks_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_grilled
# - Beef_chuck_shoulder_clod_shoulder_top_and_center_steaks_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_shoulder_clod_top_blade_steak_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_chuck_shoulder_clod_top_blade_steak_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_shoulder_clod_top_blade_steak_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_chuck_shoulder_clod_top_blade_steak_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_shoulder_clod_top_blade_steak_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_grilled
# - Beef_chuck_shoulder_clod_top_blade_steak_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_top_blade_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_broiled
# - Beef_chuck_top_blade_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_broiled
# - Beef_chuck_top_blade_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_broiled
# - Beef_chuck_top_blade_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_broiled
# - Beef_chuck_top_blade_separable_lean_only_trimmed_to_0__fat_choice_cooked_broiled
# - Beef_chuck_top_blade_separable_lean_only_trimmed_to_0__fat_select_cooked_broiled
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_grilled
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_only_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_only_trimmed_to_0__fat_select_cooked_grilled
# - Beef_chuck_under_blade_center_steak_boneless_Denver_Cut_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_chuck_under_blade_pot_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_under_blade_pot_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_under_blade_pot_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_under_blade_pot_roast_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_under_blade_pot_roast_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_under_blade_pot_roast_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_under_blade_pot_roast_or_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_under_blade_pot_roast_or_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_chuck_under_blade_pot_roast_or_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_chuck_under_blade_pot_roast_or_steak_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_chuck_under_blade_pot_roast_or_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_chuck_under_blade_pot_roast_or_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_chuck_under_blade_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_under_blade_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_under_blade_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_braised
# - Beef_chuck_under_blade_steak_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_braised
# - Beef_chuck_under_blade_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_braised
# - Beef_chuck_under_blade_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_braised
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_0__fat_select_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_1_8__fat_choice_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_1_8__fat_choice_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_1_8__fat_select_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_and_fat_trimmed_to_1_8__fat_select_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_0__fat_all_grades_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_0__fat_choice_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_0__fat_select_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_1_8__fat_all_grades_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_1_8__fat_all_grades_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_1_8__fat_choice_raw
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_1_8__fat_select_cooked
# - Beef_composite_of_trimmed_retail_cuts_separable_lean_only_trimmed_to_1_8__fat_select_raw
# - Beef_composite_separable_lean_only_trimmed_to_1_8__fat_choice_cooked
# - Beef_corned_beef_hash_with_potato_canned
# - Beef_cured_breakfast_strips_cooked
# - Beef_cured_breakfast_strips_raw_or_unheated
# - Beef_cured_corned_beef_brisket_cooked
# - Beef_cured_corned_beef_brisket_raw
# - Beef_cured_corned_beef_canned
# - Beef_cured_dried
# - Beef_cured_luncheon_meat_jellied
# - Beef_cured_pastrami
# - Beef_flank_steak_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_broiled
# - Beef_flank_steak_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_flank_steak_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_braised
# - Beef_flank_steak_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_broiled
# - Beef_flank_steak_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_flank_steak_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_broiled
# - Beef_flank_steak_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_flank_steak_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_broiled
# - Beef_flank_steak_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_flank_steak_separable_lean_only_trimmed_to_0__fat_choice_cooked_braised
# - Beef_flank_steak_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_flank_steak_separable_lean_only_trimmed_to_0__fat_select_cooked_broiled
# - Beef_flank_steak_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_Ground__Minced__70__Lean_Meat___30__Fat_Loaf_Cooked_Baked
# - Beef_Ground__Minced__70__Lean_Meat___30__Fat_Patty_Cooked_Broiled
# - Beef_Ground__Minced__70__Lean_Meat___30__Fat_Patty_Cooked_Pan-Broiled
# - Beef_Ground__Minced__70__Lean_Meat___30__Fat_Raw
# - Beef_ground__minced__75__lean_meat___25__fat_crumbles_cooked_pan-browned
# - Beef_ground__minced__75__lean_meat___25__fat_loaf_cooked_baked
# - Beef_ground__minced__75__lean_meat___25__fat_patty_cooked_broiled
# - Beef_ground__minced__75__lean_meat___25__fat_patty_cooked_pan-broiled
# - Beef_ground__minced__75__lean_meat___25__fat_raw
# - Beef_ground__minced__80__lean_meat___20__fat_crumbles_cooked_pan-browned
# - Beef_ground__minced__80__lean_meat___20__fat_loaf_cooked_baked
# - Beef_ground__minced__80__lean_meat___20__fat_patty_cooked_broiled
# - Beef_ground__minced__80__lean_meat___20__fat_patty_cooked_pan-broiled
# - Beef_ground__minced__80__lean_meat___20__fat_raw
# - Beef_ground__minced__85__lean_meat___15__fat_crumbles_cooked_pan-browned
# - Beef_ground__minced__85__lean_meat___15__fat_loaf_cooked_baked
# - Beef_ground__minced__85__lean_meat___15__fat_patty_cooked_broiled
# - Beef_ground__minced__85__lean_meat___15__fat_patty_cooked_pan-broiled
# - Beef_ground__minced__85__lean_meat___15__fat_raw
# - Beef_ground__minced__90__lean_meat___10__fat_crumbles_cooked_pan-browned
# - Beef_ground__minced__90__lean_meat___10__fat_loaf_cooked_baked
# - Beef_ground__minced__90__lean_meat___10__fat_patty_cooked_broiled
# - Beef_ground__minced__90__lean_meat___10__fat_patty_cooked_pan-broiled
# - Beef_ground__minced__90__lean_meat___10__fat_raw
# - Beef_ground__minced__93__lean_meat__7__fat_patty_cooked_pan-broiled
# - Beef_ground__minced__93__lean_meat___7__fat_crumbles_cooked_pan-browned
# - Beef_ground__minced__93__lean_meat___7__fat_loaf_cooked_baked
# - Beef_ground__minced__93__lean_meat___7__fat_raw
# - Beef_ground__minced__95__lean_meat___5__fat_crumbles_cooked_pan-browned
# - Beef_ground__minced__95__lean_meat___5__fat_loaf_cooked_baked
# - Beef_ground__minced__95__lean_meat___5__fat_patty_cooked_broiled
# - Beef_ground__minced__95__lean_meat___5__fat_patty_cooked_pan-broiled
# - Beef_ground__minced__95__lean_meat___5__fat_raw
# - Beef_ground__minced__97__lean_meat__3__fat_patty_cooked_pan-broiled
# - Beef_ground__minced__97__lean_meat___3__fat_crumbles_cooked_pan-browned
# - Beef_ground__minced__97__lean_meat___3__fat_loaf_cooked_baked
# - Beef_ground__minced__97__lean_meat___3__fat_patty_cooked_broiled
# - Beef_ground__minced__97__lean_meat___3__fat_raw
# - Beef_ground__minced__unspecified_fat_content_cooked
# - Beef_loin_bottom_sirloin_butt_tri-tip_roast_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_loin_bottom_sirloin_butt_tri-tip_steak_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_broiled
# - Beef_loin_tenderloin_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_loin_tenderloin_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_loin_tenderloin_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_loin_tenderloin_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_loin_tenderloin_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_roasted
# - Beef_loin_tenderloin_roast_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_loin_tenderloin_roast_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_loin_tenderloin_roast_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_loin_tenderloin_roast_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_loin_tenderloin_roast_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_loin_tenderloin_roast_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_loin_tenderloin_roast_separable_lean_only_boneless_trimmed_to_0__fat_select_cooked_roasted
# - Beef_loin_tenderloin_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_loin_tenderloin_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_loin_tenderloin_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_loin_tenderloin_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_loin_tenderloin_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_grilled
# - Beef_loin_tenderloin_steak_boneless_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_loin_tenderloin_steak_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_loin_tenderloin_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_loin_tenderloin_steak_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_loin_tenderloin_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_grilled
# - Beef_loin_tenderloin_steak_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_loin_top_loin_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_grilled
# - Beef_loin_top_loin_separable_lean_and_fat_trimmed_to_1_8__fat_choice_raw
# - Beef_loin_top_loin_separable_lean_and_fat_trimmed_to_1_8__fat_select_cooked_grilled
# - Beef_loin_top_loin_separable_lean_and_fat_trimmed_to_1_8__fat_select_raw
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_and_fat_trimmed_to_1_8__fat_choice_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_and_fat_trimmed_to_1_8__fat_choice_raw
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_and_fat_trimmed_to_1_8__fat_select_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_and_fat_trimmed_to_1_8__fat_select_raw
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_only_trimmed_to_1_8__fat_all_grades_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_only_trimmed_to_1_8__fat_all_grades_raw
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_only_trimmed_to_1_8__fat_choice_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_only_trimmed_to_1_8__fat_choice_raw
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_only_trimmed_to_1_8__fat_select_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip-on_separable_lean_only_trimmed_to_1_8__fat_select_raw
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_and_fat_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_and_fat_trimmed_to_0__fat_all_grades_raw
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_and_fat_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_and_fat_trimmed_to_0__fat_choice_raw
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_and_fat_trimmed_to_0__fat_select_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_and_fat_trimmed_to_0__fat_select_raw
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_only_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_only_trimmed_to_0__fat_select_cooked_grilled
# - Beef_loin_top_loin_steak_boneless_lip_off_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_cooked_grilled
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_and_fat_trimmed_to_1_8__fat_all_grades_raw
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_and_fat_trimmed_to_1_8__fat_choice_cooked_grilled
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_and_fat_trimmed_to_1_8__fat_choice_raw
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_and_fat_trimmed_to_1_8__fat_select_cooked_grilled
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_and_fat_trimmed_to_1_8__fat_select_raw
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_only_trimmed_to_1_8__fat_all_grades_cooked_grilled
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_only_trimmed_to_1_8__fat_all_grades_raw
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_only_trimmed_to_1_8__fat_choice_cooked_grilled
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_only_trimmed_to_1_8__fat_choice_raw
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_only_trimmed_to_1_8__fat_select_cooked_grilled
# - Beef_loin_top_sirloin_cap_steak_boneless_separable_lean_only_trimmed_to_1_8__fat_select_raw
# - Beef_loin_top_sirloin_filet_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_grilled
# - Beef_loin_top_sirloin_filet_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_grilled
# - Beef_loin_top_sirloin_filet_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_grilled
# - Beef_loin_top_sirloin_petite_roast_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_cooked_roasted
# - Beef_loin_top_sirloin_petite_roast_boneless_separable_lean_only_trimmed_to_0__fat_choice_cooked_roasted
# - Beef_loin_top_sirloin_petite_roast_boneless_separable_lean_only_trimmed_to_0__fat_select_cooked_roasted
# - Beef_loin_top_sirloin_petite_roast_filet_boneless_separable_lean_only_trimmed_to_0__fat_all_grades_raw
# - Beef_loin_top_sirloin_petite_roast_filet_boneless_separable_lean_only_trimmed_to_0__fat_choice_raw
# - Beef_loin_top_sirloin_petite_roast_filet_boneless_separable_lean_only_trimmed_to_0__fat_select_raw
# - Beef_macaroni_with_tomato_sauce_frozen_entree_reduced_fat
# - Beef_New_Zealand_imported_bolar_blade_separable_lean_and_fat_cooked_fast_roasted
# - Beef_New_Zealand_imported_bolar_blade_separable_lean_and_fat_raw
# - Beef_New_Zealand_imported_bolar_blade_separable_lean_only_cooked_fast_roasted
# - Beef_New_Zealand_imported_bolar_blade_separable_lean_only_raw
# - Beef_New_Zealand_imported_brisket_navel_end_separable_lean_and_fat_cooked_braised
# - Beef_New_Zealand_imported_brisket_navel_end_separable_lean_and_fat_raw
# - Beef_New_Zealand_imported_brisket_navel_end_separable_lean_only_cooked_braised
# - Beef_New_Zealand_imported_brisket_navel_end_separable_lean_only_raw
# - Beef_New_Zealand_imported_brisket_point_end_separable_lean_and_fat_cooked_braised
# - Beef_New_Zealand_imported_brisket_point_end_separable_lean_and_fat_raw
# - Beef_New_Zealand_imported_brisket_point_end_separable_lean_only_cooked_braised
# - Beef_New_Zealand_imported_brisket_point_end_separable_lean_only_raw
# - Beef_New_Zealand_imported_chuck_eye_roll_separable_lean_and_fat_cooked_braised
# - Beef_New_Zealand_imported_chuck_eye_roll_separable_lean_and_fat_raw
# - Beef_New_Zealand_imported_chuck_eye_roll_separable_lean_only_cooked_braised
# - Beef_New_Zealand_imported_chuck_eye_roll_separable_lean_only_raw
# - Beef_New_Zealand_imported_cube_roll_separable_lean_and_fat_cooked_fast_roasted
# - Beef_New_Zealand_imported_cube_roll_separable_lean_and_fat_raw
# - Beef_New_Zealand_imported_cube_roll_separable_lean_only_cooked_fast_roasted
# - Beef_New_Zealand_imported_cube_roll_separable_lean_only_raw
# - Beef_New_Zealand_imported_eye_round_separable_lean_and_fat_cooked_slow_roasted
# - Beef_New_Zealand_imported_eye_round_separable_lean_and_fat_raw
# - Beef_New_Zealand_imported_eye_round_separable_lean_only_cooked_slow_roasted
# - Beef_New_Zealand_imported_eye_round_separable_lean_only_raw
# - Beef_New_Zealand_imported_flank_separable_lean_and_fat_cooked_braised
# - Beef_New_Zealand_imported_flank_separable_lean_and_fat_raw
# - Beef_New_Zealand_imported_flank_separable_lean_only_cooked_braised
# - Beef_New_Zealand_imported_flank_separable_lean_only_raw
# ...
# - Turkey_breast_low_salt_prepackaged_or_deli_luncheon_meat
# - Turkey_breast_pre-basted_meat_and_skin_cooked_roasted
# - Turkey_canned_meat_only_with_broth
# - Turkey_dark_meat_from_whole_meat_and_skin_with_added_solution_cooked_roasted
# - Turkey_dark_meat_from_whole_meat_and_skin_with_added_solution_raw
# - Turkey_dark_meat_from_whole_meat_only_with_added_solution_raw
# - Turkey_dark_meat_meat_and_skin_raw
# - Turkey_dark_meat_meat_only_with_added_solution_cooked_roasted
# - Turkey_diced_light_and_dark_meat_seasoned
# - Turkey_drumstick_from_whole_bird_meat_only_raw
# - Turkey_drumstick_from_whole_bird_meat_only_with_added_solution_raw
# - Turkey_drumstick_from_whole_bird_meat_only_with_added_solution_roasted
# - Turkey_From_Whole_Dark_Meat_Meat_Only_Raw
# - Turkey_From_Whole_Light_Meat_Meat_And_Skin_Cooked_Roasted
# - Turkey_From_Whole_Light_Meat_Meat_And_Skin_Raw
# - Turkey_from_whole_light_meat_meat_and_skin_with_added_solution_cooked_roasted
# - Turkey_from_whole_light_meat_meat_and_skin_with_added_solution_raw
# - Turkey_from_whole_light_meat_meat_only_with_added_solution_cooked_roasted
# - Turkey_from_whole_light_meat_meat_only_with_added_solution_raw
# - Turkey_From_Whole_Neck_Meat_Only_Cooked_Simmered
# - Turkey_From_Whole_Neck_Meat_Only_Raw
# - Turkey_fryer-roasters_meat_and_skin_cooked_roasted
# - Turkey_gizzard_all_classes_raw
# - Turkey_ground__minced__85__lean_15__fat_pan-broiled_crumbles
# - Turkey_ground__minced__85__lean_15__fat_raw
# - Turkey_ground__minced__93__lean_7__fat_patties_broiled
# - Turkey_Hotdog
# - Turkey_mechanically_deboned_from_turkey_frames_raw
# - Turkey_retail_parts_breast_meat_and_skin_cooked_roasted
# - Turkey_retail_parts_breast_meat_and_skin_raw
# - Turkey_retail_parts_breast_meat_and_skin_with_added_solution_raw
# - Turkey_retail_parts_breast_meat_only_cooked_roasted
# - Turkey_retail_parts_breast_meat_only_raw
# - Turkey_retail_parts_breast_meat_only_with_added_solution_cooked_roasted
# - Turkey_retail_parts_breast_meat_only_with_added_solution_raw
# - Turkey_retail_parts_drumstick_meat_and_skin_cooked_roasted
# - Turkey_retail_parts_drumstick_meat_and_skin_raw
# - Turkey_retail_parts_drumstick_meat_only_cooked_roasted
# - Turkey_retail_parts_drumstick_meat_only_raw
# - Turkey_retail_parts_thigh_meat_and_skin_cooked_roasted
# - Turkey_retail_parts_thigh_meat_and_skin_raw
# - Turkey_retail_parts_thigh_meat_only_cooked_roasted
# - Turkey_retail_parts_thigh_meat_only_raw
# - Turkey_retail_parts_wing_meat_and_skin_cooked_roasted
# - Turkey_retail_parts_wing_meat_and_skin_raw
# - Turkey_retail_parts_wing_meat_only_cooked_roasted
# - Turkey_retail_parts_wing_meat_only_raw
# - Turkey_roast_boneless_frozen_seasoned_light_and_dark_meat_raw
# - Turkey_Salami
# - Turkey_skin_from_retail_parts_from_dark_meat_cooked_roasted
# - Turkey_skin_from_retail_parts_from_dark_meat_raw
# - Turkey_Skin_From_Whole__Light_And_Dark__Roasted
# - Turkey_skin_from_whole__light_and_dark__with_added_solution_raw
# - Turkey_skin_from_whole__light_and_dark__with_added_solution_roasted
# - Turkey_sticks_breaded_battered_fried
# - Turkey_stuffing_mashed_potatoes_w_gravy_assorted_vegetables_frozen_microwaved
# - Turkey_thigh_from_whole_bird_meat_only_raw
# - Turkey_thigh_from_whole_bird_meat_only_with_added_solution_raw
# - Turkey_thigh_from_whole_bird_meat_only_with_added_solution_roasted
# - Turkey_thigh_pre-basted_meat_and_skin_cooked_roasted
# - Turkey_white_rotisserie_deli_cut
# - Turkey_whole_dark_meat_meat_and_skin_cooked_roasted
# - Turkey_whole_giblets_cooked_simmered
# - Turkey_whole_giblets_raw
# - Turkey_whole_light_meat_raw
# - Turkey_whole_meat_and_skin_raw
# - Turkey_whole_meat_and_skin_with_added_solution_raw
# - Turkey_whole_meat_and_skin_with_added_solution_roasted
# - Turkey_whole_meat_only_raw
# - Turkey_whole_meat_only_with_added_solution_raw
# - Turkey_whole_meat_only_with_added_solution_roasted
# - Turkey_whole_skin__light_and_dark__raw
# - Turkey_whole_wing_meat_only_raw
# - Turkey_wing_from_whole_bird_meat_only_with_added_solution_raw
# - Turkey_wing_from_whole_bird_meat_only_with_added_solution_roasted
# - Turkey_young_hen_skin_only_cooked_roasted
# - Turnips_cooked_boiled_drained_with_salt
# - Turnips_frozen_cooked_boiled_drained_without_salt
# - Turnips_frozen_cooked_boiled_drained_with_salt
# - Turnips_frozen_unprepared
# - Turnip_greens_and_turnips_frozen_cooked_boiled_drained_without_salt
# - Turnip_greens_and_turnips_frozen_cooked_boiled_drained_with_salt
# - Turnip_greens_and_turnips_frozen_unprepared
# - Turnip_greens_canned_solids_and_liquids
# - Turnip_greens_cooked_boiled_drained_with_salt
# - Turnip_greens_frozen_cooked_boiled_drained_without_salt
# - Turnip_greens_frozen_cooked_boiled_drained_with_salt
# - Turnip_greens_frozen_unprepared
# - Turnover_chicken-_or_turkey-_and_vegetable-filled_reduced_fat_frozen
# - T_G_I__FRIDAY_S_chicken_fingers
# - T_G_I__FRIDAY_S_chicken_fingers_from_kids__menu
# - T_G_I__FRIDAY_S_classic_sirloin_steak__10_oz_
# - T_G_I__FRIDAY_S_FRIDAY_S_Shrimp_breaded
# - T_G_I__FRIDAY_S_fried_mozzarella
# - T_G_I__FRIDAY_S_macaroni___cheese_from_kid_s_menu
# - Udi_s_Gluten_Free_Soft___Delicious_White_Sandwich_Bread
# - Uncooked_Buckwheat
# - Uncooked_Long-Grain_Brown_Rice
# - Uncooked_Medium-Grain_Brown_Rice
# - Uncooked_Oats
# - Uncooked_Whole-Grain_Cornmeal
# - Uncooked_Yellow_Cornmeal
# - Unsalted_Butter
# - Unsalted_Peanut_Butter__Smooth_
# - Unsweetened_Baking_Chocolate
# - Upside-Down_Pineapple_Cake
# - USDA_Commodity_Chicken_Canned_Meat_Only_Drained
# - USDA_Commodity_Chicken_Canned_Meat_Only_With_Broth
# - USDA_Commodity_Chicken_Canned_Meat_Only_With_Water
# - USDA_Commodity_Chicken_Fajita_Strips_Frozen
# - USDA_Commodity_Rice_Crisps__Includes_All_Commodity_Brands_
# - Vanilla_Soy_Milk
# - Veal_Australian_rib_rib_roast_separable_lean_and_fat_raw
# - Veal_Australian_rib_rib_roast_separable_lean_only_raw
# - Veal_Australian_shank_fore_bone-in_separable_lean_and_fat_raw
# - Veal_Australian_shank_fore_bone-in_separable_lean_only_raw
# - Veal_Australian_shank_hind_bone-in_separable_lean_and_fat_raw
# - Veal_Australian_shank_hind_bone-in_separable_lean_only_raw
# - Veal_Bratwurst
# - Veal_breast_plate_half_boneless_separable_lean_and_fat_cooked_braised
# - Veal_breast_point_half_boneless_separable_lean_and_fat_cooked_braised
# - Veal_breast_separable_fat_cooked
# - Veal_breast_whole_boneless_separable_lean_and_fat_cooked_braised
# - Veal_breast_whole_boneless_separable_lean_and_fat_raw
# - Veal_breast_whole_boneless_separable_lean_only_cooked_braised
# - Veal_composite_of_trimmed_retail_cuts_separable_fat_cooked
# - Veal_composite_of_trimmed_retail_cuts_separable_fat_raw
# - Veal_composite_of_trimmed_retail_cuts_separable_lean_and_fat_cooked
# - Veal_composite_of_trimmed_retail_cuts_separable_lean_and_fat_raw
# - Veal_composite_of_trimmed_retail_cuts_separable_lean_only_cooked
# - Veal_composite_of_trimmed_retail_cuts_separable_lean_only_raw
# - Veal_cubed_for_stew__leg_and_shoulder__separable_lean_only_cooked_braised
# - Veal_cubed_for_stew__leg_and_shoulder__separable_lean_only_raw
# - Veal_external_fat_only_cooked
# - Veal_external_fat_only_raw
# - Veal_foreshank_osso_buco_separable_lean_and_fat_cooked_braised
# - Veal_foreshank_osso_buco_separable_lean_only_cooked_braised
# - Veal_Ground__Minced__Cooked_Pan-Fried
# - Veal_leg_top_round_cap_off_cutlet_boneless_cooked_grilled
# - Veal_leg_top_round_cap_off_cutlet_boneless_raw
# - Veal_leg__top_round__separable_lean_and_fat_cooked_braised
# - Veal_leg__top_round__separable_lean_and_fat_cooked_pan-fried_breaded
# - Veal_leg__top_round__separable_lean_and_fat_cooked_pan-fried_not_breaded
# - Veal_leg__top_round__separable_lean_and_fat_cooked_roasted
# - Veal_leg__top_round__separable_lean_and_fat_raw
# - Veal_leg__top_round__separable_lean_only_cooked_pan-fried_breaded
# - Veal_leg__top_round__separable_lean_only_cooked_pan-fried_not_breaded
# - Veal_leg__top_round__separable_lean_only_cooked_roasted
# - Veal_leg__top_round__separable_lean_only_raw
# - Veal_loin_chop_separable_lean_and_fat_cooked_grilled
# - Veal_loin_chop_separable_lean_only_cooked_grilled
# - Veal_loin_separable_lean_and_fat_cooked_braised
# - Veal_loin_separable_lean_and_fat_cooked_roasted
# - Veal_loin_separable_lean_and_fat_raw
# - Veal_loin_separable_lean_only_cooked_braised
# - Veal_loin_separable_lean_only_cooked_roasted
# - Veal_loin_separable_lean_only_raw
# - Veal_rib_separable_lean_and_fat_cooked_braised
# - Veal_rib_separable_lean_and_fat_cooked_roasted
# - Veal_rib_separable_lean_and_fat_raw
# - Veal_rib_separable_lean_only_cooked_braised
# - Veal_rib_separable_lean_only_cooked_roasted
# - Veal_rib_separable_lean_only_raw
# - Veal_seam_fat_only_cooked
# - Veal_seam_fat_only_raw
# - Veal_shank_separable_lean_and_fat_raw
# - Veal_shank_separable_lean_only_raw
# - Veal_shank__fore_and_hind__separable_lean_and_fat_cooked_braised
# - Veal_shank__fore_and_hind__separable_lean_and_fat_raw
# - Veal_shank__fore_and_hind__separable_lean_only_cooked_braised
# - Veal_shank__fore_and_hind__separable_lean_only_raw
# - Veal_shoulder_arm_separable_lean_and_fat_cooked_braised
# - Veal_shoulder_arm_separable_lean_and_fat_cooked_roasted
# - Veal_shoulder_arm_separable_lean_and_fat_raw
# - Veal_shoulder_arm_separable_lean_only_cooked_braised
# - Veal_shoulder_arm_separable_lean_only_cooked_roasted
# - Veal_shoulder_arm_separable_lean_only_raw
# - Veal_shoulder_blade_chop_separable_lean_and_fat_cooked_grilled
# - Veal_shoulder_blade_chop_separable_lean_and_fat_raw
# - Veal_shoulder_blade_chop_separable_lean_only_cooked_grilled
# - Veal_shoulder_blade_chop_separable_lean_only_raw
# - Veal_shoulder_blade_separable_lean_and_fat_cooked_braised
# - Veal_shoulder_blade_separable_lean_and_fat_cooked_roasted
# - Veal_shoulder_blade_separable_lean_only_cooked_braised
# - Veal_shoulder_blade_separable_lean_only_cooked_roasted
# - Veal_shoulder_whole__arm_and_blade__separable_lean_and_fat_cooked_braised
# - Veal_shoulder_whole__arm_and_blade__separable_lean_and_fat_cooked_roasted
# - Veal_shoulder_whole__arm_and_blade__separable_lean_and_fat_raw
# - Veal_shoulder_whole__arm_and_blade__separable_lean_only_cooked_braised
# - Veal_shoulder_whole__arm_and_blade__separable_lean_only_cooked_roasted
# - Veal_shoulder_whole__arm_and_blade__separable_lean_only_raw
# - Veal_sirloin_separable_lean_and_fat_cooked_braised
# - Veal_sirloin_separable_lean_and_fat_cooked_roasted
# - Veal_sirloin_separable_lean_and_fat_raw
# - Veal_sirloin_separable_lean_only_cooked_braised
# - Veal_sirloin_separable_lean_only_cooked_roasted
# - Veal_sirloin_separable_lean_only_raw
# - Veal_variety_meats_and_by-products_brain_cooked_braised
# - Veal_variety_meats_and_by-products_brain_cooked_pan-fried
# - Veal_variety_meats_and_by-products_brain_raw
# - Veal_variety_meats_and_by-products_heart_cooked_braised
# - Veal_variety_meats_and_by-products_heart_raw
# - Veal_variety_meats_and_by-products_kidneys_cooked_braised
# - Veal_variety_meats_and_by-products_kidneys_raw
# - Veal_variety_meats_and_by-products_liver_cooked_braised
# - Veal_variety_meats_and_by-products_liver_cooked_pan-fried
# - Veal_variety_meats_and_by-products_liver_raw
# - Veal_variety_meats_and_by-products_tongue_cooked_braised
# - Veal_variety_meats_and_by-products_tongue_raw
# - Vega_-_Protein___Greens_Drink_Mix_Powder
# - Vega_-_Sport_Performance_Protein_Drink_Mix
# - Vega_-_Vega_Protein___Greens_Drink_Mix
# - Vega_-_Vega_Protein___Greens_Drink_Mix_Chocolate
# - Vega_-_Vega_Protein___Greens_Drink_Mix_Powder_Chocolate
# - Vega_-_Vega_Protein___Greens_Drink_Mix_Vanilla
# - Vega_-_Vega_Sport_Performance_Protein_Drink_Mix_Berry
# - Vegetables_mixed_canned_drained_solids
# - Vegetables_mixed_canned_solids_and_liquids
# - Vegetables_mixed_frozen_cooked_boiled_drained_without_salt
# - Vegetables_mixed_frozen_cooked_boiled_drained_with_salt
# - Vegetables_mixed_frozen_unprepared
# - Vegetable_juice_cocktail_canned
# - Vegetable_juice_cocktail_low_sodium_canned
# - Veggie__Soy__Burgers
# - Waffles_buttermilk_frozen_ready-to-heat
# - Waffles_chocolate_chip_frozen_ready-to-heat
# - Waffles_plain_frozen_ready-to-heat
# - Waffles_plain_frozen_ready_-to-heat_toasted
# - Waffles_plain_prepared_from_recipe
# - Waffle_buttermilk_frozen_ready-to-heat_toasted
# - Walnuts
# - Watermelon
# - WENDY_S_CLASSIC_DOUBLE_with_cheese
# - WENDY_S_CLASSIC_SINGLE_Hamburger_no_cheese
# - WENDY_S_CLASSIC_SINGLE_Hamburger_with_cheese
# - WENDY_S_DAVE_S_Hot__N_Juicy_1_4_LB_single
# - WENDY_S_Frosty_Dairy_Dessert
# - WENDY_S_Homestyle_Chicken_Fillet_Sandwich
# - WENDY_S_Jr__Hamburger_without_cheese
# - WENDY_S_Jr__Hamburger_with_cheese
# - WENDY_S_Ultimate_Chicken_Grill_Sandwich
# - Wheat_Bran_Bread
# - Wheat_bran_crude
# - Wheat_durum
# - Wheat_flours_bread_unenriched
# - Wheat_flour_white_all-purpose_enriched_bleached
# - Wheat_flour_white_all-purpose_enriched_calcium-fortified
# - Wheat_flour_white_all-purpose_self-rising_enriched
# - Wheat_flour_white_all-purpose_unenriched
# - Wheat_flour_white_bread_enriched
# - Wheat_flour_white_cake_enriched
# - Wheat_flour_white_tortilla_mix_enriched
# - Wheat_flour_white__industrial__10__protein_bleached_enriched
# - Wheat_flour_white__industrial__10__protein_bleached_unenriched
# - Wheat_flour_white__industrial__10__protein_unbleached_enriched
# - Wheat_flour_white__industrial__11_5__protein_bleached_enriched
# - Wheat_flour_white__industrial__11_5__protein_bleached_unenriched
# - Wheat_flour_white__industrial__11_5__protein_unbleached_enriched
# - Wheat_flour_white__industrial__13__protein_bleached_enriched
# - Wheat_flour_white__industrial__13__protein_bleached_unenriched
# - Wheat_flour_white__industrial__15__protein_bleached_enriched
# - Wheat_flour_white__industrial__15__protein_bleached_unenriched
# - Wheat_flour_white__industrial__9__protein_bleached_enriched
# - Wheat_flour_white__industrial__9__protein_bleached_unenriched
# - Wheat_germ_crude
# - Wheat_hard_red_spring
# - Wheat_hard_red_winter
# - Wheat_KAMUT_khorasan_uncooked
# - Wheat_Melba_Toast_Crackers
# - wheat_puffed_fortified
# - Wheat_sprouted
# - Whey_acid_fluid
# - Whipped_Butter__Salted_
# - Whipped_Cream
# - White_Cake_With_Coconut_Frosting
# - White_California_Grapefruit
# - White_Cornmeal__Grits_
# - White_Florida_Grapefruit
# - White_Grapefruit
# - Whole_Chicken__Roasted_meat_only_no_bones_or_skin_
# - Whole_Grain_Sorghum_Flour
# - Whole_Grain_Wheat_Flour
# - Whole_Milk__Full_Fat_
# - Whole_Roasted_Chicken__Meat_and_Skin_
# - Whole_Wheat_Pita
# - Wild_rice_raw
# - Winged_beans_mature_seeds_cooked_boiled_without_salt
# - Winged_beans_mature_seeds_cooked_boiled_with_salt
# - Winged_beans_mature_seeds_raw
# - Winged_bean_leaves_raw
# - Winged_bean_tuber_raw
# - Wonton_wrappers__includes_egg_roll_wrappers_
# - Yam_cooked_boiled_drained_or_baked_with_salt
# - Yardlong_beans_mature_seeds_cooked_boiled_without_salt
# - Yardlong_beans_mature_seeds_cooked_boiled_with_salt
# - Yardlong_beans_mature_seeds_raw
# - Yardlong_bean_cooked_boiled_drained_without_salt
# - Yardlong_bean_cooked_boiled_drained_with_salt
# - Yardlong_bean_raw
# - Yellow_Cake_With_Vanilla_Frosting
# - Yellow_Cornmeal__Grits_
# - Yellow_Mustard
# - Yellow_Peaches
# - Yogurt_fruit_lowfat_with_low_calorie_sweetener
# - Yogurt_fruit_lowfat_with_low_calorie_sweetener_fortified_with_vitamin_D
# - Yogurt_fruit_low_fat_10_grams_protein_per_8_ounce
# - Yogurt_Fruit_Low_Fat_11_Grams_Protein_Per_8_Ounce
# - Yogurt_Fruit_Low_Fat_9_Grams_Protein_Per_8_Ounce
# - Yogurt_fruit_low_fat_9_grams_protein_per_8_ounce_fortified_with_vitamin_D
# - Yogurt_fruit_variety_nonfat
# - Yogurt_fruit_variety_nonfat_fortified_with_vitamin_D
# - Yogurt_Greek_2_fat_coconut_blend_CHOBANI
# - Yogurt_Greek_2__fatmixed_berry_blend_CHOBANI
# - Yogurt_Greek_2__fat_apricot_CHOBANI
# - Yogurt_Greek_2__fat_key_lime_blend_CHOBANI
# - Yogurt_Greek_2__fat_mango_CHOBANI
# - Yogurt_Greek_2__fat_pineapple_CHOBANI
# - Yogurt_Greek_2__fat_strawberry_banana_CHOBANI
# - Yogurt_Greek_Blueberry_CHOBANI
# - Yogurt_Greek_nonfat_Fruit_on_Bottom_Blackberry_CHOBANI
# - Yogurt_Greek_nonfat_Fruit_on_Bottom_Pomegranate_CHOBANI
# - Yogurt_Greek_nonfat_Fruit_on_Bottom_Strawberry_CHOBANI
# - Yogurt_Greek_nonfat_lemon_blend_CHOBANI
# - Yogurt_Greek_nonfat_peach_CHOBANI
# - Yogurt_Greek_nonfat_plain_CHOBANI
# - Yogurt_Greek_nonfat_raspberry_CHOBANI
# - Yogurt_Greek_nonfat_vanilla_CHOBANI
# - Yogurt_Greek_whole_plain_CHOBANI
# - Yogurt_Vanilla_Low_Fat_11_Grams_Protein_Per_8_Ounce
# - Yogurt_vanilla_low_fat_fortified_with_vitamin_D
# - Yokan_prepared_from_adzuki_beans_and_sugar
# Total foods with an incomplete amino acid profile: 4984

# %%
import csv
import itertools

# Define essential amino acids and their required minimum values (in mg)
REQUIRED_AMINO_ACIDS = {
    "Histidine": 980,
    "Isoleucine": 1330,
    "Leucine": 2940,
    "Lysine": 2660,
    "Methionine": 1330,
    "Phenylalanine": 2310,
    "Threonine": 1400,
    "Tryptophan": 350,
    "Valine": 1680
}

# Read the food amino acids CSV file
file_path = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/food_amino_acids_cleaned.csv"
food_data = []

with open(file_path, mode="r", encoding="utf-8") as file:
    reader = csv.reader(file)
    header = next(reader)  # Read the header row

    # Get column indices of essential amino acids
    amino_acid_indices = {aa: header.index(aa) for aa in REQUIRED_AMINO_ACIDS.keys()}

    # Read each row (food item)
    for row in reader:
        food_name = row[0]
        amino_acid_values = {aa: float(row[amino_acid_indices[aa]]) for aa in REQUIRED_AMINO_ACIDS.keys()}
        food_data.append((food_name, amino_acid_values))

# Find up to 10 valid combinations
valid_combinations = []
for food1, food2 in itertools.combinations(food_data, 2):
    name1, amino_acids1 = food1
    name2, amino_acids2 = food2

    # Combine the amino acid values of the two foods
    combined_amino_acids = {aa: amino_acids1[aa] + amino_acids2[aa] for aa in REQUIRED_AMINO_ACIDS.keys()}

    # Check if the combination meets or exceeds all required amounts
    if all(combined_amino_acids[aa] >= REQUIRED_AMINO_ACIDS[aa] for aa in REQUIRED_AMINO_ACIDS.keys()):
        valid_combinations.append((name1, name2, combined_amino_acids))

        # Stop if we have found 10 combinations
        if len(valid_combinations) == 10000:
            break

#Print the results
if valid_combinations:
    print(f"Found {len(valid_combinations)} valid food combinations:\n")
    for i, (name1, name2, combined_amino_acids) in enumerate(valid_combinations, 1):
        print(f"Combination {i}: {name1} + {name2}")
        for aa, value in combined_amino_acids.items():
            print(f"  {aa}: {value:.2f} mg")
        print("\n" + "-" * 40 + "\n")
else:
    print("No valid food combinations found.")
#print(len(valid_combinations))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#   Histidine: 1529.00 mg
#   Isoleucine: 4814.00 mg
#   Leucine: 8170.00 mg
#   Lysine: 7001.00 mg
#   Methionine: 1646.00 mg
#   Phenylalanine: 2588.00 mg
#   Threonine: 5737.00 mg
#   Tryptophan: 1090.00 mg
#   Valine: 4319.00 mg
#
# ----------------------------------------
#
# Combination 8972: Beans_french_mature_seeds_cooked_boiled_without_salt + Seal_bearded__Oogruk__meat_dried__Alaska_Native_
#   Histidine: 3143.00 mg
#   Isoleucine: 3445.00 mg
#   Leucine: 6949.00 mg
#   Lysine: 7174.00 mg
#   Methionine: 1790.00 mg
#   Phenylalanine: 3656.00 mg
#   Threonine: 3525.00 mg
#   Tryptophan: 878.00 mg
#   Valine: 3597.00 mg
#
# ----------------------------------------
#
# Combination 8973: Beans_french_mature_seeds_cooked_boiled_without_salt + Seal_bearded__Oogruk__meat_partially_dried__Alaska_Native_
#   Histidine: 2422.00 mg
#   Isoleucine: 2678.00 mg
#   Leucine: 5385.00 mg
#   Lysine: 5536.00 mg
#   Methionine: 1378.00 mg
#   Phenylalanine: 2854.00 mg
#   Threonine: 2735.00 mg
#   Tryptophan: 684.00 mg
#   Valine: 2807.00 mg
#
# ----------------------------------------
#
# Combination 8974: Beans_french_mature_seeds_cooked_boiled_without_salt + Smelt_dried__Alaska_Native_
#   Histidine: 1206.00 mg
#   Isoleucine: 2461.00 mg
#   Leucine: 4383.00 mg
#   Lysine: 4174.00 mg
#   Methionine: 1346.00 mg
#   Phenylalanine: 2391.00 mg
#   Threonine: 2687.00 mg
#   Tryptophan: 593.00 mg
#   Valine: 3029.00 mg
#
# ----------------------------------------
#
# Combination 8975: Beans_french_mature_seeds_cooked_boiled_without_salt + Soup_Swanson_Chicken_Broth_99__Fat_Free
#   Histidine: 10196.00 mg
#   Isoleucine: 7311.00 mg
#   Leucine: 14563.00 mg
#   Lysine: 19484.00 mg
#   Methionine: 7106.00 mg
#   Phenylalanine: 7381.00 mg
#   Threonine: 7297.00 mg
#   Tryptophan: 7083.00 mg
#   Valine: 7369.00 mg
#
# ----------------------------------------
#
# Combination 8976: Beans_french_mature_seeds_cooked_boiled_without_salt + Tangerine_Juice_Canned_Sweetened
#   Histidine: 2202.45 mg
#   Isoleucine: 5327.13 mg
#   Leucine: 10595.26 mg
#   Lysine: 7506.58 mg
#   Methionine: 2112.45 mg
#   Phenylalanine: 6400.35 mg
#   Threonine: 6316.35 mg
#   Tryptophan: 1086.23 mg
#   Valine: 8394.81 mg
#
# ----------------------------------------
#
# Combination 8977: Beans_french_mature_seeds_cooked_boiled_without_salt + Vital_wheat_gluten
#   Histidine: 1996.00 mg
#   Isoleucine: 3311.00 mg
#   Leucine: 7363.00 mg
#   Lysine: 3284.00 mg
#   Methionine: 2006.00 mg
#   Phenylalanine: 4781.00 mg
#   Threonine: 2897.00 mg
#   Tryptophan: 1383.00 mg
#   Valine: 4869.00 mg
#
# ----------------------------------------
#
# Combination 8978: Beans_french_mature_seeds_cooked_boiled_without_salt + Whale_beluga_meat_dried__Alaska_Native_
#   Histidine: 3195.00 mg
#   Isoleucine: 2995.00 mg
#   Leucine: 6341.00 mg
#   Lysine: 6797.00 mg
#   Methionine: 1459.00 mg
#   Phenylalanine: 3328.00 mg
#   Threonine: 3023.00 mg
#   Tryptophan: 880.00 mg
#   Valine: 3179.00 mg
#
# ----------------------------------------
#
# Combination 8979: Beans_french_mature_seeds_cooked_boiled_with_salt + Cream_Of_Rice_Cooked_With_Water_Without_Salt
#   Histidine: 26196.00 mg
#   Isoleucine: 15311.00 mg
#   Leucine: 73563.00 mg
#   Lysine: 37484.00 mg
#   Methionine: 26106.00 mg
#   Phenylalanine: 37381.00 mg
#   Threonine: 44297.00 mg
#   Tryptophan: 13083.00 mg
#   Valine: 57369.00 mg
#
# ----------------------------------------
#
# Combination 8980: Beans_french_mature_seeds_cooked_boiled_with_salt + Dried_Eggs
#   Histidine: 1396.00 mg
#   Isoleucine: 2751.00 mg
#   Leucine: 4723.00 mg
#   Lysine: 3824.00 mg
#   Methionine: 1606.00 mg
#   Phenylalanine: 2921.00 mg
#   Threonine: 2417.00 mg
#   Tryptophan: 863.00 mg
#   Valine: 3369.00 mg
#
# ----------------------------------------
#
# Combination 8981: Beans_french_mature_seeds_cooked_boiled_with_salt + Dried_Salted_Atlantic_Cod
#   Histidine: 2044.75 mg
#   Isoleucine: 3206.00 mg
#   Leucine: 5669.25 mg
#   Lysine: 6252.75 mg
#   Methionine: 1964.75 mg
#   Phenylalanine: 2833.50 mg
#   Threonine: 3050.75 mg
#   Tryptophan: 786.75 mg
#   Valine: 3605.25 mg
#
# ----------------------------------------
#
# Combination 8982: Beans_french_mature_seeds_cooked_boiled_with_salt + Egg_white_dried
#   Histidine: 2026.00 mg
#   Isoleucine: 4892.00 mg
#   Leucine: 7401.00 mg
#   Lysine: 5999.00 mg
#   Methionine: 2896.00 mg
#   Phenylalanine: 5117.00 mg
#   Threonine: 3982.00 mg
#   Tryptophan: 1082.00 mg
#   Valine: 5533.00 mg
#
# ----------------------------------------
#
# Combination 8983: Beans_french_mature_seeds_cooked_boiled_with_salt + Egg_white_dried_flakes_stabilized_glucose_reduced
#   Histidine: 1944.02 mg
#   Isoleucine: 4999.99 mg
#   Leucine: 7258.15 mg
#   Lysine: 5221.89 mg
#   Methionine: 3097.19 mg
#   Phenylalanine: 5218.00 mg
#   Threonine: 3718.15 mg
#   Tryptophan: 1264.06 mg
#   Valine: 6128.91 mg
#
# ----------------------------------------
#
# Combination 8984: Beans_french_mature_seeds_cooked_boiled_with_salt + Egg_white_dried_powder_stabilized_glucose_reduced
#   Histidine: 2067.43 mg
#   Isoleucine: 5339.57 mg
#   Leucine: 7734.43 mg
#   Lysine: 5555.43 mg
#   Methionine: 3306.00 mg
#   Phenylalanine: 5566.71 mg
#   Threonine: 3968.43 mg
#   Tryptophan: 1354.43 mg
#   Valine: 6540.43 mg
#
# ----------------------------------------
#
# Combination 8985: Beans_french_mature_seeds_cooked_boiled_with_salt + Egg_White_Powder
#   Histidine: 2253.14 mg
#   Isoleucine: 4725.29 mg
#   Leucine: 7920.14 mg
#   Lysine: 6384.00 mg
#   Methionine: 3091.71 mg
#   Phenylalanine: 5509.57 mg
#   Threonine: 3925.57 mg
#   Tryptophan: 1511.57 mg
#   Valine: 6097.57 mg
#
# ----------------------------------------
#
# Combination 8986: Beans_french_mature_seeds_cooked_boiled_with_salt + Egg_whole_dried_stabilized_glucose_reduced
#   Histidine: 1356.00 mg
#   Isoleucine: 3331.00 mg
#   Leucine: 4803.00 mg
#   Lysine: 3744.00 mg
#   Methionine: 1666.00 mg
#   Phenylalanine: 3101.00 mg
#   Threonine: 2657.00 mg
#   Tryptophan: 863.00 mg
#   Valine: 3829.00 mg
#
# ----------------------------------------
#
# Combination 8987: Beans_french_mature_seeds_cooked_boiled_with_salt + Fish_whitefish_dried__Alaska_Native_
#   Histidine: 1496.00 mg
#   Isoleucine: 2571.00 mg
#   Leucine: 4673.00 mg
#   Lysine: 5254.00 mg
#   Methionine: 1846.00 mg
#   Phenylalanine: 2721.00 mg
#   Threonine: 2767.00 mg
#   Tryptophan: 663.00 mg
#   Valine: 2979.00 mg
#
# ----------------------------------------
#
# Combination 8988: Beans_french_mature_seeds_cooked_boiled_with_salt + Growing_Naturals_-_Brown_Rice_Protein_Powder
#   Histidine: 1861.00 mg
#   Isoleucine: 3367.00 mg
#   Leucine: 6592.00 mg
#   Lysine: 2763.00 mg
#   Methionine: 2047.00 mg
#   Phenylalanine: 4425.00 mg
#   Threonine: 2888.00 mg
#   Tryptophan: 1136.00 mg
#   Valine: 4669.00 mg
#
# ----------------------------------------
#
# Combination 8989: Beans_french_mature_seeds_cooked_boiled_with_salt + Nutribiotic_Systems_-_Rice_Protein
#   Histidine: 1740.00 mg
#   Isoleucine: 4324.00 mg
#   Leucine: 6819.00 mg
#   Lysine: 4003.00 mg
#   Methionine: 1687.00 mg
#   Phenylalanine: 3394.00 mg
#   Threonine: 3560.00 mg
#   Tryptophan: 1152.00 mg
#   Valine: 4507.00 mg
#
# ----------------------------------------
#
# Combination 8990: Beans_french_mature_seeds_cooked_boiled_with_salt + Primal_Nutrition_-_Chocolate_Coconut_Primal_Fuel_Low-Carb_Meal_Replacement_Shake
#   Histidine: 1101.00 mg
#   Isoleucine: 3430.00 mg
#   Leucine: 5420.00 mg
#   Lysine: 4294.00 mg
#   Methionine: 2225.00 mg
#   Phenylalanine: 3119.00 mg
#   Threonine: 3773.00 mg
#   Tryptophan: 916.00 mg
#   Valine: 3107.00 mg
#
# ----------------------------------------
#
# Combination 8991: Beans_french_mature_seeds_cooked_boiled_with_salt + Rexall_Sundown_Inc__-_Engineered_Nutrition_Meal_Replacement
#   Histidine: 1543.00 mg
#   Isoleucine: 2560.00 mg
#   Leucine: 4775.00 mg
#   Lysine: 4089.00 mg
#   Methionine: 1374.00 mg
#   Phenylalanine: 2605.00 mg
#   Threonine: 2304.00 mg
#   Tryptophan: 591.00 mg
#   Valine: 3224.00 mg
#
# ----------------------------------------
#
# Combination 8992: Beans_french_mature_seeds_cooked_boiled_with_salt + Rexall_Sundown_Inc__-_Meal_Replacement_Protein_Powder
#   Histidine: 1486.00 mg
#   Isoleucine: 2779.00 mg
#   Leucine: 5028.00 mg
#   Lysine: 4295.00 mg
#   Methionine: 1391.00 mg
#   Phenylalanine: 2798.00 mg
#   Threonine: 2561.00 mg
#   Tryptophan: 673.00 mg
#   Valine: 3479.00 mg
#
# ----------------------------------------
#
# Combination 8993: Beans_french_mature_seeds_cooked_boiled_with_salt + Rexall_Sundown_Inc__-_Whey_Protein_Powder
#   Histidine: 1529.00 mg
#   Isoleucine: 4814.00 mg
#   Leucine: 8170.00 mg
#   Lysine: 7001.00 mg
#   Methionine: 1646.00 mg
#   Phenylalanine: 2588.00 mg
#   Threonine: 5737.00 mg
#   Tryptophan: 1090.00 mg
#   Valine: 4319.00 mg
#
# ----------------------------------------
#
# Combination 8994: Beans_french_mature_seeds_cooked_boiled_with_salt + Seal_bearded__Oogruk__meat_dried__Alaska_Native_
#   Histidine: 3143.00 mg
#   Isoleucine: 3445.00 mg
#   Leucine: 6949.00 mg
#   Lysine: 7174.00 mg
#   Methionine: 1790.00 mg
#   Phenylalanine: 3656.00 mg
#   Threonine: 3525.00 mg
#   Tryptophan: 878.00 mg
#   Valine: 3597.00 mg
#
# ----------------------------------------
#
# Combination 8995: Beans_french_mature_seeds_cooked_boiled_with_salt + Seal_bearded__Oogruk__meat_partially_dried__Alaska_Native_
#   Histidine: 2422.00 mg
#   Isoleucine: 2678.00 mg
#   Leucine: 5385.00 mg
#   Lysine: 5536.00 mg
#   Methionine: 1378.00 mg
#   Phenylalanine: 2854.00 mg
#   Threonine: 2735.00 mg
#   Tryptophan: 684.00 mg
#   Valine: 2807.00 mg
#
# ----------------------------------------
#
# Combination 8996: Beans_french_mature_seeds_cooked_boiled_with_salt + Smelt_dried__Alaska_Native_
#   Histidine: 1206.00 mg
#   Isoleucine: 2461.00 mg
#   Leucine: 4383.00 mg
#   Lysine: 4174.00 mg
#   Methionine: 1346.00 mg
#   Phenylalanine: 2391.00 mg
#   Threonine: 2687.00 mg
#   Tryptophan: 593.00 mg
#   Valine: 3029.00 mg
#
# ----------------------------------------
#
# Combination 8997: Beans_french_mature_seeds_cooked_boiled_with_salt + Soup_Swanson_Chicken_Broth_99__Fat_Free
#   Histidine: 10196.00 mg
#   Isoleucine: 7311.00 mg
#   Leucine: 14563.00 mg
#   Lysine: 19484.00 mg
#   Methionine: 7106.00 mg
#   Phenylalanine: 7381.00 mg
#   Threonine: 7297.00 mg
#   Tryptophan: 7083.00 mg
#   Valine: 7369.00 mg
#
# ----------------------------------------
#
# Combination 8998: Beans_french_mature_seeds_cooked_boiled_with_salt + Tangerine_Juice_Canned_Sweetened
#   Histidine: 2202.45 mg
#   Isoleucine: 5327.13 mg
#   Leucine: 10595.26 mg
#   Lysine: 7506.58 mg
#   Methionine: 2112.45 mg
#   Phenylalanine: 6400.35 mg
#   Threonine: 6316.35 mg
#   Tryptophan: 1086.23 mg
#   Valine: 8394.81 mg
#
# ----------------------------------------
#
# Combination 8999: Beans_french_mature_seeds_cooked_boiled_with_salt + Vital_wheat_gluten
#   Histidine: 1996.00 mg
#   Isoleucine: 3311.00 mg
#   Leucine: 7363.00 mg
#   Lysine: 3284.00 mg
#   Methionine: 2006.00 mg
#   Phenylalanine: 4781.00 mg
#   Threonine: 2897.00 mg
#   Tryptophan: 1383.00 mg
#   Valine: 4869.00 mg
#
# ----------------------------------------
#
# Combination 9000: Beans_french_mature_seeds_cooked_boiled_with_salt + Whale_beluga_meat_dried__Alaska_Native_
#   Histidine: 3195.00 mg
#   Isoleucine: 2995.00 mg
#   Leucine: 6341.00 mg
#   Lysine: 6797.00 mg
#   Methionine: 1459.00 mg
#   Phenylalanine: 3328.00 mg
#   Threonine: 3023.00 mg
#   Tryptophan: 880.00 mg
#   Valine: 3179.00 mg
#
# ----------------------------------------
#
# Combination 9001: Beans_french_mature_seeds_raw + Beef_New_Zealand_imported_bolar_blade_separable_lean_only_cooked_fast_roasted
#   Histidine: 1732.00 mg
#   Isoleucine: 2225.00 mg
#   Leucine: 4031.00 mg
#   Lysine: 3945.00 mg
#   Methionine: 1386.00 mg
#   Phenylalanine: 2320.00 mg
#   Threonine: 2006.00 mg
#   Tryptophan: 574.00 mg
#   Valine: 2464.00 mg
#
# ----------------------------------------
#
# Combination 9002: Beans_french_mature_seeds_raw + Beef_New_Zealand_imported_brisket_point_end_separable_lean_only_cooked_braised
#   Histidine: 1767.00 mg
#   Isoleucine: 2266.00 mg
#   Leucine: 4106.00 mg
#   Lysine: 4023.00 mg
#   Methionine: 1418.00 mg
#   Phenylalanine: 2359.00 mg
#   Threonine: 2042.00 mg
#   Tryptophan: 585.00 mg
#   Valine: 2507.00 mg
#
# ----------------------------------------
#
# Combination 9003: Beans_french_mature_seeds_raw + Cooked_Whelk
#   Histidine: 1501.00 mg
#   Isoleucine: 2486.00 mg
#   Leucine: 5309.00 mg
#   Lysine: 4221.00 mg
#   Methionine: 1488.00 mg
#   Phenylalanine: 2665.00 mg
#   Threonine: 2928.00 mg
#   Tryptophan: 841.00 mg
#   Valine: 3059.00 mg
#
# ----------------------------------------
#
# Combination 9004: Beans_french_mature_seeds_raw + Cream_Of_Rice_Cooked_With_Water_Without_Salt
#   Histidine: 26524.00 mg
#   Isoleucine: 15831.00 mg
#   Leucine: 74502.00 mg
#   Lysine: 38291.00 mg
#   Methionine: 26283.00 mg
#   Phenylalanine: 38017.00 mg
#   Threonine: 44792.00 mg
#   Tryptophan: 13223.00 mg
#   Valine: 57984.00 mg
#
# ----------------------------------------
#
# Combination 9005: Beans_french_mature_seeds_raw + Dried_Eggs
#   Histidine: 1724.00 mg
#   Isoleucine: 3271.00 mg
#   Leucine: 5662.00 mg
#   Lysine: 4631.00 mg
#   Methionine: 1783.00 mg
#   Phenylalanine: 3557.00 mg
#   Threonine: 2912.00 mg
#   Tryptophan: 1003.00 mg
#   Valine: 3984.00 mg
#
# ----------------------------------------
#
# Combination 9006: Beans_french_mature_seeds_raw + Dried_Salted_Atlantic_Cod
#   Histidine: 2372.75 mg
#   Isoleucine: 3726.00 mg
#   Leucine: 6608.25 mg
#   Lysine: 7059.75 mg
#   Methionine: 2141.75 mg
#   Phenylalanine: 3469.50 mg
#   Threonine: 3545.75 mg
#   Tryptophan: 926.75 mg
#   Valine: 4220.25 mg
#
# ----------------------------------------
#
# Combination 9007: Beans_french_mature_seeds_raw + Dried_Spirulina
#   Histidine: 1609.71 mg
#   Isoleucine: 4045.29 mg
#   Leucine: 6444.86 mg
#   Lysine: 4319.57 mg
#   Methionine: 1425.86 mg
#   Phenylalanine: 3788.43 mg
#   Threonine: 3763.43 mg
#   Tryptophan: 1151.57 mg
#   Valine: 4498.29 mg
#
# ----------------------------------------
#
# Combination 9008: Beans_french_mature_seeds_raw + Egg_Mix_USDA_Commodity
#   Histidine: 1400.19 mg
#   Isoleucine: 2769.10 mg
#   Leucine: 4814.38 mg
#   Lysine: 5199.57 mg
#   Methionine: 1725.86 mg
#   Phenylalanine: 2919.86 mg
#   Threonine: 2203.43 mg
#   Tryptophan: 623.00 mg
#   Valine: 3297.33 mg
#
# ----------------------------------------
#
# Combination 9009: Beans_french_mature_seeds_raw + Egg_white_dried
#   Histidine: 2354.00 mg
#   Isoleucine: 5412.00 mg
#   Leucine: 8340.00 mg
#   Lysine: 6806.00 mg
#   Methionine: 3073.00 mg
#   Phenylalanine: 5753.00 mg
#   Threonine: 4477.00 mg
#   Tryptophan: 1222.00 mg
#   Valine: 6148.00 mg
#
# ----------------------------------------
#
# Combination 9010: Beans_french_mature_seeds_raw + Egg_white_dried_flakes_stabilized_glucose_reduced
#   Histidine: 2272.02 mg
#   Isoleucine: 5519.99 mg
#   Leucine: 8197.15 mg
#   Lysine: 6028.89 mg
#   Methionine: 3274.19 mg
#   Phenylalanine: 5854.00 mg
#   Threonine: 4213.15 mg
#   Tryptophan: 1404.06 mg
#   Valine: 6743.91 mg
#
# ----------------------------------------
#
# Combination 9011: Beans_french_mature_seeds_raw + Egg_white_dried_powder_stabilized_glucose_reduced
#   Histidine: 2395.43 mg
#   Isoleucine: 5859.57 mg
#   Leucine: 8673.43 mg
#   Lysine: 6362.43 mg
#   Methionine: 3483.00 mg
#   Phenylalanine: 6202.71 mg
#   Threonine: 4463.43 mg
#   Tryptophan: 1494.43 mg
#   Valine: 7155.43 mg
#
# ----------------------------------------
#
# Combination 9012: Beans_french_mature_seeds_raw + Egg_White_Powder
#   Histidine: 2581.14 mg
#   Isoleucine: 5245.29 mg
#   Leucine: 8859.14 mg
#   Lysine: 7191.00 mg
#   Methionine: 3268.71 mg
#   Phenylalanine: 6145.57 mg
#   Threonine: 4420.57 mg
#   Tryptophan: 1651.57 mg
#   Valine: 6712.57 mg
#
# ----------------------------------------
#
# Combination 9013: Beans_french_mature_seeds_raw + Egg_whole_dried_stabilized_glucose_reduced
#   Histidine: 1684.00 mg
#   Isoleucine: 3851.00 mg
#   Leucine: 5742.00 mg
#   Lysine: 4551.00 mg
#   Methionine: 1843.00 mg
#   Phenylalanine: 3737.00 mg
#   Threonine: 3152.00 mg
#   Tryptophan: 1003.00 mg
#   Valine: 4444.00 mg
#
# ----------------------------------------
#
# Combination 9014: Beans_french_mature_seeds_raw + Fish_whitefish_dried__Alaska_Native_
#   Histidine: 1824.00 mg
#   Isoleucine: 3091.00 mg
#   Leucine: 5612.00 mg
#   Lysine: 6061.00 mg
#   Methionine: 2023.00 mg
#   Phenylalanine: 3357.00 mg
#   Threonine: 3262.00 mg
#   Tryptophan: 803.00 mg
#   Valine: 3594.00 mg
#
# ----------------------------------------
#
# Combination 9015: Beans_french_mature_seeds_raw + Growing_Naturals_-_Brown_Rice_Protein_Powder
#   Histidine: 2189.00 mg
#   Isoleucine: 3887.00 mg
#   Leucine: 7531.00 mg
#   Lysine: 3570.00 mg
#   Methionine: 2224.00 mg
#   Phenylalanine: 5061.00 mg
#   Threonine: 3383.00 mg
#   Tryptophan: 1276.00 mg
#   Valine: 5284.00 mg
#
# ----------------------------------------
#
# Combination 9016: Beans_french_mature_seeds_raw + Lamb_New_Zealand_imported_fore-shank_separable_lean_only_cooked_braised
#   Histidine: 1229.00 mg
#   Isoleucine: 2322.00 mg
#   Leucine: 4075.00 mg
#   Lysine: 4200.00 mg
#   Methionine: 1370.00 mg
#   Phenylalanine: 2329.00 mg
#   Threonine: 2381.00 mg
#   Tryptophan: 591.00 mg
#   Valine: 2680.00 mg
#
# ----------------------------------------
#
# Combination 9017: Beans_french_mature_seeds_raw + Nutribiotic_Systems_-_Rice_Protein
#   Histidine: 2068.00 mg
#   Isoleucine: 4844.00 mg
#   Leucine: 7758.00 mg
#   Lysine: 4810.00 mg
#   Methionine: 1864.00 mg
#   Phenylalanine: 4030.00 mg
#   Threonine: 4055.00 mg
#   Tryptophan: 1292.00 mg
#   Valine: 5122.00 mg
#
# ----------------------------------------
#
# Combination 9018: Beans_french_mature_seeds_raw + Pork_cured_bacon_cooked_microwaved
#   Histidine: 2109.71 mg
#   Isoleucine: 2677.43 mg
#   Leucine: 4712.71 mg
#   Lysine: 4762.43 mg
#   Methionine: 1350.86 mg
#   Phenylalanine: 2638.43 mg
#   Threonine: 2506.29 mg
#   Tryptophan: 687.29 mg
#   Valine: 2955.43 mg
#
# ----------------------------------------
#
# Combination 9019: Beans_french_mature_seeds_raw + Prevention_LLC_-_Naturade_Grass_Fed_Whey_Protein_Booster_Chocolate
#   Histidine: 1405.00 mg
#   Isoleucine: 3902.00 mg
#   Leucine: 6526.00 mg
#   Lysine: 5386.00 mg
#   Methionine: 1426.00 mg
#   Phenylalanine: 2612.00 mg
#   Threonine: 4030.00 mg
#   Tryptophan: 1152.00 mg
#   Valine: 3794.00 mg
#
# ----------------------------------------
#
# Combination 9020: Beans_french_mature_seeds_raw + Prevention_llc_-_NATURADE_WHEY_PROTEIN_BOOSTER_VANILLA_VANILLA
#   Histidine: 1498.00 mg
#   Isoleucine: 4199.00 mg
#   Leucine: 7002.00 mg
#   Lysine: 5817.00 mg
#   Methionine: 1546.00 mg
#   Phenylalanine: 2701.00 mg
#   Threonine: 4345.00 mg
#   Tryptophan: 1223.00 mg
#   Valine: 3079931.00 mg
#
# ----------------------------------------
#
# Combination 9021: Beans_french_mature_seeds_raw + Primal_Nutrition_-_Chocolate_Coconut_Primal_Fuel_Low-Carb_Meal_Replacement_Shake
#   Histidine: 1429.00 mg
#   Isoleucine: 3950.00 mg
#   Leucine: 6359.00 mg
#   Lysine: 5101.00 mg
#   Methionine: 2402.00 mg
#   Phenylalanine: 3755.00 mg
#   Threonine: 4268.00 mg
#   Tryptophan: 1056.00 mg
#   Valine: 3722.00 mg
#
# ----------------------------------------
#
# Combination 9022: Beans_french_mature_seeds_raw + Rexall_Sundown_Inc__-_Engineered_Nutrition_Meal_Replacement
#   Histidine: 1871.00 mg
#   Isoleucine: 3080.00 mg
#   Leucine: 5714.00 mg
#   Lysine: 4896.00 mg
#   Methionine: 1551.00 mg
#   Phenylalanine: 3241.00 mg
#   Threonine: 2799.00 mg
#   Tryptophan: 731.00 mg
#   Valine: 3839.00 mg
#
# ----------------------------------------
#
# Combination 9023: Beans_french_mature_seeds_raw + Rexall_Sundown_Inc__-_Meal_Replacement_Protein_Powder
#   Histidine: 1814.00 mg
#   Isoleucine: 3299.00 mg
#   Leucine: 5967.00 mg
#   Lysine: 5102.00 mg
#   Methionine: 1568.00 mg
#   Phenylalanine: 3434.00 mg
#   Threonine: 3056.00 mg
#   Tryptophan: 813.00 mg
#   Valine: 4094.00 mg
#
# ----------------------------------------
#
# Combination 9024: Beans_french_mature_seeds_raw + Rexall_Sundown_Inc__-_Whey_Protein_Powder
#   Histidine: 1857.00 mg
#   Isoleucine: 5334.00 mg
#   Leucine: 9109.00 mg
#   Lysine: 7808.00 mg
#   Methionine: 1823.00 mg
#   Phenylalanine: 3224.00 mg
#   Threonine: 6232.00 mg
#   Tryptophan: 1230.00 mg
#   Valine: 4934.00 mg
#
# ----------------------------------------
#
# Combination 9025: Beans_french_mature_seeds_raw + Seal_bearded__Oogruk__meat_dried__Alaska_Native_
#   Histidine: 3471.00 mg
#   Isoleucine: 3965.00 mg
#   Leucine: 7888.00 mg
#   Lysine: 7981.00 mg
#   Methionine: 1967.00 mg
#   Phenylalanine: 4292.00 mg
#   Threonine: 4020.00 mg
#   Tryptophan: 1018.00 mg
#   Valine: 4212.00 mg
#
# ----------------------------------------
#
# Combination 9026: Beans_french_mature_seeds_raw + Seal_bearded__Oogruk__meat_partially_dried__Alaska_Native_
#   Histidine: 2750.00 mg
#   Isoleucine: 3198.00 mg
#   Leucine: 6324.00 mg
#   Lysine: 6343.00 mg
#   Methionine: 1555.00 mg
#   Phenylalanine: 3490.00 mg
#   Threonine: 3230.00 mg
#   Tryptophan: 824.00 mg
#   Valine: 3422.00 mg
#
# ----------------------------------------
#
# Combination 9027: Beans_french_mature_seeds_raw + Seeds_sesame_flour_low-fat
#   Histidine: 2000.00 mg
#   Isoleucine: 2988.00 mg
#   Leucine: 5343.00 mg
#   Lysine: 2899.00 mg
#   Methionine: 1939.00 mg
#   Phenylalanine: 3675.00 mg
#   Threonine: 2873.00 mg
#   Tryptophan: 1320.00 mg
#   Valine: 3784.00 mg
#
# ----------------------------------------
#
# Combination 9028: Beans_french_mature_seeds_raw + Seeds_sunflower_seed_flour_partially_defatted
#   Histidine: 1849.00 mg
#   Isoleucine: 3231.00 mg
#   Leucine: 5002.00 mg
#   Lysine: 3266.00 mg
#   Methionine: 1333.00 mg
#   Phenylalanine: 3492.00 mg
#   Threonine: 2742.00 mg
#   Tryptophan: 948.00 mg
#   Valine: 3759.00 mg
#
# ----------------------------------------
#
# Combination 9029: Beans_french_mature_seeds_raw + Shredded_Parmesan
#   Histidine: 2133.00 mg
#   Isoleucine: 3033.00 mg
#   Leucine: 5515.00 mg
#   Lysine: 5134.00 mg
#   Methionine: 1397.00 mg
#   Phenylalanine: 3251.00 mg
#   Threonine: 2323.00 mg
#   Tryptophan: 783.00 mg
#   Valine: 3837.00 mg
#
# ----------------------------------------
#
# Combination 9030: Beans_french_mature_seeds_raw + Smelt_dried__Alaska_Native_
#   Histidine: 1534.00 mg
#   Isoleucine: 2981.00 mg
#   Leucine: 5322.00 mg
#   Lysine: 4981.00 mg
#   Methionine: 1523.00 mg
#   Phenylalanine: 3027.00 mg
#   Threonine: 3182.00 mg
#   Tryptophan: 733.00 mg
#   Valine: 3644.00 mg
#
# ----------------------------------------
#
# Combination 9031: Beans_french_mature_seeds_raw + Soup_Swanson_Chicken_Broth_99__Fat_Free
#   Histidine: 10524.00 mg
#   Isoleucine: 7831.00 mg
#   Leucine: 15502.00 mg
#   Lysine: 20291.00 mg
#   Methionine: 7283.00 mg
#   Phenylalanine: 8017.00 mg
#   Threonine: 7792.00 mg
#   Tryptophan: 7223.00 mg
#   Valine: 7984.00 mg
#
# ----------------------------------------
#
# Combination 9032: Beans_french_mature_seeds_raw + Soy_protein_isolate_potassium_type
#   Histidine: 2827.00 mg
#   Isoleucine: 5084.00 mg
#   Leucine: 8285.00 mg
#   Lysine: 6618.00 mg
#   Methionine: 1413.00 mg
#   Phenylalanine: 5610.00 mg
#   Threonine: 3929.00 mg
#   Tryptophan: 1339.00 mg
#   Valine: 5082.00 mg
#
# ----------------------------------------
#
# Combination 9033: Beans_french_mature_seeds_raw + Soy_Protein_Powder__Isolate_
#   Histidine: 2827.00 mg
#   Isoleucine: 5084.00 mg
#   Leucine: 8285.00 mg
#   Lysine: 6618.00 mg
#   Methionine: 1413.00 mg
#   Phenylalanine: 5610.00 mg
#   Threonine: 3929.00 mg
#   Tryptophan: 1339.00 mg
#   Valine: 5082.00 mg
#
# ----------------------------------------
#
# Combination 9034: Beans_french_mature_seeds_raw + Tangerine_Juice_Canned_Sweetened
#   Histidine: 2530.45 mg
#   Isoleucine: 5847.13 mg
#   Leucine: 11534.26 mg
#   Lysine: 8313.58 mg
#   Methionine: 2289.45 mg
#   Phenylalanine: 7036.35 mg
#   Threonine: 6811.35 mg
#   Tryptophan: 1226.23 mg
#   Valine: 9009.81 mg
#
# ----------------------------------------
#
# Combination 9035: Beans_french_mature_seeds_raw + Vital_wheat_gluten
#   Histidine: 2324.00 mg
#   Isoleucine: 3831.00 mg
#   Leucine: 8302.00 mg
#   Lysine: 4091.00 mg
#   Methionine: 2183.00 mg
#   Phenylalanine: 5417.00 mg
#   Threonine: 3392.00 mg
#   Tryptophan: 1523.00 mg
#   Valine: 5484.00 mg
#
# ----------------------------------------
#
# Combination 9036: Beans_french_mature_seeds_raw + Whale_beluga_meat_dried__Alaska_Native_
#   Histidine: 3523.00 mg
#   Isoleucine: 3515.00 mg
#   Leucine: 7280.00 mg
#   Lysine: 7604.00 mg
#   Methionine: 1636.00 mg
#   Phenylalanine: 3964.00 mg
#   Threonine: 3518.00 mg
#   Tryptophan: 1020.00 mg
#   Valine: 3794.00 mg
#
# ----------------------------------------
#
# Combination 9037: Beans_great_northern_mature_seeds_canned + Cream_Of_Rice_Cooked_With_Water_Without_Salt
#   Histidine: 26202.00 mg
#   Isoleucine: 15349.00 mg
#   Leucine: 73626.00 mg
#   Lysine: 37516.00 mg
#   Methionine: 26096.00 mg
#   Phenylalanine: 37435.00 mg
#   Threonine: 44271.00 mg
#   Tryptophan: 13088.00 mg
#   Valine: 57425.00 mg
#
# ----------------------------------------
#
# Combination 9038: Beans_great_northern_mature_seeds_canned + Dried_Eggs
#   Histidine: 1402.00 mg
#   Isoleucine: 2789.00 mg
#   Leucine: 4786.00 mg
#   Lysine: 3856.00 mg
#   Methionine: 1596.00 mg
#   Phenylalanine: 2975.00 mg
#   Threonine: 2391.00 mg
#   Tryptophan: 868.00 mg
#   Valine: 3425.00 mg
#
# ----------------------------------------
#
# Combination 9039: Beans_great_northern_mature_seeds_canned + Dried_Salted_Atlantic_Cod
#   Histidine: 2050.75 mg
#   Isoleucine: 3244.00 mg
#   Leucine: 5732.25 mg
#   Lysine: 6284.75 mg
#   Methionine: 1954.75 mg
#   Phenylalanine: 2887.50 mg
#   Threonine: 3024.75 mg
#   Tryptophan: 791.75 mg
#   Valine: 3661.25 mg
#
# ----------------------------------------
#
# Combination 9040: Beans_great_northern_mature_seeds_canned + Egg_Mix_USDA_Commodity
#   Histidine: 1078.19 mg
#   Isoleucine: 2287.10 mg
#   Leucine: 3938.38 mg
#   Lysine: 4424.57 mg
#   Methionine: 1538.86 mg
#   Phenylalanine: 2337.86 mg
#   Threonine: 1682.43 mg
#   Tryptophan: 488.00 mg
#   Valine: 2738.33 mg
#
# ----------------------------------------
#
# Combination 9041: Beans_great_northern_mature_seeds_canned + Egg_white_dried
#   Histidine: 2032.00 mg
#   Isoleucine: 4930.00 mg
#   Leucine: 7464.00 mg
#   Lysine: 6031.00 mg
#   Methionine: 2886.00 mg
#   Phenylalanine: 5171.00 mg
#   Threonine: 3956.00 mg
#   Tryptophan: 1087.00 mg
#   Valine: 5589.00 mg
#
# ----------------------------------------
#
# Combination 9042: Beans_great_northern_mature_seeds_canned + Egg_white_dried_flakes_stabilized_glucose_reduced
#   Histidine: 1950.02 mg
#   Isoleucine: 5037.99 mg
#   Leucine: 7321.15 mg
#   Lysine: 5253.89 mg
#   Methionine: 3087.19 mg
#   Phenylalanine: 5272.00 mg
#   Threonine: 3692.15 mg
#   Tryptophan: 1269.06 mg
#   Valine: 6184.91 mg
#
# ----------------------------------------
#
# Combination 9043: Beans_great_northern_mature_seeds_canned + Egg_white_dried_powder_stabilized_glucose_reduced
#   Histidine: 2073.43 mg
#   Isoleucine: 5377.57 mg
#   Leucine: 7797.43 mg
#   Lysine: 5587.43 mg
#   Methionine: 3296.00 mg
#   Phenylalanine: 5620.71 mg
#   Threonine: 3942.43 mg
#   Tryptophan: 1359.43 mg
#   Valine: 6596.43 mg
#
# ----------------------------------------
#
# Combination 9044: Beans_great_northern_mature_seeds_canned + Egg_White_Powder
#   Histidine: 2259.14 mg
#   Isoleucine: 4763.29 mg
#   Leucine: 7983.14 mg
#   Lysine: 6416.00 mg
#   Methionine: 3081.71 mg
#   Phenylalanine: 5563.57 mg
#   Threonine: 3899.57 mg
#   Tryptophan: 1516.57 mg
#   Valine: 6153.57 mg
#
# ----------------------------------------
#
# Combination 9045: Beans_great_northern_mature_seeds_canned + Egg_whole_dried_stabilized_glucose_reduced
#   Histidine: 1362.00 mg
#   Isoleucine: 3369.00 mg
#   Leucine: 4866.00 mg
#   Lysine: 3776.00 mg
#   Methionine: 1656.00 mg
#   Phenylalanine: 3155.00 mg
#   Threonine: 2631.00 mg
#   Tryptophan: 868.00 mg
#   Valine: 3885.00 mg
#
# ----------------------------------------
#
# Combination 9046: Beans_great_northern_mature_seeds_canned + Fish_whitefish_dried__Alaska_Native_
#   Histidine: 1502.00 mg
#   Isoleucine: 2609.00 mg
#   Leucine: 4736.00 mg
#   Lysine: 5286.00 mg
#   Methionine: 1836.00 mg
#   Phenylalanine: 2775.00 mg
#   Threonine: 2741.00 mg
#   Tryptophan: 668.00 mg
#   Valine: 3035.00 mg
#
# ----------------------------------------
#
# Combination 9047: Beans_great_northern_mature_seeds_canned + Growing_Naturals_-_Brown_Rice_Protein_Powder
#   Histidine: 1867.00 mg
#   Isoleucine: 3405.00 mg
#   Leucine: 6655.00 mg
#   Lysine: 2795.00 mg
#   Methionine: 2037.00 mg
#   Phenylalanine: 4479.00 mg
#   Threonine: 2862.00 mg
#   Tryptophan: 1141.00 mg
#   Valine: 4725.00 mg
#
# ----------------------------------------
#
# Combination 9048: Beans_great_northern_mature_seeds_canned + Nutribiotic_Systems_-_Rice_Protein
#   Histidine: 1746.00 mg
#   Isoleucine: 4362.00 mg
#   Leucine: 6882.00 mg
#   Lysine: 4035.00 mg
#   Methionine: 1677.00 mg
#   Phenylalanine: 3448.00 mg
#   Threonine: 3534.00 mg
#   Tryptophan: 1157.00 mg
#   Valine: 4563.00 mg
#
# ----------------------------------------
#
# Combination 9049: Beans_great_northern_mature_seeds_canned + Primal_Nutrition_-_Chocolate_Coconut_Primal_Fuel_Low-Carb_Meal_Replacement_Shake
#   Histidine: 1107.00 mg
#   Isoleucine: 3468.00 mg
#   Leucine: 5483.00 mg
#   Lysine: 4326.00 mg
#   Methionine: 2215.00 mg
#   Phenylalanine: 3173.00 mg
#   Threonine: 3747.00 mg
#   Tryptophan: 921.00 mg
#   Valine: 3163.00 mg
#
# ----------------------------------------
#
# Combination 9050: Beans_great_northern_mature_seeds_canned + Rexall_Sundown_Inc__-_Engineered_Nutrition_Meal_Replacement
#   Histidine: 1549.00 mg
#   Isoleucine: 2598.00 mg
#   Leucine: 4838.00 mg
#   Lysine: 4121.00 mg
#   Methionine: 1364.00 mg
#   Phenylalanine: 2659.00 mg
#   Threonine: 2278.00 mg
#   Tryptophan: 596.00 mg
#   Valine: 3280.00 mg
#
# ----------------------------------------
#
# Combination 9051: Beans_great_northern_mature_seeds_canned + Rexall_Sundown_Inc__-_Meal_Replacement_Protein_Powder
#   Histidine: 1492.00 mg
#   Isoleucine: 2817.00 mg
#   Leucine: 5091.00 mg
#   Lysine: 4327.00 mg
#   Methionine: 1381.00 mg
#   Phenylalanine: 2852.00 mg
#   Threonine: 2535.00 mg
#   Tryptophan: 678.00 mg
#   Valine: 3535.00 mg
#
# ----------------------------------------
#
# Combination 9052: Beans_great_northern_mature_seeds_canned + Rexall_Sundown_Inc__-_Whey_Protein_Powder
#   Histidine: 1535.00 mg
#   Isoleucine: 4852.00 mg
#   Leucine: 8233.00 mg
#   Lysine: 7033.00 mg
#   Methionine: 1636.00 mg
#   Phenylalanine: 2642.00 mg
#   Threonine: 5711.00 mg
#   Tryptophan: 1095.00 mg
#   Valine: 4375.00 mg
#
# ----------------------------------------
#
# Combination 9053: Beans_great_northern_mature_seeds_canned + Seal_bearded__Oogruk__meat_dried__Alaska_Native_
#   Histidine: 3149.00 mg
#   Isoleucine: 3483.00 mg
#   Leucine: 7012.00 mg
#   Lysine: 7206.00 mg
#   Methionine: 1780.00 mg
#   Phenylalanine: 3710.00 mg
#   Threonine: 3499.00 mg
#   Tryptophan: 883.00 mg
#   Valine: 3653.00 mg
#
# ----------------------------------------
#
# Combination 9054: Beans_great_northern_mature_seeds_canned + Seal_bearded__Oogruk__meat_partially_dried__Alaska_Native_
#   Histidine: 2428.00 mg
#   Isoleucine: 2716.00 mg
#   Leucine: 5448.00 mg
#   Lysine: 5568.00 mg
#   Methionine: 1368.00 mg
#   Phenylalanine: 2908.00 mg
#   Threonine: 2709.00 mg
#   Tryptophan: 689.00 mg
#   Valine: 2863.00 mg
#
# ----------------------------------------
#
# Combination 9055: Beans_great_northern_mature_seeds_canned + Smelt_dried__Alaska_Native_
#   Histidine: 1212.00 mg
#   Isoleucine: 2499.00 mg
#   Leucine: 4446.00 mg
#   Lysine: 4206.00 mg
#   Methionine: 1336.00 mg
#   Phenylalanine: 2445.00 mg
#   Threonine: 2661.00 mg
#   Tryptophan: 598.00 mg
#   Valine: 3085.00 mg
#
# ----------------------------------------
#
# Combination 9056: Beans_great_northern_mature_seeds_canned + Soup_Swanson_Chicken_Broth_99__Fat_Free
#   Histidine: 10202.00 mg
#   Isoleucine: 7349.00 mg
#   Leucine: 14626.00 mg
#   Lysine: 19516.00 mg
#   Methionine: 7096.00 mg
#   Phenylalanine: 7435.00 mg
#   Threonine: 7271.00 mg
#   Tryptophan: 7088.00 mg
#   Valine: 7425.00 mg
#
# ----------------------------------------
#
# Combination 9057: Beans_great_northern_mature_seeds_canned + Tangerine_Juice_Canned_Sweetened
#   Histidine: 2208.45 mg
#   Isoleucine: 5365.13 mg
#   Leucine: 10658.26 mg
#   Lysine: 7538.58 mg
#   Methionine: 2102.45 mg
#   Phenylalanine: 6454.35 mg
#   Threonine: 6290.35 mg
#   Tryptophan: 1091.23 mg
#   Valine: 8450.81 mg
#
# ----------------------------------------
#
# Combination 9058: Beans_great_northern_mature_seeds_canned + Vital_wheat_gluten
#   Histidine: 2002.00 mg
#   Isoleucine: 3349.00 mg
#   Leucine: 7426.00 mg
#   Lysine: 3316.00 mg
#   Methionine: 1996.00 mg
#   Phenylalanine: 4835.00 mg
#   Threonine: 2871.00 mg
#   Tryptophan: 1388.00 mg
#   Valine: 4925.00 mg
#
# ----------------------------------------
#
# Combination 9059: Beans_great_northern_mature_seeds_canned + Whale_beluga_meat_dried__Alaska_Native_
#   Histidine: 3201.00 mg
#   Isoleucine: 3033.00 mg
#   Leucine: 6404.00 mg
#   Lysine: 6829.00 mg
#   Methionine: 1449.00 mg
#   Phenylalanine: 3382.00 mg
#   Threonine: 2997.00 mg
#   Tryptophan: 885.00 mg
#   Valine: 3235.00 mg
#
# ----------------------------------------
#
# Combination 9060: Beans_great_northern_mature_seeds_canned_low_sodium + Cream_Of_Rice_Cooked_With_Water_Without_Salt
#   Histidine: 26202.00 mg
#   Isoleucine: 15349.00 mg
#   Leucine: 73626.00 mg
#   Lysine: 37516.00 mg
#   Methionine: 26096.00 mg
#   Phenylalanine: 37435.00 mg
#   Threonine: 44271.00 mg
#   Tryptophan: 13088.00 mg
#   Valine: 57425.00 mg
#
# ----------------------------------------
#
# Combination 9061: Beans_great_northern_mature_seeds_canned_low_sodium + Dried_Eggs
#   Histidine: 1402.00 mg
#   Isoleucine: 2789.00 mg
#   Leucine: 4786.00 mg
#   Lysine: 3856.00 mg
#   Methionine: 1596.00 mg
#   Phenylalanine: 2975.00 mg
#   Threonine: 2391.00 mg
#   Tryptophan: 868.00 mg
#   Valine: 3425.00 mg
#
# ----------------------------------------
#
# Combination 9062: Beans_great_northern_mature_seeds_canned_low_sodium + Dried_Salted_Atlantic_Cod
#   Histidine: 2050.75 mg
#   Isoleucine: 3244.00 mg
#   Leucine: 5732.25 mg
#   Lysine: 6284.75 mg
#   Methionine: 1954.75 mg
#   Phenylalanine: 2887.50 mg
#   Threonine: 3024.75 mg
#   Tryptophan: 791.75 mg
#   Valine: 3661.25 mg
#
# ----------------------------------------
#
# Combination 9063: Beans_great_northern_mature_seeds_canned_low_sodium + Egg_Mix_USDA_Commodity
#   Histidine: 1078.19 mg
#   Isoleucine: 2287.10 mg
#   Leucine: 3938.38 mg
#   Lysine: 4424.57 mg
#   Methionine: 1538.86 mg
#   Phenylalanine: 2337.86 mg
#   Threonine: 1682.43 mg
#   Tryptophan: 488.00 mg
#   Valine: 2738.33 mg
#
# ----------------------------------------
#
# Combination 9064: Beans_great_northern_mature_seeds_canned_low_sodium + Egg_white_dried
#   Histidine: 2032.00 mg
#   Isoleucine: 4930.00 mg
#   Leucine: 7464.00 mg
#   Lysine: 6031.00 mg
#   Methionine: 2886.00 mg
#   Phenylalanine: 5171.00 mg
#   Threonine: 3956.00 mg
#   Tryptophan: 1087.00 mg
#   Valine: 5589.00 mg
#
# ----------------------------------------
#
# Combination 9065: Beans_great_northern_mature_seeds_canned_low_sodium + Egg_white_dried_flakes_stabilized_glucose_reduced
#   Histidine: 1950.02 mg
#   Isoleucine: 5037.99 mg
#   Leucine: 7321.15 mg
#   Lysine: 5253.89 mg
#   Methionine: 3087.19 mg
#   Phenylalanine: 5272.00 mg
#   Threonine: 3692.15 mg
#   Tryptophan: 1269.06 mg
#   Valine: 6184.91 mg
#
# ----------------------------------------
#
# Combination 9066: Beans_great_northern_mature_seeds_canned_low_sodium + Egg_white_dried_powder_stabilized_glucose_reduced
#   Histidine: 2073.43 mg
#   Isoleucine: 5377.57 mg
#   Leucine: 7797.43 mg
#   Lysine: 5587.43 mg
#   Methionine: 3296.00 mg
#   Phenylalanine: 5620.71 mg
#   Threonine: 3942.43 mg
#   Tryptophan: 1359.43 mg
#   Valine: 6596.43 mg
#
# ----------------------------------------
#
# Combination 9067: Beans_great_northern_mature_seeds_canned_low_sodium + Egg_White_Powder
#   Histidine: 2259.14 mg
#   Isoleucine: 4763.29 mg
#   Leucine: 7983.14 mg
#   Lysine: 6416.00 mg
#   Methionine: 3081.71 mg
#   Phenylalanine: 5563.57 mg
#   Threonine: 3899.57 mg
#   Tryptophan: 1516.57 mg
#   Valine: 6153.57 mg
#
# ----------------------------------------
#
# Combination 9068: Beans_great_northern_mature_seeds_canned_low_sodium + Egg_whole_dried_stabilized_glucose_reduced
#   Histidine: 1362.00 mg
#   Isoleucine: 3369.00 mg
#   Leucine: 4866.00 mg
#   Lysine: 3776.00 mg
#   Methionine: 1656.00 mg
#   Phenylalanine: 3155.00 mg
#   Threonine: 2631.00 mg
#   Tryptophan: 868.00 mg
#   Valine: 3885.00 mg
#
# ----------------------------------------
#
# Combination 9069: Beans_great_northern_mature_seeds_canned_low_sodium + Fish_whitefish_dried__Alaska_Native_
#   Histidine: 1502.00 mg
#   Isoleucine: 2609.00 mg
#   Leucine: 4736.00 mg
#   Lysine: 5286.00 mg
#   Methionine: 1836.00 mg
#   Phenylalanine: 2775.00 mg
#   Threonine: 2741.00 mg
#   Tryptophan: 668.00 mg
#   Valine: 3035.00 mg
#
# ----------------------------------------
#
# Combination 9070: Beans_great_northern_mature_seeds_canned_low_sodium + Growing_Naturals_-_Brown_Rice_Protein_Powder
#   Histidine: 1867.00 mg
#   Isoleucine: 3405.00 mg
#   Leucine: 6655.00 mg
#   Lysine: 2795.00 mg
#   Methionine: 2037.00 mg
#   Phenylalanine: 4479.00 mg
#   Threonine: 2862.00 mg
#   Tryptophan: 1141.00 mg
#   Valine: 4725.00 mg
#
# ----------------------------------------
#
# Combination 9071: Beans_great_northern_mature_seeds_canned_low_sodium + Nutribiotic_Systems_-_Rice_Protein
#   Histidine: 1746.00 mg
#   Isoleucine: 4362.00 mg
#   Leucine: 6882.00 mg
#   Lysine: 4035.00 mg
#   Methionine: 1677.00 mg
#   Phenylalanine: 3448.00 mg
#   Threonine: 3534.00 mg
#   Tryptophan: 1157.00 mg
#   Valine: 4563.00 mg
#
# ----------------------------------------
#
# Combination 9072: Beans_great_northern_mature_seeds_canned_low_sodium + Primal_Nutrition_-_Chocolate_Coconut_Primal_Fuel_Low-Carb_Meal_Replacement_Shake
#   Histidine: 1107.00 mg
#   Isoleucine: 3468.00 mg
#   Leucine: 5483.00 mg
#   Lysine: 4326.00 mg
#   Methionine: 2215.00 mg
#   Phenylalanine: 3173.00 mg
#   Threonine: 3747.00 mg
#   Tryptophan: 921.00 mg
#   Valine: 3163.00 mg
#
# ----------------------------------------
#
# Combination 9073: Beans_great_northern_mature_seeds_canned_low_sodium + Rexall_Sundown_Inc__-_Engineered_Nutrition_Meal_Replacement
#   Histidine: 1549.00 mg
#   Isoleucine: 2598.00 mg
#   Leucine: 4838.00 mg
#   Lysine: 4121.00 mg
#   Methionine: 1364.00 mg
#   Phenylalanine: 2659.00 mg
#   Threonine: 2278.00 mg
#   Tryptophan: 596.00 mg
#   Valine: 3280.00 mg
#
# ----------------------------------------
#
# Combination 9074: Beans_great_northern_mature_seeds_canned_low_sodium + Rexall_Sundown_Inc__-_Meal_Replacement_Protein_Powder
#   Histidine: 1492.00 mg
#   Isoleucine: 2817.00 mg
#   Leucine: 5091.00 mg
#   Lysine: 4327.00 mg
#   Methionine: 1381.00 mg
#   Phenylalanine: 2852.00 mg
#   Threonine: 2535.00 mg
#   Tryptophan: 678.00 mg
#   Valine: 3535.00 mg
#
# ----------------------------------------
#
# Combination 9075: Beans_great_northern_mature_seeds_canned_low_sodium + Rexall_Sundown_Inc__-_Whey_Protein_Powder
#   Histidine: 1535.00 mg
#   Isoleucine: 4852.00 mg
#   Leucine: 8233.00 mg
#   Lysine: 7033.00 mg
#   Methionine: 1636.00 mg
#   Phenylalanine: 2642.00 mg
#   Threonine: 5711.00 mg
#   Tryptophan: 1095.00 mg
#   Valine: 4375.00 mg
#
# ----------------------------------------
#
# Combination 9076: Beans_great_northern_mature_seeds_canned_low_sodium + Seal_bearded__Oogruk__meat_dried__Alaska_Native_
#   Histidine: 3149.00 mg
#   Isoleucine: 3483.00 mg
#   Leucine: 7012.00 mg
#   Lysine: 7206.00 mg
#   Methionine: 1780.00 mg
#   Phenylalanine: 3710.00 mg
#   Threonine: 3499.00 mg
#   Tryptophan: 883.00 mg
#   Valine: 3653.00 mg
#
# ----------------------------------------
#
# Combination 9077: Beans_great_northern_mature_seeds_canned_low_sodium + Seal_bearded__Oogruk__meat_partially_dried__Alaska_Native_
#   Histidine: 2428.00 mg
#   Isoleucine: 2716.00 mg
#   Leucine: 5448.00 mg
#   Lysine: 5568.00 mg
#   Methionine: 1368.00 mg
#   Phenylalanine: 2908.00 mg
#   Threonine: 2709.00 mg
#   Tryptophan: 689.00 mg
#   Valine: 2863.00 mg
#
# ----------------------------------------
#
# Combination 9078: Beans_great_northern_mature_seeds_canned_low_sodium + Smelt_dried__Alaska_Native_
#   Histidine: 1212.00 mg
#   Isoleucine: 2499.00 mg
#   Leucine: 4446.00 mg
#   Lysine: 4206.00 mg
#   Methionine: 1336.00 mg
#   Phenylalanine: 2445.00 mg
#   Threonine: 2661.00 mg
#   Tryptophan: 598.00 mg
#   Valine: 3085.00 mg
#
# ----------------------------------------
#
# Combination 9079: Beans_great_northern_mature_seeds_canned_low_sodium + Soup_Swanson_Chicken_Broth_99__Fat_Free
#   Histidine: 10202.00 mg
#   Isoleucine: 7349.00 mg
#   Leucine: 14626.00 mg
#   Lysine: 19516.00 mg
#   Methionine: 7096.00 mg
#   Phenylalanine: 7435.00 mg
#   Threonine: 7271.00 mg
#   Tryptophan: 7088.00 mg
#   Valine: 7425.00 mg
#
# ----------------------------------------
#
# Combination 9080: Beans_great_northern_mature_seeds_canned_low_sodium + Tangerine_Juice_Canned_Sweetened
#   Histidine: 2208.45 mg
#   Isoleucine: 5365.13 mg
#   Leucine: 10658.26 mg
#   Lysine: 7538.58 mg
#   Methionine: 2102.45 mg
#   Phenylalanine: 6454.35 mg
#   Threonine: 6290.35 mg
#   Tryptophan: 1091.23 mg
#   Valine: 8450.81 mg
#
# ----------------------------------------
#
# Combination 9081: Beans_great_northern_mature_seeds_canned_low_sodium + Vital_wheat_gluten
#   Histidine: 2002.00 mg
#   Isoleucine: 3349.00 mg
#   Leucine: 7426.00 mg
#   Lysine: 3316.00 mg
#   Methionine: 1996.00 mg
#   Phenylalanine: 4835.00 mg
#   Threonine: 2871.00 mg
#   Tryptophan: 1388.00 mg
#   Valine: 4925.00 mg
#
# ----------------------------------------
#
# Combination 9082: Beans_great_northern_mature_seeds_canned_low_sodium + Whale_beluga_meat_dried__Alaska_Native_
#   Histidine: 3201.00 mg
#   Isoleucine: 3033.00 mg
#   Leucine: 6404.00 mg
#   Lysine: 6829.00 mg
#   Methionine: 1449.00 mg
#   Phenylalanine: 3382.00 mg
#   Threonine: 2997.00 mg
#   Tryptophan: 885.00 mg
#   Valine: 3235.00 mg
#
# ----------------------------------------
#
# Combination 9083: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Cream_Of_Rice_Cooked_With_Water_Without_Salt
#   Histidine: 26232.00 mg
#   Isoleucine: 15368.00 mg
#   Leucine: 73665.00 mg
#   Lysine: 37572.00 mg
#   Methionine: 26125.00 mg
#   Phenylalanine: 37451.00 mg
#   Threonine: 44351.00 mg
#   Tryptophan: 13099.00 mg
#   Valine: 57436.00 mg
#
# ----------------------------------------
#
# Combination 9084: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Dried_Eggs
#   Histidine: 1432.00 mg
#   Isoleucine: 2808.00 mg
#   Leucine: 4825.00 mg
#   Lysine: 3912.00 mg
#   Methionine: 1625.00 mg
#   Phenylalanine: 2991.00 mg
#   Threonine: 2471.00 mg
#   Tryptophan: 879.00 mg
#   Valine: 3436.00 mg
#
# ----------------------------------------
#
# Combination 9085: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Dried_Salted_Atlantic_Cod
#   Histidine: 2080.75 mg
#   Isoleucine: 3263.00 mg
#   Leucine: 5771.25 mg
#   Lysine: 6340.75 mg
#   Methionine: 1983.75 mg
#   Phenylalanine: 2903.50 mg
#   Threonine: 3104.75 mg
#   Tryptophan: 802.75 mg
#   Valine: 3672.25 mg
#
# ----------------------------------------
#
# Combination 9086: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Egg_Mix_USDA_Commodity
#   Histidine: 1108.19 mg
#   Isoleucine: 2306.10 mg
#   Leucine: 3977.38 mg
#   Lysine: 4480.57 mg
#   Methionine: 1567.86 mg
#   Phenylalanine: 2353.86 mg
#   Threonine: 1762.43 mg
#   Tryptophan: 499.00 mg
#   Valine: 2749.33 mg
#
# ----------------------------------------
#
# Combination 9087: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Egg_white_dried
#   Histidine: 2062.00 mg
#   Isoleucine: 4949.00 mg
#   Leucine: 7503.00 mg
#   Lysine: 6087.00 mg
#   Methionine: 2915.00 mg
#   Phenylalanine: 5187.00 mg
#   Threonine: 4036.00 mg
#   Tryptophan: 1098.00 mg
#   Valine: 5600.00 mg
#
# ----------------------------------------
#
# Combination 9088: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Egg_white_dried_flakes_stabilized_glucose_reduced
#   Histidine: 1980.02 mg
#   Isoleucine: 5056.99 mg
#   Leucine: 7360.15 mg
#   Lysine: 5309.89 mg
#   Methionine: 3116.19 mg
#   Phenylalanine: 5288.00 mg
#   Threonine: 3772.15 mg
#   Tryptophan: 1280.06 mg
#   Valine: 6195.91 mg
#
# ----------------------------------------
#
# Combination 9089: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Egg_white_dried_powder_stabilized_glucose_reduced
#   Histidine: 2103.43 mg
#   Isoleucine: 5396.57 mg
#   Leucine: 7836.43 mg
#   Lysine: 5643.43 mg
#   Methionine: 3325.00 mg
#   Phenylalanine: 5636.71 mg
#   Threonine: 4022.43 mg
#   Tryptophan: 1370.43 mg
#   Valine: 6607.43 mg
#
# ----------------------------------------
#
# Combination 9090: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Egg_White_Powder
#   Histidine: 2289.14 mg
#   Isoleucine: 4782.29 mg
#   Leucine: 8022.14 mg
#   Lysine: 6472.00 mg
#   Methionine: 3110.71 mg
#   Phenylalanine: 5579.57 mg
#   Threonine: 3979.57 mg
#   Tryptophan: 1527.57 mg
#   Valine: 6164.57 mg
#
# ----------------------------------------
#
# Combination 9091: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Egg_whole_dried_stabilized_glucose_reduced
#   Histidine: 1392.00 mg
#   Isoleucine: 3388.00 mg
#   Leucine: 4905.00 mg
#   Lysine: 3832.00 mg
#   Methionine: 1685.00 mg
#   Phenylalanine: 3171.00 mg
#   Threonine: 2711.00 mg
#   Tryptophan: 879.00 mg
#   Valine: 3896.00 mg
#
# ----------------------------------------
#
# Combination 9092: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Fish_whitefish_dried__Alaska_Native_
#   Histidine: 1532.00 mg
#   Isoleucine: 2628.00 mg
#   Leucine: 4775.00 mg
#   Lysine: 5342.00 mg
#   Methionine: 1865.00 mg
#   Phenylalanine: 2791.00 mg
#   Threonine: 2821.00 mg
#   Tryptophan: 679.00 mg
#   Valine: 3046.00 mg
#
# ----------------------------------------
#
# Combination 9093: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Growing_Naturals_-_Brown_Rice_Protein_Powder
#   Histidine: 1897.00 mg
#   Isoleucine: 3424.00 mg
#   Leucine: 6694.00 mg
#   Lysine: 2851.00 mg
#   Methionine: 2066.00 mg
#   Phenylalanine: 4495.00 mg
#   Threonine: 2942.00 mg
#   Tryptophan: 1152.00 mg
#   Valine: 4736.00 mg
#
# ----------------------------------------
#
# Combination 9094: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Nutribiotic_Systems_-_Rice_Protein
#   Histidine: 1776.00 mg
#   Isoleucine: 4381.00 mg
#   Leucine: 6921.00 mg
#   Lysine: 4091.00 mg
#   Methionine: 1706.00 mg
#   Phenylalanine: 3464.00 mg
#   Threonine: 3614.00 mg
#   Tryptophan: 1168.00 mg
#   Valine: 4574.00 mg
#
# ----------------------------------------
#
# Combination 9095: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Primal_Nutrition_-_Chocolate_Coconut_Primal_Fuel_Low-Carb_Meal_Replacement_Shake
#   Histidine: 1137.00 mg
#   Isoleucine: 3487.00 mg
#   Leucine: 5522.00 mg
#   Lysine: 4382.00 mg
#   Methionine: 2244.00 mg
#   Phenylalanine: 3189.00 mg
#   Threonine: 3827.00 mg
#   Tryptophan: 932.00 mg
#   Valine: 3174.00 mg
#
# ----------------------------------------
#
# Combination 9096: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Rexall_Sundown_Inc__-_Engineered_Nutrition_Meal_Replacement
#   Histidine: 1579.00 mg
#   Isoleucine: 2617.00 mg
#   Leucine: 4877.00 mg
#   Lysine: 4177.00 mg
#   Methionine: 1393.00 mg
#   Phenylalanine: 2675.00 mg
#   Threonine: 2358.00 mg
#   Tryptophan: 607.00 mg
#   Valine: 3291.00 mg
#
# ----------------------------------------
#
# Combination 9097: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Rexall_Sundown_Inc__-_Meal_Replacement_Protein_Powder
#   Histidine: 1522.00 mg
#   Isoleucine: 2836.00 mg
#   Leucine: 5130.00 mg
#   Lysine: 4383.00 mg
#   Methionine: 1410.00 mg
#   Phenylalanine: 2868.00 mg
#   Threonine: 2615.00 mg
#   Tryptophan: 689.00 mg
#   Valine: 3546.00 mg
#
# ----------------------------------------
#
# Combination 9098: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Rexall_Sundown_Inc__-_Whey_Protein_Powder
#   Histidine: 1565.00 mg
#   Isoleucine: 4871.00 mg
#   Leucine: 8272.00 mg
#   Lysine: 7089.00 mg
#   Methionine: 1665.00 mg
#   Phenylalanine: 2658.00 mg
#   Threonine: 5791.00 mg
#   Tryptophan: 1106.00 mg
#   Valine: 4386.00 mg
#
# ----------------------------------------
#
# Combination 9099: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Seal_bearded__Oogruk__meat_dried__Alaska_Native_
#   Histidine: 3179.00 mg
#   Isoleucine: 3502.00 mg
#   Leucine: 7051.00 mg
#   Lysine: 7262.00 mg
#   Methionine: 1809.00 mg
#   Phenylalanine: 3726.00 mg
#   Threonine: 3579.00 mg
#   Tryptophan: 894.00 mg
#   Valine: 3664.00 mg
#
# ----------------------------------------
#
# Combination 9100: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Seal_bearded__Oogruk__meat_partially_dried__Alaska_Native_
#   Histidine: 2458.00 mg
#   Isoleucine: 2735.00 mg
#   Leucine: 5487.00 mg
#   Lysine: 5624.00 mg
#   Methionine: 1397.00 mg
#   Phenylalanine: 2924.00 mg
#   Threonine: 2789.00 mg
#   Tryptophan: 700.00 mg
#   Valine: 2874.00 mg
#
# ----------------------------------------
#
# Combination 9101: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Smelt_dried__Alaska_Native_
#   Histidine: 1242.00 mg
#   Isoleucine: 2518.00 mg
#   Leucine: 4485.00 mg
#   Lysine: 4262.00 mg
#   Methionine: 1365.00 mg
#   Phenylalanine: 2461.00 mg
#   Threonine: 2741.00 mg
#   Tryptophan: 609.00 mg
#   Valine: 3096.00 mg
#
# ----------------------------------------
#
# Combination 9102: Beans_great_northern_mature_seeds_cooked_boiled_with_salt + Soup_Swanson_Chicken_Broth_99__Fat_Free
#   Histidine: 10232.00 mg
#   Isoleucine: 7368.00 mg
#   Leucine: 14665.00 mg
#   Lysine: 19572.00 mg
#   Methionine: 7125.00 mg
#   Phenylalanine: 7451.00 mg
# ...
#   Histidine: 1766.33 mg
#   Isoleucine: 2269.00 mg
#   Leucine: 4087.33 mg
#   Lysine: 4012.33 mg
#   Methionine: 1361.33 mg
#   Phenylalanine: 2394.67 mg
#   Threonine: 2022.33 mg
#   Tryptophan: 584.33 mg
#   Valine: 2480.00 mg
#
# ----------------------------------------
#
# Combination 9957: Beans_Pinto_Mature_Seeds_Raw + Beef_New_Zealand_imported_brisket_point_end_separable_lean_only_cooked_braised
#   Histidine: 1801.33 mg
#   Isoleucine: 2310.00 mg
#   Leucine: 4162.33 mg
#   Lysine: 4090.33 mg
#   Methionine: 1393.33 mg
#   Phenylalanine: 2433.67 mg
#   Threonine: 2058.33 mg
#   Tryptophan: 595.33 mg
#   Valine: 2523.00 mg
#
# ----------------------------------------
#
# Combination 9958: Beans_Pinto_Mature_Seeds_Raw + Beef_New_Zealand_imported_flat_separable_lean_only_cooked_braised
#   Histidine: 1755.33 mg
#   Isoleucine: 2256.00 mg
#   Leucine: 4065.33 mg
#   Lysine: 3988.33 mg
#   Methionine: 1351.33 mg
#   Phenylalanine: 2383.67 mg
#   Threonine: 2011.33 mg
#   Tryptophan: 581.33 mg
#   Valine: 2466.00 mg
#
# ----------------------------------------
#
# Combination 9959: Beans_Pinto_Mature_Seeds_Raw + Cooked_Whelk
#   Histidine: 1535.33 mg
#   Isoleucine: 2530.00 mg
#   Leucine: 5365.33 mg
#   Lysine: 4288.33 mg
#   Methionine: 1463.33 mg
#   Phenylalanine: 2739.67 mg
#   Threonine: 2944.33 mg
#   Tryptophan: 851.33 mg
#   Valine: 3075.00 mg
#
# ----------------------------------------
#
# Combination 9960: Beans_Pinto_Mature_Seeds_Raw + Cream_Of_Rice_Cooked_With_Water_Without_Salt
#   Histidine: 26558.33 mg
#   Isoleucine: 15875.00 mg
#   Leucine: 74558.33 mg
#   Lysine: 38358.33 mg
#   Methionine: 26258.33 mg
#   Phenylalanine: 38091.67 mg
#   Threonine: 44808.33 mg
#   Tryptophan: 13233.33 mg
#   Valine: 58000.00 mg
#
# ----------------------------------------
#
# Combination 9961: Beans_Pinto_Mature_Seeds_Raw + Dried_Eggs
#   Histidine: 1758.33 mg
#   Isoleucine: 3315.00 mg
#   Leucine: 5718.33 mg
#   Lysine: 4698.33 mg
#   Methionine: 1758.33 mg
#   Phenylalanine: 3631.67 mg
#   Threonine: 2928.33 mg
#   Tryptophan: 1013.33 mg
#   Valine: 4000.00 mg
#
# ----------------------------------------
#
# Combination 9962: Beans_Pinto_Mature_Seeds_Raw + Dried_Salted_Atlantic_Cod
#   Histidine: 2407.08 mg
#   Isoleucine: 3770.00 mg
#   Leucine: 6664.58 mg
#   Lysine: 7127.08 mg
#   Methionine: 2117.08 mg
#   Phenylalanine: 3544.17 mg
#   Threonine: 3562.08 mg
#   Tryptophan: 937.08 mg
#   Valine: 4236.25 mg
#
# ----------------------------------------
#
# Combination 9963: Beans_Pinto_Mature_Seeds_Raw + Dried_Spirulina
#   Histidine: 1644.05 mg
#   Isoleucine: 4089.29 mg
#   Leucine: 6501.19 mg
#   Lysine: 4386.90 mg
#   Methionine: 1401.19 mg
#   Phenylalanine: 3863.10 mg
#   Threonine: 3779.76 mg
#   Tryptophan: 1161.90 mg
#   Valine: 4514.29 mg
#
# ----------------------------------------
#
# Combination 9964: Beans_Pinto_Mature_Seeds_Raw + Egg_Mix_USDA_Commodity
#   Histidine: 1434.52 mg
#   Isoleucine: 2813.10 mg
#   Leucine: 4870.71 mg
#   Lysine: 5266.90 mg
#   Methionine: 1701.19 mg
#   Phenylalanine: 2994.52 mg
#   Threonine: 2219.76 mg
#   Tryptophan: 633.33 mg
#   Valine: 3313.33 mg
#
# ----------------------------------------
#
# Combination 9965: Beans_Pinto_Mature_Seeds_Raw + Egg_white_dried
#   Histidine: 2388.33 mg
#   Isoleucine: 5456.00 mg
#   Leucine: 8396.33 mg
#   Lysine: 6873.33 mg
#   Methionine: 3048.33 mg
#   Phenylalanine: 5827.67 mg
#   Threonine: 4493.33 mg
#   Tryptophan: 1232.33 mg
#   Valine: 6164.00 mg
#
# ----------------------------------------
#
# Combination 9966: Beans_Pinto_Mature_Seeds_Raw + Egg_white_dried_flakes_stabilized_glucose_reduced
#   Histidine: 2306.35 mg
#   Isoleucine: 5563.99 mg
#   Leucine: 8253.49 mg
#   Lysine: 6096.22 mg
#   Methionine: 3249.52 mg
#   Phenylalanine: 5928.67 mg
#   Threonine: 4229.48 mg
#   Tryptophan: 1414.39 mg
#   Valine: 6759.91 mg
#
# ----------------------------------------
#
# Combination 9967: Beans_Pinto_Mature_Seeds_Raw + Egg_white_dried_powder_stabilized_glucose_reduced
#   Histidine: 2429.76 mg
#   Isoleucine: 5903.57 mg
#   Leucine: 8729.76 mg
#   Lysine: 6429.76 mg
#   Methionine: 3458.33 mg
#   Phenylalanine: 6277.38 mg
#   Threonine: 4479.76 mg
#   Tryptophan: 1504.76 mg
#   Valine: 7171.43 mg
#
# ----------------------------------------
#
# Combination 9968: Beans_Pinto_Mature_Seeds_Raw + Egg_White_Powder
#   Histidine: 2615.48 mg
#   Isoleucine: 5289.29 mg
#   Leucine: 8915.48 mg
#   Lysine: 7258.33 mg
#   Methionine: 3244.05 mg
#   Phenylalanine: 6220.24 mg
#   Threonine: 4436.90 mg
#   Tryptophan: 1661.90 mg
#   Valine: 6728.57 mg
#
# ----------------------------------------
#
# Combination 9969: Beans_Pinto_Mature_Seeds_Raw + Egg_whole_dried_stabilized_glucose_reduced
#   Histidine: 1718.33 mg
#   Isoleucine: 3895.00 mg
#   Leucine: 5798.33 mg
#   Lysine: 4618.33 mg
#   Methionine: 1818.33 mg
#   Phenylalanine: 3811.67 mg
#   Threonine: 3168.33 mg
#   Tryptophan: 1013.33 mg
#   Valine: 4460.00 mg
#
# ----------------------------------------
#
# Combination 9970: Beans_Pinto_Mature_Seeds_Raw + Fish_whitefish_dried__Alaska_Native_
#   Histidine: 1858.33 mg
#   Isoleucine: 3135.00 mg
#   Leucine: 5668.33 mg
#   Lysine: 6128.33 mg
#   Methionine: 1998.33 mg
#   Phenylalanine: 3431.67 mg
#   Threonine: 3278.33 mg
#   Tryptophan: 813.33 mg
#   Valine: 3610.00 mg
#
# ----------------------------------------
#
# Combination 9971: Beans_Pinto_Mature_Seeds_Raw + Growing_Naturals_-_Brown_Rice_Protein_Powder
#   Histidine: 2223.33 mg
#   Isoleucine: 3931.00 mg
#   Leucine: 7587.33 mg
#   Lysine: 3637.33 mg
#   Methionine: 2199.33 mg
#   Phenylalanine: 5135.67 mg
#   Threonine: 3399.33 mg
#   Tryptophan: 1286.33 mg
#   Valine: 5300.00 mg
#
# ----------------------------------------
#
# Combination 9972: Beans_Pinto_Mature_Seeds_Raw + Lamb_New_Zealand_imported_fore-shank_separable_lean_only_cooked_braised
#   Histidine: 1263.33 mg
#   Isoleucine: 2366.00 mg
#   Leucine: 4131.33 mg
#   Lysine: 4267.33 mg
#   Methionine: 1345.33 mg
#   Phenylalanine: 2403.67 mg
#   Threonine: 2397.33 mg
#   Tryptophan: 601.33 mg
#   Valine: 2696.00 mg
#
# ----------------------------------------
#
# Combination 9973: Beans_Pinto_Mature_Seeds_Raw + Nutribiotic_Systems_-_Rice_Protein
#   Histidine: 2102.33 mg
#   Isoleucine: 4888.00 mg
#   Leucine: 7814.33 mg
#   Lysine: 4877.33 mg
#   Methionine: 1839.33 mg
#   Phenylalanine: 4104.67 mg
#   Threonine: 4071.33 mg
#   Tryptophan: 1302.33 mg
#   Valine: 5138.00 mg
#
# ----------------------------------------
#
# Combination 9974: Beans_Pinto_Mature_Seeds_Raw + Prevention_LLC_-_Naturade_Grass_Fed_Whey_Protein_Booster_Chocolate
#   Histidine: 1439.33 mg
#   Isoleucine: 3946.00 mg
#   Leucine: 6582.33 mg
#   Lysine: 5453.33 mg
#   Methionine: 1401.33 mg
#   Phenylalanine: 2686.67 mg
#   Threonine: 4046.33 mg
#   Tryptophan: 1162.33 mg
#   Valine: 3810.00 mg
#
# ----------------------------------------
#
# Combination 9975: Beans_Pinto_Mature_Seeds_Raw + Prevention_llc_-_NATURADE_WHEY_PROTEIN_BOOSTER_VANILLA_VANILLA
#   Histidine: 1532.33 mg
#   Isoleucine: 4243.00 mg
#   Leucine: 7058.33 mg
#   Lysine: 5884.33 mg
#   Methionine: 1521.33 mg
#   Phenylalanine: 2775.67 mg
#   Threonine: 4361.33 mg
#   Tryptophan: 1233.33 mg
#   Valine: 3079947.00 mg
#
# ----------------------------------------
#
# Combination 9976: Beans_Pinto_Mature_Seeds_Raw + Primal_Nutrition_-_Chocolate_Coconut_Primal_Fuel_Low-Carb_Meal_Replacement_Shake
#   Histidine: 1463.33 mg
#   Isoleucine: 3994.00 mg
#   Leucine: 6415.33 mg
#   Lysine: 5168.33 mg
#   Methionine: 2377.33 mg
#   Phenylalanine: 3829.67 mg
#   Threonine: 4284.33 mg
#   Tryptophan: 1066.33 mg
#   Valine: 3738.00 mg
#
# ----------------------------------------
#
# Combination 9977: Beans_Pinto_Mature_Seeds_Raw + Rexall_Sundown_Inc__-_Engineered_Nutrition_Meal_Replacement
#   Histidine: 1905.33 mg
#   Isoleucine: 3124.00 mg
#   Leucine: 5770.33 mg
#   Lysine: 4963.33 mg
#   Methionine: 1526.33 mg
#   Phenylalanine: 3315.67 mg
#   Threonine: 2815.33 mg
#   Tryptophan: 741.33 mg
#   Valine: 3855.00 mg
#
# ----------------------------------------
#
# Combination 9978: Beans_Pinto_Mature_Seeds_Raw + Rexall_Sundown_Inc__-_Meal_Replacement_Protein_Powder
#   Histidine: 1848.33 mg
#   Isoleucine: 3343.00 mg
#   Leucine: 6023.33 mg
#   Lysine: 5169.33 mg
#   Methionine: 1543.33 mg
#   Phenylalanine: 3508.67 mg
#   Threonine: 3072.33 mg
#   Tryptophan: 823.33 mg
#   Valine: 4110.00 mg
#
# ----------------------------------------
#
# Combination 9979: Beans_Pinto_Mature_Seeds_Raw + Rexall_Sundown_Inc__-_Whey_Protein_Powder
#   Histidine: 1891.33 mg
#   Isoleucine: 5378.00 mg
#   Leucine: 9165.33 mg
#   Lysine: 7875.33 mg
#   Methionine: 1798.33 mg
#   Phenylalanine: 3298.67 mg
#   Threonine: 6248.33 mg
#   Tryptophan: 1240.33 mg
#   Valine: 4950.00 mg
#
# ----------------------------------------
#
# Combination 9980: Beans_Pinto_Mature_Seeds_Raw + Seal_bearded__Oogruk__meat_dried__Alaska_Native_
#   Histidine: 3505.33 mg
#   Isoleucine: 4009.00 mg
#   Leucine: 7944.33 mg
#   Lysine: 8048.33 mg
#   Methionine: 1942.33 mg
#   Phenylalanine: 4366.67 mg
#   Threonine: 4036.33 mg
#   Tryptophan: 1028.33 mg
#   Valine: 4228.00 mg
#
# ----------------------------------------
#
# Combination 9981: Beans_Pinto_Mature_Seeds_Raw + Seal_bearded__Oogruk__meat_partially_dried__Alaska_Native_
#   Histidine: 2784.33 mg
#   Isoleucine: 3242.00 mg
#   Leucine: 6380.33 mg
#   Lysine: 6410.33 mg
#   Methionine: 1530.33 mg
#   Phenylalanine: 3564.67 mg
#   Threonine: 3246.33 mg
#   Tryptophan: 834.33 mg
#   Valine: 3438.00 mg
#
# ----------------------------------------
#
# Combination 9982: Beans_Pinto_Mature_Seeds_Raw + Seeds_sesame_flour_low-fat
#   Histidine: 2034.33 mg
#   Isoleucine: 3032.00 mg
#   Leucine: 5399.33 mg
#   Lysine: 2966.33 mg
#   Methionine: 1914.33 mg
#   Phenylalanine: 3749.67 mg
#   Threonine: 2889.33 mg
#   Tryptophan: 1330.33 mg
#   Valine: 3800.00 mg
#
# ----------------------------------------
#
# Combination 9983: Beans_Pinto_Mature_Seeds_Raw + Shredded_Parmesan
#   Histidine: 2167.33 mg
#   Isoleucine: 3077.00 mg
#   Leucine: 5571.33 mg
#   Lysine: 5201.33 mg
#   Methionine: 1372.33 mg
#   Phenylalanine: 3325.67 mg
#   Threonine: 2339.33 mg
#   Tryptophan: 793.33 mg
#   Valine: 3853.00 mg
#
# ----------------------------------------
#
# Combination 9984: Beans_Pinto_Mature_Seeds_Raw + Smelt_dried__Alaska_Native_
#   Histidine: 1568.33 mg
#   Isoleucine: 3025.00 mg
#   Leucine: 5378.33 mg
#   Lysine: 5048.33 mg
#   Methionine: 1498.33 mg
#   Phenylalanine: 3101.67 mg
#   Threonine: 3198.33 mg
#   Tryptophan: 743.33 mg
#   Valine: 3660.00 mg
#
# ----------------------------------------
#
# Combination 9985: Beans_Pinto_Mature_Seeds_Raw + Soup_Swanson_Chicken_Broth_99__Fat_Free
#   Histidine: 10558.33 mg
#   Isoleucine: 7875.00 mg
#   Leucine: 15558.33 mg
#   Lysine: 20358.33 mg
#   Methionine: 7258.33 mg
#   Phenylalanine: 8091.67 mg
#   Threonine: 7808.33 mg
#   Tryptophan: 7233.33 mg
#   Valine: 8000.00 mg
#
# ----------------------------------------
#
# Combination 9986: Beans_Pinto_Mature_Seeds_Raw + Soy_protein_isolate_potassium_type
#   Histidine: 2861.33 mg
#   Isoleucine: 5128.00 mg
#   Leucine: 8341.33 mg
#   Lysine: 6685.33 mg
#   Methionine: 1388.33 mg
#   Phenylalanine: 5684.67 mg
#   Threonine: 3945.33 mg
#   Tryptophan: 1349.33 mg
#   Valine: 5098.00 mg
#
# ----------------------------------------
#
# Combination 9987: Beans_Pinto_Mature_Seeds_Raw + Soy_Protein_Powder__Isolate_
#   Histidine: 2861.33 mg
#   Isoleucine: 5128.00 mg
#   Leucine: 8341.33 mg
#   Lysine: 6685.33 mg
#   Methionine: 1388.33 mg
#   Phenylalanine: 5684.67 mg
#   Threonine: 3945.33 mg
#   Tryptophan: 1349.33 mg
#   Valine: 5098.00 mg
#
# ----------------------------------------
#
# Combination 9988: Beans_Pinto_Mature_Seeds_Raw + Tangerine_Juice_Canned_Sweetened
#   Histidine: 2564.78 mg
#   Isoleucine: 5891.13 mg
#   Leucine: 11590.59 mg
#   Lysine: 8380.91 mg
#   Methionine: 2264.78 mg
#   Phenylalanine: 7111.02 mg
#   Threonine: 6827.69 mg
#   Tryptophan: 1236.56 mg
#   Valine: 9025.81 mg
#
# ----------------------------------------
#
# Combination 9989: Beans_Pinto_Mature_Seeds_Raw + Vital_wheat_gluten
#   Histidine: 2358.33 mg
#   Isoleucine: 3875.00 mg
#   Leucine: 8358.33 mg
#   Lysine: 4158.33 mg
#   Methionine: 2158.33 mg
#   Phenylalanine: 5491.67 mg
#   Threonine: 3408.33 mg
#   Tryptophan: 1533.33 mg
#   Valine: 5500.00 mg
#
# ----------------------------------------
#
# Combination 9990: Beans_Pinto_Mature_Seeds_Raw + Whale_beluga_meat_dried__Alaska_Native_
#   Histidine: 3557.33 mg
#   Isoleucine: 3559.00 mg
#   Leucine: 7336.33 mg
#   Lysine: 7671.33 mg
#   Methionine: 1611.33 mg
#   Phenylalanine: 4038.67 mg
#   Threonine: 3534.33 mg
#   Tryptophan: 1030.33 mg
#   Valine: 3810.00 mg
#
# ----------------------------------------
#
# Combination 9991: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Cream_Of_Rice_Cooked_With_Water_Without_Salt
#   Histidine: 26052.00 mg
#   Isoleucine: 15082.00 mg
#   Leucine: 73133.00 mg
#   Lysine: 37106.00 mg
#   Methionine: 26019.00 mg
#   Phenylalanine: 37094.00 mg
#   Threonine: 44078.00 mg
#   Tryptophan: 13019.00 mg
#   Valine: 57095.00 mg
#
# ----------------------------------------
#
# Combination 9992: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Dried_Eggs
#   Histidine: 1252.00 mg
#   Isoleucine: 2522.00 mg
#   Leucine: 4293.00 mg
#   Lysine: 3446.00 mg
#   Methionine: 1519.00 mg
#   Phenylalanine: 2634.00 mg
#   Threonine: 2198.00 mg
#   Tryptophan: 799.00 mg
#   Valine: 3095.00 mg
#
# ----------------------------------------
#
# Combination 9993: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Dried_Salted_Atlantic_Cod
#   Histidine: 1900.75 mg
#   Isoleucine: 2977.00 mg
#   Leucine: 5239.25 mg
#   Lysine: 5874.75 mg
#   Methionine: 1877.75 mg
#   Phenylalanine: 2546.50 mg
#   Threonine: 2831.75 mg
#   Tryptophan: 722.75 mg
#   Valine: 3331.25 mg
#
# ----------------------------------------
#
# Combination 9994: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Egg_white_dried
#   Histidine: 1882.00 mg
#   Isoleucine: 4663.00 mg
#   Leucine: 6971.00 mg
#   Lysine: 5621.00 mg
#   Methionine: 2809.00 mg
#   Phenylalanine: 4830.00 mg
#   Threonine: 3763.00 mg
#   Tryptophan: 1018.00 mg
#   Valine: 5259.00 mg
#
# ----------------------------------------
#
# Combination 9995: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Egg_white_dried_flakes_stabilized_glucose_reduced
#   Histidine: 1800.02 mg
#   Isoleucine: 4770.99 mg
#   Leucine: 6828.15 mg
#   Lysine: 4843.89 mg
#   Methionine: 3010.19 mg
#   Phenylalanine: 4931.00 mg
#   Threonine: 3499.15 mg
#   Tryptophan: 1200.06 mg
#   Valine: 5854.91 mg
#
# ----------------------------------------
#
# Combination 9996: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Egg_white_dried_powder_stabilized_glucose_reduced
#   Histidine: 1923.43 mg
#   Isoleucine: 5110.57 mg
#   Leucine: 7304.43 mg
#   Lysine: 5177.43 mg
#   Methionine: 3219.00 mg
#   Phenylalanine: 5279.71 mg
#   Threonine: 3749.43 mg
#   Tryptophan: 1290.43 mg
#   Valine: 6266.43 mg
#
# ----------------------------------------
#
# Combination 9997: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Egg_White_Powder
#   Histidine: 2109.14 mg
#   Isoleucine: 4496.29 mg
#   Leucine: 7490.14 mg
#   Lysine: 6006.00 mg
#   Methionine: 3004.71 mg
#   Phenylalanine: 5222.57 mg
#   Threonine: 3706.57 mg
#   Tryptophan: 1447.57 mg
#   Valine: 5823.57 mg
#
# ----------------------------------------
#
# Combination 9998: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Egg_whole_dried_stabilized_glucose_reduced
#   Histidine: 1212.00 mg
#   Isoleucine: 3102.00 mg
#   Leucine: 4373.00 mg
#   Lysine: 3366.00 mg
#   Methionine: 1579.00 mg
#   Phenylalanine: 2814.00 mg
#   Threonine: 2438.00 mg
#   Tryptophan: 799.00 mg
#   Valine: 3555.00 mg
#
# ----------------------------------------
#
# Combination 9999: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Fish_whitefish_dried__Alaska_Native_
#   Histidine: 1352.00 mg
#   Isoleucine: 2342.00 mg
#   Leucine: 4243.00 mg
#   Lysine: 4876.00 mg
#   Methionine: 1759.00 mg
#   Phenylalanine: 2434.00 mg
#   Threonine: 2548.00 mg
#   Tryptophan: 599.00 mg
#   Valine: 2705.00 mg
#
# ----------------------------------------
#
# Combination 10000: Beans_pinto_mature_seeds_sprouted_cooked_boiled_drained_without_salt + Nutribiotic_Systems_-_Rice_Protein
#   Histidine: 1596.00 mg
#   Isoleucine: 4095.00 mg
#   Leucine: 6389.00 mg
#   Lysine: 3625.00 mg
#   Methionine: 1600.00 mg
#   Phenylalanine: 3107.00 mg
#   Threonine: 3341.00 mg
#   Tryptophan: 1088.00 mg
#   Valine: 4233.00 mg
#
# ----------------------------------------

# %%
import csv

# Define required minimum values for essential amino acids (in mg)
REQUIRED_AMINO_ACIDS = {
    "Histidine": 980,
    "Isoleucine": 1330,
    "Leucine": 2940,
    "Lysine": 2660,
    "Methionine": 1330,
    "Phenylalanine": 2310,
    "Threonine": 1400,
    "Tryptophan": 350,
    "Valine": 1680
}

# File paths
file_path = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/food_amino_acids_cleaned.csv"
output_file = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/foods_with_missing_amino_acids.csv"

# Store foods that lack certain amino acids
foods_with_deficiencies = []

# Read the CSV file
with open(file_path, mode="r", encoding="utf-8") as file:
    reader = csv.reader(file)
    header = next(reader)  # Read the header row

    # Get column indices of essential amino acids
    amino_acid_indices = {aa: header.index(aa) for aa in REQUIRED_AMINO_ACIDS.keys()}

    # Check each food item
    for row in reader:
        food_name = row[0]
        amino_acid_values = {aa: float(row[amino_acid_indices[aa]]) for aa in REQUIRED_AMINO_ACIDS.keys()}

        # Identify missing (insufficient) amino acids
        lacking_amino_acids = [aa for aa in REQUIRED_AMINO_ACIDS.keys() if amino_acid_values[aa] < REQUIRED_AMINO_ACIDS[aa]]

        if lacking_amino_acids:
            foods_with_deficiencies.append([food_name] + lacking_amino_acids)

# Save results to a new CSV file
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Food Name", "Lacking Amino Acids"])  # Header
    writer.writerows(foods_with_deficiencies)

# Print results
print(f"Foods with missing amino acids saved to '{output_file}'.")
# Out:
# Foods with missing amino acids saved to 'C:/Users/laure/OneDrive/Documents/GitHub/KG_project/foods_with_missing_amino_acids.csv'.

# %%
import csv
from collections import Counter

# Define required minimum values for essential amino acids (in mg)
REQUIRED_AMINO_ACIDS = {
    "Histidine": 980,
    "Isoleucine": 1330,
    "Leucine": 2940,
    "Lysine": 2660,
    "Methionine": 1330,
    "Phenylalanine": 2310,
    "Threonine": 1400,
    "Tryptophan": 350,
    "Valine": 1680
}

# File paths
input_file = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/foods_with_missing_amino_acids.csv"
output_file = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/amino_acid_missing_counts.csv"

# Initialize a counter for missing amino acids
missing_amino_acids_counter = Counter()

# Read the CSV file with foods that have missing amino acids
with open(input_file, mode="r", encoding="utf-8") as file:
    reader = csv.reader(file)
    header = next(reader)  # Skip the header row

    # Iterate through each food item row
    for row in reader:
        food_name = row[0]  # Food name is the first column
        lacking_amino_acids = row[1:]  # The rest are the lacking amino acids

        # Remove empty strings or any extra spaces
        lacking_amino_acids = [aa for aa in lacking_amino_acids if aa.strip()]

        # Update the counter with each missing amino acid
        missing_amino_acids_counter.update(lacking_amino_acids)

# Save the amino acid missing counts to a new CSV file
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Amino Acid", "Count"])  # Header row
    for amino_acid, count in missing_amino_acids_counter.items():
        writer.writerow([amino_acid, count])

# Print results
print(f"Missing amino acid counts saved to '{output_file}'.")
# Out:
# Missing amino acid counts saved to 'C:/Users/laure/OneDrive/Documents/GitHub/KG_project/amino_acid_missing_counts.csv'.

# %%
import csv

# Define the required essential amino acids (in mg)
REQUIRED_AMINO_ACIDS = [
    "Histidine", "Isoleucine", "Leucine", "Lysine", "Methionine",
    "Phenylalanine", "Threonine", "Tryptophan", "Valine"
]

# Define the threshold for high protein (in grams)
PROTEIN_THRESHOLD = 10  # Protein above 10 grams

# File path to the CSV with the amino acid profiles
input_file = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/food_amino_acids.csv"

# Read the file and process the foods
with open(input_file, mode="r", encoding="utf-8") as file:
    reader = csv.reader(file)
    header = next(reader)  # Skip the header row

    # Find the column index for "Protein" and other amino acids
    protein_index = header.index("Protein")  # Assuming "Protein" column is labeled as "Protein"
    amino_acid_indices = {aa: header.index(aa) for aa in REQUIRED_AMINO_ACIDS}

    # Go over each row and filter foods with high protein but missing amino acids
    foods_with_missing_amino_acids = []

    for row in reader:
        food_name = row[0]  # Food name is the first column
        protein_amount = float(row[protein_index])  # Protein amount in grams

        # Check if the food has protein above the threshold
        if protein_amount > PROTEIN_THRESHOLD:
            # Check which amino acids are missing
            lacking_amino_acids = [aa for aa in REQUIRED_AMINO_ACIDS if not row[amino_acid_indices[aa]].strip()]

            if lacking_amino_acids:
                # Save food name and missing amino acids
                food_info = {
                    "name": food_name,
                    "protein": protein_amount,
                    "lacking_amino_acids": lacking_amino_acids
                }
                foods_with_missing_amino_acids.append(food_info)

# Print the results
if foods_with_missing_amino_acids:
    print(f"Foods with more than {PROTEIN_THRESHOLD}g of protein but missing amino acids:\n")
    for food in foods_with_missing_amino_acids:
        print(f"Food: {food['name']}, Protein: {food['protein']}g, Missing Amino Acids: {', '.join(food['lacking_amino_acids'])}")
else:
    print(f"No foods with more than {PROTEIN_THRESHOLD}g of protein and missing amino acids found.")
# Out:
# No foods with more than 10g of protein and missing amino acids found.

# %%
import csv

# File path to the cleaned amino acids CSV
input_file = "C:/Users/laure/OneDrive/Documents/GitHub/KG_project/food_amino_acids_cleaned.csv"

# Initialize dictionaries to store best and worst values
best_acids = {}
worst_acids = {}

# Read the file and process the amino acid data
with open(input_file, mode="r", encoding="utf-8") as file:
    reader = csv.reader(file)
    header = next(reader)  # Get the header

    # Initialize best and worst tracking dictionaries
    for acid in header[3:]:  # Assuming amino acids columns are after the third column
        best_acids[acid] = {"name": None, "value": float("-inf")}
        worst_acids[acid] = {"name": None, "value": float("inf")}

    for row in reader:
        food_name = row[0]  # Food name is the first column
        protein_value = float(row[3])  # Assuming protein content is in the second column

        if protein_value >= 10:
            for index, acid in enumerate(header[3:], start=3):
                try:
                    value = float(row[index])
                    if value <= 50000:
                        if value > best_acids[acid]["value"]:
                            best_acids[acid] = {"name": food_name, "value": value}
                        if value < worst_acids[acid]["value"]:
                            worst_acids[acid] = {"name": food_name, "value": value}
                except ValueError:
                    continue  # Skip invalid or missing values

# Print the results
for acid in header[3:]:
    print(f"{acid}:")
    print(f"  Best: {best_acids[acid]['name']} - {best_acids[acid]['value']}")
    print(f"  Worst: {worst_acids[acid]['name']} - {worst_acids[acid]['value']}")
# Out:
# Protein:
#   Best: Soy_protein_isolate_potassium_type - 88.3
#   Worst: Bread_stuffing_cornbread_dry_mix - 10.0
# Histidine:
#   Best: Whale_beluga_meat_dried__Alaska_Native_ - 2999.0
#   Worst: Pork_cured_feet_pickled - 127.97356828193833
# Isoleucine:
#   Best: Egg_white_dried_powder_stabilized_glucose_reduced - 5028.571428571428
#   Worst: Onion_Powder - 142.85714285714286
# Leucine:
#   Best: Rexall_Sundown_Inc__-_Whey_Protein_Powder - 7606.999999999999
#   Worst: Onion_Powder - 214.28571428571428
# Lysine:
#   Best: Seal_bearded__Oogruk__meat_dried__Alaska_Native_ - 6690.000000000001
#   Worst: Beverages_coffee_instant_decaffeinated_powder - 92.0
# Methionine:
#   Best: Egg_white_dried_powder_stabilized_glucose_reduced - 3200.0
#   Worst: Beverages_coffee_instant_decaffeinated_powder - 22.0
# Phenylalanine:
#   Best: Egg_white_dried_powder_stabilized_glucose_reduced - 5185.714285714285
#   Worst: Barley_malt_flour - 225.0
# Threonine:
#   Best: Rexall_Sundown_Inc__-_Whey_Protein_Powder - 5440.0
#   Worst: Cooked_Wild_Eastern_Oysters - 45.23809523809524
# Tryptophan:
#   Best: Sunfood_LLC_-_Organic_Supergreens___Protein - 1832.0
#   Worst: Dry_Powder_Gelatin - 0.0
# Valine:
#   Best: Egg_white_dried_powder_stabilized_glucose_reduced - 6171.428571428572
#   Worst: Onion_Powder - 171.42857142857142
